# %%
import json
import pandas as pd
import statistics as stats
import re
import pprint

# %%
ALL_TABULAR_DATASETS = ["adult", "census", "child", "covtype", "credit", "insurance", "health_insurance", 
                       "intrusion", "drugs", "loan", "pums"]
ALL_TABULAR_MODELS = {
    "gretel": ["actgan"], 
    "sdv": ["ctgan", "tvae", "gaussian_copula"], 
    "syn": ["ctgan", "tvae", "goggle", "arf", "ddpm", "nflow", "rtvae"], 
    "llm": ["great"], 
    "betterdata": ["gan", "gan_dp"]
}

ALL_SEQUENTIAL_DATASETS = ["taxi", "nasdaq", "pums"]

ALL_SEQUENTIAL_MODELS = {
    "gretel": ["dgan"],
    "sdv": ["par"]
}

# %% [markdown]
# # Jobs Evaluation

# %%
def get_cmds_configs(command_string):

    # Sample command string
    # command_string = "python3 run_model.py --m sequential --l sdv --s par --data nasdaq --o outputs --run_model_training --use_gpu"

    # Regular expression pattern to extract arguments for "--l", "--s", and "--data"
    pattern = r"--l (\S+).*?--s (\S+).*?--data (\S+)"

    # Use regex to find the match
    match = re.search(pattern, command_string)

    # Extract values from the match
    library = match.group(1) if match else None
    synthesizer = match.group(2) if match else None
    data = match.group(3) if match else None

    return (library, synthesizer, data)

# %%
sdg_jobs_df = pd.read_csv("../final_outs/sdg_jobs.csv")
if 'Unnamed: 0' in sdg_jobs_df.columns:
    sdg_jobs_df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
sdg_jobs_df.columns
# Out:
# Index(['Experiment Name', 'Run ID', 'Status', 'Creation Time', 'End Time',
#        'Duration (seconds)', 'Compute Target', 'Command Parameters'],
#       dtype='object')

# %%
# sdg_jobs_df[["Command Parameters"]]

# %% [markdown]
# ## Incompleted Jobs -- Failed, Canceled, Running

# %%
# Iterate over rows and print 'Command Parameters' for specific 'Status' values
TABULAR_INCOMPLETE_JOBS = {
    "gretel": {}, 
    "sdv": {}, 
    "syn": {}
}
for index, row in sdg_jobs_df.iterrows():
    if row['Status'] in ['Failed', 'Canceled', 'Running']:
        (library, synthesizer, data) = get_cmds_configs(row['Command Parameters'])
        if library and synthesizer and data:
            # print(library, synthesizer, data)
            
            if library == "synthcity":
                library = "syn"
            
            if synthesizer in TABULAR_INCOMPLETE_JOBS[library]:
                TABULAR_INCOMPLETE_JOBS[library][synthesizer][data] = row['Status']
            else:
                TABULAR_INCOMPLETE_JOBS[library][synthesizer] = {}
                TABULAR_INCOMPLETE_JOBS[library][synthesizer][data] = row['Status']
                
                
pprint.pprint(TABULAR_INCOMPLETE_JOBS)
# Out:
# {'gretel': {'dgan': {'pums': 'Failed'}},
#  'sdv': {'ctgan': {'insurance': 'Failed'}, 'par': {'pums': 'Failed'}},
#  'syn': {'arf': {'pums': 'Failed'},
#          'ctgan': {'covtype': 'Running',
#                    'credit': 'Canceled',
#                    'pums': 'Failed'},
#          'ddpm': {'pums': 'Canceled'},
#          'goggle': {'adult': 'Failed',
#                     'covtype': 'Failed',
#                     'intrusion': 'Failed',
#                     'loan': 'Failed',
#                     'pums': 'Running'},
#          'nflow': {'adult': 'Failed',
#                    'covtype': 'Failed',
#                    'loan': 'Failed',
#                    'pums': 'Failed'},
#          'rtvae': {'credit': 'Canceled', 'pums': 'Failed'},
#          'tvae': {'pums': 'Failed'}}}

# %%
ERROR_VAL  = -99
def get_scores_df(exp_dataset, models_list, case="tabular", all_jobs=False):
    
    final_report = {
        "dataset": [], 
        "model": [],
        "case": [], 
        "domain_cov": [], 
        "stats_cov": [], 
        "outliers_cov": [],
        "missing_cov": [],
        "ks_sim": [], 
        "tv_sim": [],
        "corr_sim": [], 
        "contin_sim": [], 
        "sdv_quality_report": [],
        "wass_dist": [], 
        "js_dist": [], 
        "new_row_synthesis": []
    }


    for lib, models in models_list.items():
        
        if case == "hpo" and lib!= "syn":
            continue
        for model in models: 
            
            if case in ["hyperimpute", "ice", "missforest", "simple", "only_hyperimpute", "only_ice", "only_missforest", "only_simple",]:  
                corr_file = f"../metrics_out/hyperimpute/{model}_{lib}/{exp_dataset}/{case}/{exp_dataset}_{model}_correlation.csv"
                metrics_file = f"../metrics_out/hyperimpute/{model}_{lib}/{exp_dataset}/{case}/{exp_dataset}_{model}_metrics.json"
            else:
                corr_file = f"../metrics_out/{case}/{model}_{lib}/{exp_dataset}/{exp_dataset}_{model}_correlation.csv"
                metrics_file = f"../metrics_out/{case}/{model}_{lib}/{exp_dataset}/{exp_dataset}_{model}_metrics.json"
                        
            try:
                with open(metrics_file, 'r') as file:
                    metrics_scores = json.load(file)
                corr_df = pd.read_csv(corr_file)
                # print("Success:", metrics_file)
            except Exception as e:
                # print(e)
                if all_jobs:
                    # print(model, lib)
                    status = None
                    if lib in TABULAR_INCOMPLETE_JOBS and model in TABULAR_INCOMPLETE_JOBS[lib]:
                        if exp_dataset in TABULAR_INCOMPLETE_JOBS[lib][model]:
                            # print("Status: ",  TABULAR_INCOMPLETE_JOBS[lib][model][exp_dataset])
                            # print("-")
                            status = TABULAR_INCOMPLETE_JOBS[lib][model][exp_dataset]
                        else:
                            status = -99 #"Skipped"
                    else:
                        status =  -99 #"Skipped"
                        # print(e)
                        # print("Skipped")
                    for k in final_report.keys():
                        if k not in ["model", "dataset", "case"]: 
                            final_report[k].append(ERROR_VAL) #.append(status)
                        # print(final_report)
                    
                continue
            
            final_report["model"].append(f"{model}_{lib}")
            final_report["dataset"].append(exp_dataset)
            final_report["case"].append(case)
            
            #----------------------
            # Domain Coverage
            #----------------------
            if metrics_scores["coverage"]["domain_coverage"].values():
                domain_coverage_mean = round(stats.mean(metrics_scores["coverage"]["domain_coverage"].values()), 2)
                final_report["domain_cov"].append(domain_coverage_mean)
            else:
                # Handle the case for empty list, e.g., append a default value or skip
                final_report["domain_cov"].append(ERROR_VAL)  # or any other default value

            #----------------------
            # Missing values Coverage
            #----------------------
            if metrics_scores["coverage"]["missing_values_coverage"].values():
                missing_values_coverage_mean = round(stats.mean(metrics_scores["coverage"]["missing_values_coverage"].values()), 2)
                final_report["missing_cov"].append(missing_values_coverage_mean)
            else:
                # Handle the case for empty list, e.g., append a default value or skip
                final_report["missing_cov"].append(ERROR_VAL)  # or any other default value

            #----------------------
            # Outliers Coverage
            #----------------------
            if metrics_scores["coverage"]["outlier_coverage"].values():
                outlier_coverage_mean = round(stats.mean(metrics_scores["coverage"]["outlier_coverage"].values()), 2)
                final_report["outliers_cov"].append(outlier_coverage_mean)
            else:
                # Handle the case for empty list, e.g., append a default value or skip
                final_report["outliers_cov"].append(ERROR_VAL)  # or any other default value
            
            #----------------------
            # Statistics Similarity
            #----------------------
            # Initialize total and count variables
            total_average = 0
            count = 0
            # Calculate the average of mean, median, and std for each column
            try:
                for c, s in metrics_scores["similarity"]["statistic"].items():
                    column_average = (s["mean"] + s["median"] + s["std"]) / 3
                    total_average += column_average
                    count += 1
                # Calculate the overall average
                overall_average = total_average / count if count > 0 else ERROR_VAL
                final_report["stats_cov"].append(round(overall_average, 2))
            except:
                final_report["stats_cov"].append(ERROR_VAL)

            #---------------------------
            # KSComplement & TVComplement
            #---------------------------
            ks_scores = []
            tv_scores = []
            for key, value in metrics_scores["sdv_quality_report"]["distribution"].items():
                if value["metric"] == "KSComplement":
                    ks_scores.append(value["score"])
                elif value["metric"] == "TVComplement":
                    tv_scores.append(value["score"])

            # Calculating averages
            ks_average = stats.mean(ks_scores) if ks_scores else ERROR_VAL
            tv_average = stats.mean(tv_scores) if tv_scores else ERROR_VAL
            final_report["ks_sim"].append(round(ks_average, 2))
            final_report["tv_sim"].append(round(tv_average, 2))

            #--------------------------------------------
            # contingency_average, correlation_average
            #--------------------------------------------
            contingency_average = corr_df[corr_df['Metric'] == 'ContingencySimilarity']["Score"].mean()
            correlation_average = corr_df[corr_df['Metric'] == 'CorrelationSimilarity']["Score"].mean()

            final_report["contin_sim"].append(round(contingency_average, 2))
            final_report["corr_sim"].append(round(correlation_average, 2))

            #--------------------------------------------
            # SDV quality report
            #--------------------------------------------
            final_report["sdv_quality_report"].append(round(metrics_scores["sdv_quality_report"]["score"], 2))
            
            #--------------------------------------------
            # Jensen Shannon Distance
            #--------------------------------------------
            if metrics_scores["similarity"]["js_distance"].values():
                js_dist_mean = round(stats.mean(metrics_scores["similarity"]["js_distance"].values()), 2)
                final_report["js_dist"].append(js_dist_mean)
            else:
                # Handle the case for empty list, e.g., append a default value or skip
                final_report["js_dist"].append(ERROR_VAL)  # or any other default value
                
            #--------------------------------------------
            # Wassertein Distance
            #--------------------------------------------
            if metrics_scores["similarity"]["wass_distance"].values():
                wass_dist_mean = round(stats.mean(metrics_scores["similarity"]["wass_distance"].values()), 2)
                final_report["wass_dist"].append(wass_dist_mean)
            else:
                # Handle the case for empty list, e.g., append a default value or skip
                final_report["wass_dist"].append(ERROR_VAL)  # or any other default value

            #--------------------------------------------
            # Privacy: New row synthesis
            #--------------------------------------------
            if "score" in metrics_scores["privacy"]["new_row_synthesis"]:
                final_report["new_row_synthesis"].append(round(metrics_scores["privacy"]["new_row_synthesis"]["score"], 2))
            else:
                final_report["new_row_synthesis"].append(ERROR_VAL)
            
    return final_report

# %% [markdown]
# # Standard Tabular Evaluation

# %%
# ALL_TABULAR_DATASETS = ["adult", "census", "child", "covtype", "credit", "insurance", "health_insurance", 
#                        "intrusion", "drugs", "loan", "pums"]
std_tabular_df = pd.DataFrame()
for exp_dataset in ALL_TABULAR_DATASETS:
    final_report = get_scores_df(exp_dataset, ALL_TABULAR_MODELS, "tabular", False) 
    std_tabular_df = pd.concat([std_tabular_df, pd.DataFrame(final_report)], ignore_index=True)
std_tabular_df
# Out:
#     dataset                model     case  domain_cov  stats_cov  \
# 0     adult        actgan_gretel  tabular        0.89       0.99
# 1     adult            ctgan_sdv  tabular        0.87       0.99
# 2     adult             tvae_sdv  tabular        0.79       0.99
# 3     adult  gaussian_copula_sdv  tabular        0.92       0.95
# 4     adult            ctgan_syn  tabular        0.91       0.99
# ..      ...                  ...      ...         ...        ...
# 98     loan    gan_dp_betterdata  tabular        0.99       0.98
# 99     pums        actgan_gretel  tabular        0.81       0.99
# 100    pums            ctgan_sdv  tabular        0.82       0.99
# 101    pums             tvae_sdv  tabular        0.80       0.97
# 102    pums  gaussian_copula_sdv  tabular        0.77       0.96
#
#      outliers_cov  missing_cov  ks_sim  tv_sim  corr_sim  contin_sim  \
# 0            0.49         1.00    0.79    0.92      0.97        0.87
# 1            0.79         1.00    0.87    0.91      0.98        0.82
# 2            0.68         1.00    0.88    0.94      0.97        0.88
# 3            0.41         1.00    0.70    0.80      0.99        0.73
# 4            0.49         1.00    0.76    0.79      0.98        0.74
# ..            ...          ...     ...     ...       ...         ...
# 98           0.35         1.00    0.92    0.95      0.91        0.73
# 99           0.60         0.98    0.85    0.98      0.97        0.91
# 100          0.67         1.00    0.88    0.99      0.99        0.94
# 101          0.63         1.00    0.81    0.92      0.95        0.82
# 102          0.52         1.00    0.73    0.73      0.97        0.62
#
#      sdv_quality_report  wass_dist  js_dist  new_row_synthesis
# 0                  0.88       0.02     0.24               1.00
# 1                  0.87       0.02     0.22               1.00
# 2                  0.91       0.02     0.13               1.00
# 3                  0.76       0.07     0.29               1.00
# 4                  0.78       0.02     0.34               1.00
# ..                  ...        ...      ...                ...
# 98                 0.85       0.02     0.16               1.00
# 99                 0.92       0.01     0.20               0.99
# 100                0.95       0.01     0.19               1.00
# 101                0.86       0.04     0.29               1.00
# 102                0.69       0.05     0.35               1.00
#
# [103 rows x 15 columns]

# %% [markdown]
# # Imputation Evaluation -- imputed data and generated synthetic data (with imputation)

# %%
ALL_HYPERIMPUTE_MODELS = {
    "sdv": ["ctgan"]
}

IMPUTERS = ["missforest", "ice", "hyperimpute", "simple"]

tabular_impute_df = pd.DataFrame()
for imputer in IMPUTERS:
    final_report = get_scores_df("drugs", ALL_HYPERIMPUTE_MODELS, imputer, True)
    tabular_impute_df = pd.concat([tabular_impute_df, pd.DataFrame(final_report)], ignore_index=True)
    
    final_report = get_scores_df("drugs", ALL_HYPERIMPUTE_MODELS, "only_" + imputer, True)
    tabular_impute_df = pd.concat([tabular_impute_df, pd.DataFrame(final_report)], ignore_index=True)
    
tabular_impute_df
# Out:
#   dataset      model              case  domain_cov  stats_cov  outliers_cov  \
# 0   drugs  ctgan_sdv        missforest        0.92       0.99           0.0
# 1   drugs  ctgan_sdv   only_missforest        0.93       1.00           1.0
# 2   drugs  ctgan_sdv               ice        0.96       0.93           0.0
# 3   drugs  ctgan_sdv          only_ice        0.96       1.00           1.0
# 4   drugs  ctgan_sdv       hyperimpute        0.95       0.92           1.0
# 5   drugs  ctgan_sdv  only_hyperimpute        0.95       1.00           1.0
# 6   drugs  ctgan_sdv            simple        0.90       0.98           0.0
# 7   drugs  ctgan_sdv       only_simple        0.91       1.00           1.0
#
#    missing_cov  ks_sim  tv_sim  corr_sim  contin_sim  sdv_quality_report  \
# 0         0.42    0.95    0.88      0.92        0.17                0.53
# 1         0.42    0.98    0.91      0.97        0.19                0.55
# 2         0.42    0.90    0.89      0.95        0.17                0.53
# 3         0.42    0.98    0.92      0.97        0.19                0.56
# 4         0.42    0.85    0.90      0.96        0.17                0.53
# 5         0.42    0.98    0.92      0.97        0.19                0.56
# 6         0.42    0.94    0.89      0.96        0.17                0.53
# 7         0.42    0.98    0.92      0.97        0.19                0.56
#
#    wass_dist  js_dist  new_row_synthesis
# 0       0.01     0.07                -99
# 1       0.01     0.05                -99
# 2       0.09     0.22                -99
# 3       0.01     0.05                -99
# 4       0.12     0.27                -99
# 5       0.01     0.05                -99
# 6       0.03     0.10                -99
# 7       0.01     0.05                -99

# %% [markdown]
# # Hyperparameter Optimisation

# %%
# exp_dataset = "adult"
HPO_DATASETS = ["adult", "loan"]
hpo_df = pd.DataFrame()
for exp_dataset in HPO_DATASETS:
    final_report = get_scores_df(exp_dataset, ALL_TABULAR_MODELS, "hpo", False)
    hpo_df = pd.concat([hpo_df, pd.DataFrame(final_report)], ignore_index=True)
hpo_df
# Out:
#   dataset      model case  domain_cov  stats_cov  outliers_cov  missing_cov  \
# 0   adult  ctgan_syn  hpo        0.94       0.99          0.59          1.0
# 1   adult   tvae_syn  hpo        0.92       0.99          0.57          1.0
# 2   adult    arf_syn  hpo        0.98       1.00          0.81          1.0
# 3   adult   ddpm_syn  hpo        0.99       1.00          0.72          1.0
# 4   adult  rtvae_syn  hpo        0.96       0.98          0.95          1.0
# 5    loan  ctgan_syn  hpo        0.97       0.99          0.40          1.0
# 6    loan   tvae_syn  hpo        0.95       0.98          0.35          1.0
# 7    loan    arf_syn  hpo        1.00       0.99          0.46          1.0
# 8    loan   ddpm_syn  hpo        1.00       0.94          0.45          1.0
# 9    loan  rtvae_syn  hpo        0.87       0.97          0.35          1.0
#
#    ks_sim  tv_sim  corr_sim  contin_sim  sdv_quality_report  wass_dist  \
# 0    0.80    0.83      0.98        0.76                0.81       0.01
# 1    0.90    0.85      0.99        0.80                0.85       0.01
# 2    0.90    0.92      0.99        0.87                0.90       0.01
# 3    0.98    0.97      0.99        0.94                0.96       0.01
# 4    0.84    0.80      0.96        0.74                0.79       0.03
# 5    0.91    0.98      0.96        0.93                0.94       0.03
# 6    0.93    0.98      0.96        0.92                0.94       0.02
# 7    0.90    0.99      0.98        0.93                0.94       0.02
# 8    0.95    0.97      0.98        0.88                0.93       0.03
# 9    0.87    0.98      0.94        0.81                0.88       0.04
#
#    js_dist  new_row_synthesis
# 0     0.27                1.0
# 1     0.19                1.0
# 2     0.16                1.0
# 3     0.07                1.0
# 4     0.23                1.0
# 5     0.17                1.0
# 6     0.19                1.0
# 7     0.14                1.0
# 8     0.10                1.0
# 9     0.47                1.0

# %% [markdown]
# # Sequential Evaulation

# %%
#TODO: pums-dgan is running 
seq_df = pd.DataFrame()
for exp_dataset in ALL_SEQUENTIAL_DATASETS:
    final_report = get_scores_df(exp_dataset, ALL_SEQUENTIAL_MODELS, "sequential", False)
    seq_df = pd.concat([seq_df, pd.DataFrame(final_report)], ignore_index=True)
seq_df
# Out:
#   dataset        model        case  domain_cov  stats_cov  outliers_cov  \
# 0    taxi  dgan_gretel  sequential         NaN     -99.00          0.17
# 1    taxi      par_sdv  sequential         NaN     -99.00          0.11
# 2  nasdaq  dgan_gretel  sequential        0.32       0.95          0.82
# 3  nasdaq      par_sdv  sequential        0.37       0.96          0.43
#
#    missing_cov  ks_sim  tv_sim  corr_sim  contin_sim  sdv_quality_report  \
# 0         0.88     NaN    0.98      0.92        0.61                0.66
# 1         0.98     NaN    0.96      0.94        0.72                0.82
# 2         0.97    0.65    0.36      0.88        0.38                0.55
# 3         0.99    0.89    0.57      0.89        0.46                0.69
#
#    wass_dist  js_dist  new_row_synthesis
# 0       0.19     0.69              -99.0
# 1       0.37     0.49              -99.0
# 2       0.05     0.36                1.0
# 3       0.03     0.21                1.0

# %%
# tabular_bm_df.to_csv("tabular_benchmarks.csv")

# %% [markdown]
# # Machine Learning Metrics

# %%
ML_CLASSIFICATION_TASK_DATASETS = [
    "adult", "census", "credit", "covtype", "loan", "intrusion"]
ML_REGRESSION_TASK_DATASETS = ["health_insurance"]

ERROR_VAL  = -99
def get_ml_scores_df(exp_dataset, report, metric):
    for lib, models in ALL_TABULAR_MODELS.items():
        for model in models: 
            # corr_file = f"../metrics_out/tabular/{model}_{lib}/{exp_dataset}/{exp_dataset}_{model}_correlation.csv"
            metrics_file = f"../metrics_out/tabular/{model}_{lib}/{exp_dataset}/{exp_dataset}_{model}_metrics.json"
                        
            try:
                with open(metrics_file, 'r') as file:
                    metrics_scores = json.load(file)
            except Exception as e:
                # print(e)
                # print(model, lib)
                # status = None
                # if lib in TABULAR_INCOMPLETE_JOBS and model in TABULAR_INCOMPLETE_JOBS[lib]:
                #     if exp_dataset in TABULAR_INCOMPLETE_JOBS[lib][model]:
                #         # print("Status: ",  TABULAR_INCOMPLETE_JOBS[lib][model][exp_dataset])
                #         # print("-")
                #         status = TABULAR_INCOMPLETE_JOBS[lib][model][exp_dataset]
                #     else:
                #         status = "Skipped"
                # else:
                #     status = "Skipped"
                #     # print(e)
                #     # print("Skipped")
                # for k in report.keys():
                #     if k not in ["model", "dataset", "case"]: 
                #         report[k].append(status)
                #     # print(final_report)
                continue
                
            report["dataset"].append(exp_dataset)
            report["model"].append(f"{model}_{lib}")
            
            for k, v in report.items():
                if k in ["dataset", "model"]:
                    continue   
                try:
                    scores = metrics_scores["ml_efficacy"][k]
                    # print(scores)
                    report[k].append(round(abs(scores[f"synthetic_{metric}"] - scores[f"real_{metric}"]), 2))
                except:
                    report[k].append(ERROR_VAL)
                # final_report_ml_cls["model"]["adaboost_classifier"].append()
                
    # for k, v in report.items():
    #     print(k, len(v))
    return report

# %% [markdown]
# ## Classification

# %%
final_report_ml_cls = {
    "dataset": [],  
    "model": [],
    "adaboost_classification": [], 
    "decision_tree_classification": [], 
    "logistic_classification": [],
    "mlp_classification": [], 
}
ml_cls_metric = "f1"

tabular_ml_cls_df = pd.DataFrame()
for exp_dataset in ML_CLASSIFICATION_TASK_DATASETS:
    final_report = get_ml_scores_df(exp_dataset, final_report_ml_cls, ml_cls_metric)
    tabular_ml_cls_df = pd.concat([tabular_ml_cls_df, pd.DataFrame(final_report)], ignore_index=True)
    
tabular_ml_cls_df
# Out:
#   dataset                model  adaboost_classification  \
# 0   adult        actgan_gretel                     0.03
# 1   adult            ctgan_sdv                     0.01
# 2   adult             tvae_sdv                     0.01
# 3   adult  gaussian_copula_sdv                     0.02
# 4   adult            ctgan_syn                     0.04
#
#    decision_tree_classification  logistic_classification  mlp_classification
# 0                          0.01                     0.05                0.02
# 1                          0.03                     0.05                0.01
# 2                          0.02                     0.05                0.03
# 3                          0.11                     0.06                0.03
# 4                          0.08                     0.06                0.02

# %% [markdown]
# ## Regression

# %%
final_report_ml_regress = {
    "dataset": [],  
    "model": [],
    "linear_regression": [], 
    "mlp_regression": []
}

ml_regress_metric = "r2"
tabular_ml_reg_df = pd.DataFrame()
for exp_dataset in ML_REGRESSION_TASK_DATASETS:
    final_report = get_ml_scores_df(exp_dataset, final_report_ml_regress, ml_regress_metric)
    tabular_ml_reg_df = pd.concat([tabular_ml_reg_df, pd.DataFrame(final_report)], ignore_index=True)
    
tabular_ml_reg_df
# Out:
#              dataset                model  linear_regression  mlp_regression
# 0   health_insurance        actgan_gretel               0.55            0.01
# 1   health_insurance            ctgan_sdv               0.90            0.01
# 2   health_insurance             tvae_sdv               0.12            0.01
# 3   health_insurance  gaussian_copula_sdv               0.31            0.01
# 4   health_insurance            ctgan_syn               0.00            0.01
# 5   health_insurance             tvae_syn               0.05            0.01
# 6   health_insurance           goggle_syn               0.44            0.02
# 7   health_insurance              arf_syn               0.00            0.01
# 8   health_insurance             ddpm_syn               0.27            0.01
# 9   health_insurance            nflow_syn               0.10            0.01
# 10  health_insurance            rtvae_syn               0.20            0.01
# 11  health_insurance            great_llm               0.38            0.01
# 12  health_insurance       gan_betterdata               0.07            0.01

# %% [markdown]
# # Performance Evaluation

# %%
ERROR_VAL  = -99
def get_execution_scores_df(exp_dataset, case="tabular"):
    
    final_report = {
        "dataset": [],
        "lib": [], 
        "model": [],
        "num_rows": [], 
        "num_cols": [], 
        "num_sampled_rows": [],
        "device": [],
        "num_epochs": [], 
        "train_time_sec": [],
        "sample_time_sec": [], 
        "peak_memory_mb": [], 
        "synthesizer_size": [],
        "synthetic_dataset_size_mb_deep": [], 
        "train_dataset_size_mb_deep": [], 
        "synthetic_dataset_size_mb": [],
        "train_dataset_size_mb": []
    }
    
    for lib, models in ALL_TABULAR_MODELS.items():
        
        for model in models: 
            
            BASE = f"final_outs/{lib}_tabular"
            execution_scores_path = f"../{BASE}/{model}/{exp_dataset}/{exp_dataset}_{model}_execution_scores.json"
            
            try:
                with open(execution_scores_path, 'r') as file:
                    execution_scores = json.load(file)
            except Exception as e:
                # print(e)
                continue
                      
            # corr_file = f"../metrics_out/{case}/{model}_{lib}/{exp_dataset}/{exp_dataset}_{model}_correlation.csv"
            # metrics_file = f"../metrics_out/{case}/{model}_{lib}/{exp_dataset}/{exp_dataset}_{model}_metrics.json"
            final_report["model"].append(f"{model}_{lib}")
            for k, v in final_report.items():
                if k in ["model"]: continue # "modality", "synthesizer"
                
                if k not in execution_scores:
                    final_report[k].append("-99")
                    continue
                final_report[k].append(execution_scores[k])
                    
# execution_scores
    # for k, v in final_report.items():
    #     print(k, len(v))
                    
    return final_report

# %%
execution_scores_df = pd.DataFrame()
for exp_dataset in ALL_TABULAR_DATASETS:
    final_report = get_execution_scores_df(exp_dataset, case="tabular")
    execution_scores_df = pd.concat([execution_scores_df, pd.DataFrame(final_report)], ignore_index=True)
execution_scores_df
# Out:
#    dataset               lib                model  num_rows  num_cols  \
# 0    adult     GRETEL_0.20.0        actgan_gretel     26048        16
# 1    adult         SDV_1.2.1            ctgan_sdv     26048        15
# 2    adult         SDV_1.2.1             tvae_sdv     26048        15
# 3    adult         SDV_1.2.1  gaussian_copula_sdv     26048        15
# 4    adult  synthcity==0.2.9            ctgan_syn     26048        15
# ..     ...               ...                  ...       ...       ...
# 93    loan             GREAT            great_llm      5000        14
# 94    pums     GRETEL_0.20.0        actgan_gretel    828161        36
# 95    pums         SDV_1.2.1            ctgan_sdv    828161        36
# 96    pums         SDV_1.2.1             tvae_sdv    828161        36
# 97    pums         SDV_1.2.1  gaussian_copula_sdv    828161        36
#
#    num_sampled_rows device  num_epochs  train_time_sec  sample_time_sec  \
# 0             26048    GPU         300      844.420231         2.135426
# 1             32561    CPU         300     1019.838562         2.317747
# 2             32561    CPU         300      378.850136         0.980367
# 3             32561    CPU           0       11.544246         1.632146
# 4             32561    cpu         300     5387.746336         9.032208
# ..              ...    ...         ...             ...              ...
# 93             5000    GPU         100     2870.947590        35.642844
# 94           828161    GPU         300    50401.469090       198.961060
# 95              -99    GPU         300    34275.731180       190.307225
# 96              -99    GPU         300    22887.041172       153.788952
# 97              -99    CPU           0      691.980786       163.582960
#
#     peak_memory_mb  synthesizer_size synthetic_dataset_size_mb_deep  \
# 0       112.538464         37.958943                      16.898896
# 1       101.742050         35.808308                      20.880857
# 2       101.740078          0.417060                      20.859236
# 3        32.554806          0.135811                      20.769536
# 4       161.648593         38.916708                      21.105475
# ..             ...               ...                            ...
# 93      203.695731        327.700000                            -99
# 94     9927.379896       3308.896283                     284.691334
# 95     8131.216867       2639.754827                     355.908334
# 96     8131.214587          0.997506                     355.923838
# 97     2445.597733          0.322649                     355.926141
#
#    train_dataset_size_mb_deep synthetic_dataset_size_mb train_dataset_size_mb
# 0                   17.094568                  3.334272              3.542528
# 1                   16.886184                  3.907448              3.334144
# 2                   16.886184                  3.907448              3.334144
# 3                   16.886184                  3.907448              3.334144
# 4                   16.886184                  4.167808              3.334144
# ..                        ...                       ...                   ...
# 93                        -99                       -99                   -99
# 94                  291.35225                238.510496            245.135656
# 95                  291.35225                298.138304            245.135656
# 96                  291.35225                298.138304            245.135656
# 97                  291.35225                298.138304            245.135656
#
# [98 rows x 16 columns]

# %% [markdown]
# # Anlaysis

# %%
# merge dataframes 
all_df = pd.DataFrame()
for df in [std_tabular_df, tabular_impute_df, hpo_df, seq_df]:
    all_df = pd.concat([all_df, df], ignore_index=True)

# std_tabular_df
# tabular_impute_df
# hpo_df
# seq_df

# execution_scores_df

# tabular_ml_reg_df
# tabular_ml_cls_df

# %%
all_df.to_csv("tabular_benchmarks.csv")

# %%
all_df.columns
# Out:
# Index(['dataset', 'model', 'case', 'domain_cov', 'stats_cov', 'outliers_cov',
#        'missing_cov', 'ks_sim', 'tv_sim', 'corr_sim', 'contin_sim',
#        'sdv_quality_report', 'wass_dist', 'js_dist', 'new_row_synthesis'],
#       dtype='object')

# %%
all_df["case"].unique()
# Out:
# array(['tabular', 'missforest', 'only_missforest', 'ice', 'only_ice',
#        'hyperimpute', 'only_hyperimpute', 'simple', 'only_simple', 'hpo',
#        'sequential'], dtype=object)

# %%
all_df["dataset"].unique()
# Out:
# array(['adult', 'census', 'child', 'covtype', 'credit', 'insurance',
#        'health_insurance', 'intrusion', 'drugs', 'loan', 'pums', 'taxi',
#        'nasdaq'], dtype=object)

# %%
all_df[all_df["dataset"] == "adult"]
# Out:
#     dataset                model     case  domain_cov  stats_cov  \
# 0     adult        actgan_gretel  tabular        0.89       0.99
# 1     adult            ctgan_sdv  tabular        0.87       0.99
# 2     adult             tvae_sdv  tabular        0.79       0.99
# 3     adult  gaussian_copula_sdv  tabular        0.92       0.95
# 4     adult            ctgan_syn  tabular        0.91       0.99
# 5     adult             tvae_syn  tabular        0.86       0.99
# 6     adult           goggle_syn  tabular        0.33       0.95
# 7     adult              arf_syn  tabular        0.99       1.00
# 8     adult             ddpm_syn  tabular        0.99       1.00
# 9     adult            nflow_syn  tabular        0.97       0.98
# 10    adult            rtvae_syn  tabular        0.73       0.98
# 11    adult            great_llm  tabular        0.90       0.97
# 12    adult       gan_betterdata  tabular        0.95       0.99
# 13    adult    gan_dp_betterdata  tabular        0.97       0.99
# 111   adult            ctgan_syn      hpo        0.94       0.99
# 112   adult             tvae_syn      hpo        0.92       0.99
# 113   adult              arf_syn      hpo        0.98       1.00
# 114   adult             ddpm_syn      hpo        0.99       1.00
# 115   adult            rtvae_syn      hpo        0.96       0.98
#
#      outliers_cov  missing_cov  ks_sim  tv_sim  corr_sim  contin_sim  \
# 0            0.49          1.0    0.79    0.92      0.97        0.87
# 1            0.79          1.0    0.87    0.91      0.98        0.82
# 2            0.68          1.0    0.88    0.94      0.97        0.88
# 3            0.41          1.0    0.70    0.80      0.99        0.73
# 4            0.49          1.0    0.76    0.79      0.98        0.74
# 5            0.65          1.0    0.81    0.89      0.99        0.81
# 6            0.27          1.0    0.62    0.67      0.97        0.49
# 7            0.81          1.0    0.88    0.91      0.99        0.87
# 8            0.68          1.0    0.98    0.97      0.98        0.95
# 9            0.70          1.0    0.89    0.77      0.97        0.69
# 10           0.39          1.0    0.77    0.74      0.98        0.65
# 11           0.63          1.0    0.91    0.84      0.98        0.78
# 12           0.84          1.0    0.96    0.95      0.98        0.36
# 13           0.76          1.0    0.93    0.94      0.98        0.34
# 111          0.59          1.0    0.80    0.83      0.98        0.76
# 112          0.57          1.0    0.90    0.85      0.99        0.80
# 113          0.81          1.0    0.90    0.92      0.99        0.87
# 114          0.72          1.0    0.98    0.97      0.99        0.94
# 115          0.95          1.0    0.84    0.80      0.96        0.74
#
#      sdv_quality_report  wass_dist  js_dist  new_row_synthesis
# 0                  0.88       0.02     0.24               1.00
# 1                  0.87       0.02     0.22               1.00
# 2                  0.91       0.02     0.13               1.00
# 3                  0.76       0.07     0.29               1.00
# 4                  0.78       0.02     0.34               1.00
# 5                  0.84       0.01     0.30               1.00
# 6                  0.59       0.06     0.54               1.00
# 7                  0.90       0.01     0.16               1.00
# 8                  0.97       0.01     0.06               1.00
# 9                  0.77       0.02     0.23               1.00
# 10                 0.73       0.02     0.48               1.00
# 11                 0.84       0.03     0.13               0.99
# 12                 0.70       0.01     0.11               1.00
# 13                 0.68       0.02     0.14               1.00
# 111                0.81       0.01     0.27               1.00
# 112                0.85       0.01     0.19               1.00
# 113                0.90       0.01     0.16               1.00
# 114                0.96       0.01     0.07               1.00
# 115                0.79       0.03     0.23               1.00

# %%
all_df[all_df["model"] == "ctgan_syn"]
# Out:
#               dataset      model     case  domain_cov  stats_cov  \
# 4               adult  ctgan_syn  tabular        0.91       0.99
# 22              child  ctgan_syn  tabular        1.00     -99.00
# 40             credit  ctgan_syn  tabular        0.56       1.00
# 47          insurance  ctgan_syn  tabular        1.00     -99.00
# 58   health_insurance  ctgan_syn  tabular        0.92       0.94
# 71          intrusion  ctgan_syn  tabular        0.96       0.90
# 78              drugs  ctgan_syn  tabular      -99.00     -99.00
# 89               loan  ctgan_syn  tabular        0.96       0.96
# 111             adult  ctgan_syn      hpo        0.94       0.99
# 116              loan  ctgan_syn      hpo        0.97       0.99
#
#      outliers_cov  missing_cov  ks_sim  tv_sim  corr_sim  contin_sim  \
# 4            0.49          1.0    0.76    0.79      0.98        0.74
# 22         -99.00          1.0  -99.00    0.94       NaN        0.90
# 40           0.80          1.0    0.93    1.00      0.97        0.64
# 47         -99.00          1.0  -99.00    0.96       NaN        0.93
# 58           0.32          1.0    0.86    0.88      0.98        0.80
# 71           0.65          1.0    0.78    0.96      0.98        0.91
# 78         -99.00        -99.0    0.89    0.85      0.93        0.14
# 89           0.49          1.0    0.87    0.96      0.98        0.85
# 111          0.59          1.0    0.80    0.83      0.98        0.76
# 116          0.40          1.0    0.91    0.98      0.96        0.93
#
#      sdv_quality_report  wass_dist  js_dist  new_row_synthesis
# 4                  0.78       0.02     0.34               1.00
# 22                 0.92     -99.00   -99.00               0.86
# 40                 0.94       0.01     0.08               0.99
# 47                 0.94     -99.00   -99.00               0.91
# 58                 0.85       0.07     0.21               1.00
# 71                 0.91       0.02     0.17               1.00
# 78                 0.50     -99.00   -99.00             -99.00
# 89                 0.90       0.05     0.21               1.00
# 111                0.81       0.01     0.27               1.00
# 116                0.94       0.03     0.17               1.00

# %%
# def highlight_top3(s, skip_cols):
#     '''
#     Highlight the top 3 unique numerical values in each column with different colors.
#     Skip specified columns.
#     '''
#     if s.name not in ['dataset', 'model', 'case']:
#         # print(s.name)
#         # Find the top 3 unique values
#         unique_top_values = s.drop_duplicates().nlargest(3)

#         return ['background-color: #ffd700' if v == unique_top_values.iloc[0] else
#                 'background-color: #c0c0c0' if v == unique_top_values.iloc[1] else
#                 'background-color: #cd7f32' if v == unique_top_values.iloc[2] else ''
#                 for v in s]
#     else:
#         return ['' for _ in s]  # Return empty styling for skipped columns
    
    
ORANGE = "#FFB347"
GREEN = "#77dd77"
YELLOW = "#fdfd96"
def highlight_top3_min3(s, skip_cols, min_cols):
    # print(s)
    '''
    Highlight the top 3 unique numerical values in each column with different colors.
    Highlight the smallest 3 unique values in specified columns.
    Skip specified columns.
    '''
    if s.name in min_cols:
        # Find the smallest 3 unique values for specified columns
        unique_bottom_values = s.drop_duplicates().nsmallest(3)
        return [f'background-color: {GREEN}' if v == unique_bottom_values.iloc[0] else
                f'background-color: {ORANGE}' if v == unique_bottom_values.iloc[1] else
                f'background-color: {YELLOW}' if v == unique_bottom_values.iloc[2] else ''
                for v in s]
    elif s.name not in skip_cols:
        # print(s.name)
        # Find the top 3 unique values for other columns
        unique_top_values = s.drop_duplicates().nlargest(3)
        return [f'background-color: {GREEN}' if v == unique_top_values.iloc[0] else
                f'background-color: {ORANGE}' if v == unique_top_values.iloc[1] else
                f'background-color: {YELLOW}' if v == unique_top_values.iloc[2] else ''
                for v in s]
    else:
        return ['' for _ in s]  # Return empty styling for skipped columns

# %%
skip_cols = ['dataset', 'model', 'case']
min_cols = ["wass_dist", "js_dist"]

# %% [markdown]
# ## Does HPO performs better?

# %% [markdown]
# ### ctgan | loan & adult

# %%
subset = all_df[(all_df["model"] == "ctgan_syn") & (all_df["dataset"] == "loan")]
df_style = subset.style.apply(lambda s: highlight_top3_min3(s, skip_cols=skip_cols, min_cols=min_cols))
df_style
# Out:
# <style type="text/css">
# #T_d6ba3_row0_col3, #T_d6ba3_row0_col4, #T_d6ba3_row0_col7, #T_d6ba3_row0_col8, #T_d6ba3_row0_col10, #T_d6ba3_row0_col11, #T_d6ba3_row0_col12, #T_d6ba3_row0_col13, #T_d6ba3_row1_col5, #T_d6ba3_row1_col9 {
#   background-color: #FFB347;
# }
# #T_d6ba3_row0_col5, #T_d6ba3_row0_col6, #T_d6ba3_row0_col9, #T_d6ba3_row0_col14, #T_d6ba3_row1_col3, #T_d6ba3_row1_col4, #T_d6ba3_row1_col6, #T_d6ba3_row1_col7, #T_d6ba3_row1_col8, #T_d6ba3_row1_col10, #T_d6ba3_row1_col11, #T_d6ba3_row1_col12, #T_d6ba3_row1_col13, #T_d6ba3_row1_col14 {
#   background-color: #77dd77;
# }
# </style>
# <table id="T_d6ba3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d6ba3_level0_col0" class="col_heading level0 col0" >dataset</th>
#       <th id="T_d6ba3_level0_col1" class="col_heading level0 col1" >model</th>
#       <th id="T_d6ba3_level0_col2" class="col_heading level0 col2" >case</th>
#       <th id="T_d6ba3_level0_col3" class="col_heading level0 col3" >domain_cov</th>
#       <th id="T_d6ba3_level0_col4" class="col_heading level0 col4" >stats_cov</th>
#       <th id="T_d6ba3_level0_col5" class="col_heading level0 col5" >outliers_cov</th>
#       <th id="T_d6ba3_level0_col6" class="col_heading level0 col6" >missing_cov</th>
#       <th id="T_d6ba3_level0_col7" class="col_heading level0 col7" >ks_sim</th>
#       <th id="T_d6ba3_level0_col8" class="col_heading level0 col8" >tv_sim</th>
#       <th id="T_d6ba3_level0_col9" class="col_heading level0 col9" >corr_sim</th>
#       <th id="T_d6ba3_level0_col10" class="col_heading level0 col10" >contin_sim</th>
#       <th id="T_d6ba3_level0_col11" class="col_heading level0 col11" >sdv_quality_report</th>
#       <th id="T_d6ba3_level0_col12" class="col_heading level0 col12" >wass_dist</th>
#       <th id="T_d6ba3_level0_col13" class="col_heading level0 col13" >js_dist</th>
#       <th id="T_d6ba3_level0_col14" class="col_heading level0 col14" >new_row_synthesis</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d6ba3_level0_row0" class="row_heading level0 row0" >89</th>
#       <td id="T_d6ba3_row0_col0" class="data row0 col0" >loan</td>
#       <td id="T_d6ba3_row0_col1" class="data row0 col1" >ctgan_syn</td>
#       <td id="T_d6ba3_row0_col2" class="data row0 col2" >tabular</td>
#       <td id="T_d6ba3_row0_col3" class="data row0 col3" >0.960000</td>
#       <td id="T_d6ba3_row0_col4" class="data row0 col4" >0.960000</td>
#       <td id="T_d6ba3_row0_col5" class="data row0 col5" >0.490000</td>
#       <td id="T_d6ba3_row0_col6" class="data row0 col6" >1.000000</td>
#       <td id="T_d6ba3_row0_col7" class="data row0 col7" >0.870000</td>
#       <td id="T_d6ba3_row0_col8" class="data row0 col8" >0.960000</td>
#       <td id="T_d6ba3_row0_col9" class="data row0 col9" >0.980000</td>
#       <td id="T_d6ba3_row0_col10" class="data row0 col10" >0.850000</td>
#       <td id="T_d6ba3_row0_col11" class="data row0 col11" >0.900000</td>
#       <td id="T_d6ba3_row0_col12" class="data row0 col12" >0.050000</td>
#       <td id="T_d6ba3_row0_col13" class="data row0 col13" >0.210000</td>
#       <td id="T_d6ba3_row0_col14" class="data row0 col14" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d6ba3_level0_row1" class="row_heading level0 row1" >116</th>
#       <td id="T_d6ba3_row1_col0" class="data row1 col0" >loan</td>
#       <td id="T_d6ba3_row1_col1" class="data row1 col1" >ctgan_syn</td>
#       <td id="T_d6ba3_row1_col2" class="data row1 col2" >hpo</td>
#       <td id="T_d6ba3_row1_col3" class="data row1 col3" >0.970000</td>
#       <td id="T_d6ba3_row1_col4" class="data row1 col4" >0.990000</td>
#       <td id="T_d6ba3_row1_col5" class="data row1 col5" >0.400000</td>
#       <td id="T_d6ba3_row1_col6" class="data row1 col6" >1.000000</td>
#       <td id="T_d6ba3_row1_col7" class="data row1 col7" >0.910000</td>
#       <td id="T_d6ba3_row1_col8" class="data row1 col8" >0.980000</td>
#       <td id="T_d6ba3_row1_col9" class="data row1 col9" >0.960000</td>
#       <td id="T_d6ba3_row1_col10" class="data row1 col10" >0.930000</td>
#       <td id="T_d6ba3_row1_col11" class="data row1 col11" >0.940000</td>
#       <td id="T_d6ba3_row1_col12" class="data row1 col12" >0.030000</td>
#       <td id="T_d6ba3_row1_col13" class="data row1 col13" >0.170000</td>
#       <td id="T_d6ba3_row1_col14" class="data row1 col14" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
subset = all_df[(all_df["model"] == "ctgan_syn") & (all_df["dataset"] == "adult")]
df_style = subset.style.apply(lambda s: highlight_top3_min3(s, skip_cols=skip_cols, min_cols=min_cols))
df_style
# Out:
# <style type="text/css">
# #T_7d761_row0_col3, #T_7d761_row0_col5, #T_7d761_row0_col7, #T_7d761_row0_col8, #T_7d761_row0_col10, #T_7d761_row0_col11, #T_7d761_row0_col12, #T_7d761_row0_col13 {
#   background-color: #FFB347;
# }
# #T_7d761_row0_col4, #T_7d761_row0_col6, #T_7d761_row0_col9, #T_7d761_row0_col14, #T_7d761_row1_col3, #T_7d761_row1_col4, #T_7d761_row1_col5, #T_7d761_row1_col6, #T_7d761_row1_col7, #T_7d761_row1_col8, #T_7d761_row1_col9, #T_7d761_row1_col10, #T_7d761_row1_col11, #T_7d761_row1_col12, #T_7d761_row1_col13, #T_7d761_row1_col14 {
#   background-color: #77dd77;
# }
# </style>
# <table id="T_7d761">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7d761_level0_col0" class="col_heading level0 col0" >dataset</th>
#       <th id="T_7d761_level0_col1" class="col_heading level0 col1" >model</th>
#       <th id="T_7d761_level0_col2" class="col_heading level0 col2" >case</th>
#       <th id="T_7d761_level0_col3" class="col_heading level0 col3" >domain_cov</th>
#       <th id="T_7d761_level0_col4" class="col_heading level0 col4" >stats_cov</th>
#       <th id="T_7d761_level0_col5" class="col_heading level0 col5" >outliers_cov</th>
#       <th id="T_7d761_level0_col6" class="col_heading level0 col6" >missing_cov</th>
#       <th id="T_7d761_level0_col7" class="col_heading level0 col7" >ks_sim</th>
#       <th id="T_7d761_level0_col8" class="col_heading level0 col8" >tv_sim</th>
#       <th id="T_7d761_level0_col9" class="col_heading level0 col9" >corr_sim</th>
#       <th id="T_7d761_level0_col10" class="col_heading level0 col10" >contin_sim</th>
#       <th id="T_7d761_level0_col11" class="col_heading level0 col11" >sdv_quality_report</th>
#       <th id="T_7d761_level0_col12" class="col_heading level0 col12" >wass_dist</th>
#       <th id="T_7d761_level0_col13" class="col_heading level0 col13" >js_dist</th>
#       <th id="T_7d761_level0_col14" class="col_heading level0 col14" >new_row_synthesis</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7d761_level0_row0" class="row_heading level0 row0" >4</th>
#       <td id="T_7d761_row0_col0" class="data row0 col0" >adult</td>
#       <td id="T_7d761_row0_col1" class="data row0 col1" >ctgan_syn</td>
#       <td id="T_7d761_row0_col2" class="data row0 col2" >tabular</td>
#       <td id="T_7d761_row0_col3" class="data row0 col3" >0.910000</td>
#       <td id="T_7d761_row0_col4" class="data row0 col4" >0.990000</td>
#       <td id="T_7d761_row0_col5" class="data row0 col5" >0.490000</td>
#       <td id="T_7d761_row0_col6" class="data row0 col6" >1.000000</td>
#       <td id="T_7d761_row0_col7" class="data row0 col7" >0.760000</td>
#       <td id="T_7d761_row0_col8" class="data row0 col8" >0.790000</td>
#       <td id="T_7d761_row0_col9" class="data row0 col9" >0.980000</td>
#       <td id="T_7d761_row0_col10" class="data row0 col10" >0.740000</td>
#       <td id="T_7d761_row0_col11" class="data row0 col11" >0.780000</td>
#       <td id="T_7d761_row0_col12" class="data row0 col12" >0.020000</td>
#       <td id="T_7d761_row0_col13" class="data row0 col13" >0.340000</td>
#       <td id="T_7d761_row0_col14" class="data row0 col14" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7d761_level0_row1" class="row_heading level0 row1" >111</th>
#       <td id="T_7d761_row1_col0" class="data row1 col0" >adult</td>
#       <td id="T_7d761_row1_col1" class="data row1 col1" >ctgan_syn</td>
#       <td id="T_7d761_row1_col2" class="data row1 col2" >hpo</td>
#       <td id="T_7d761_row1_col3" class="data row1 col3" >0.940000</td>
#       <td id="T_7d761_row1_col4" class="data row1 col4" >0.990000</td>
#       <td id="T_7d761_row1_col5" class="data row1 col5" >0.590000</td>
#       <td id="T_7d761_row1_col6" class="data row1 col6" >1.000000</td>
#       <td id="T_7d761_row1_col7" class="data row1 col7" >0.800000</td>
#       <td id="T_7d761_row1_col8" class="data row1 col8" >0.830000</td>
#       <td id="T_7d761_row1_col9" class="data row1 col9" >0.980000</td>
#       <td id="T_7d761_row1_col10" class="data row1 col10" >0.760000</td>
#       <td id="T_7d761_row1_col11" class="data row1 col11" >0.810000</td>
#       <td id="T_7d761_row1_col12" class="data row1 col12" >0.010000</td>
#       <td id="T_7d761_row1_col13" class="data row1 col13" >0.270000</td>
#       <td id="T_7d761_row1_col14" class="data row1 col14" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### ddpm | loan & adult

# %%
subset = all_df[(all_df["model"] == "ddpm_syn") & (all_df["dataset"] == "loan")]
df_style = subset.style.apply(lambda s: highlight_top3_min3(s, skip_cols=skip_cols, min_cols=min_cols))
df_style
# Out:
# <style type="text/css">
# #T_5fb6e_row0_col3, #T_5fb6e_row0_col4, #T_5fb6e_row0_col6, #T_5fb6e_row0_col7, #T_5fb6e_row0_col8, #T_5fb6e_row0_col10, #T_5fb6e_row0_col11, #T_5fb6e_row0_col12, #T_5fb6e_row0_col13, #T_5fb6e_row0_col14, #T_5fb6e_row1_col3, #T_5fb6e_row1_col4, #T_5fb6e_row1_col5, #T_5fb6e_row1_col6, #T_5fb6e_row1_col8, #T_5fb6e_row1_col9, #T_5fb6e_row1_col11, #T_5fb6e_row1_col12, #T_5fb6e_row1_col14 {
#   background-color: #77dd77;
# }
# #T_5fb6e_row0_col5, #T_5fb6e_row0_col9, #T_5fb6e_row1_col7, #T_5fb6e_row1_col10, #T_5fb6e_row1_col13 {
#   background-color: #FFB347;
# }
# </style>
# <table id="T_5fb6e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5fb6e_level0_col0" class="col_heading level0 col0" >dataset</th>
#       <th id="T_5fb6e_level0_col1" class="col_heading level0 col1" >model</th>
#       <th id="T_5fb6e_level0_col2" class="col_heading level0 col2" >case</th>
#       <th id="T_5fb6e_level0_col3" class="col_heading level0 col3" >domain_cov</th>
#       <th id="T_5fb6e_level0_col4" class="col_heading level0 col4" >stats_cov</th>
#       <th id="T_5fb6e_level0_col5" class="col_heading level0 col5" >outliers_cov</th>
#       <th id="T_5fb6e_level0_col6" class="col_heading level0 col6" >missing_cov</th>
#       <th id="T_5fb6e_level0_col7" class="col_heading level0 col7" >ks_sim</th>
#       <th id="T_5fb6e_level0_col8" class="col_heading level0 col8" >tv_sim</th>
#       <th id="T_5fb6e_level0_col9" class="col_heading level0 col9" >corr_sim</th>
#       <th id="T_5fb6e_level0_col10" class="col_heading level0 col10" >contin_sim</th>
#       <th id="T_5fb6e_level0_col11" class="col_heading level0 col11" >sdv_quality_report</th>
#       <th id="T_5fb6e_level0_col12" class="col_heading level0 col12" >wass_dist</th>
#       <th id="T_5fb6e_level0_col13" class="col_heading level0 col13" >js_dist</th>
#       <th id="T_5fb6e_level0_col14" class="col_heading level0 col14" >new_row_synthesis</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5fb6e_level0_row0" class="row_heading level0 row0" >93</th>
#       <td id="T_5fb6e_row0_col0" class="data row0 col0" >loan</td>
#       <td id="T_5fb6e_row0_col1" class="data row0 col1" >ddpm_syn</td>
#       <td id="T_5fb6e_row0_col2" class="data row0 col2" >tabular</td>
#       <td id="T_5fb6e_row0_col3" class="data row0 col3" >1.000000</td>
#       <td id="T_5fb6e_row0_col4" class="data row0 col4" >0.940000</td>
#       <td id="T_5fb6e_row0_col5" class="data row0 col5" >0.440000</td>
#       <td id="T_5fb6e_row0_col6" class="data row0 col6" >1.000000</td>
#       <td id="T_5fb6e_row0_col7" class="data row0 col7" >0.960000</td>
#       <td id="T_5fb6e_row0_col8" class="data row0 col8" >0.970000</td>
#       <td id="T_5fb6e_row0_col9" class="data row0 col9" >0.960000</td>
#       <td id="T_5fb6e_row0_col10" class="data row0 col10" >0.890000</td>
#       <td id="T_5fb6e_row0_col11" class="data row0 col11" >0.930000</td>
#       <td id="T_5fb6e_row0_col12" class="data row0 col12" >0.030000</td>
#       <td id="T_5fb6e_row0_col13" class="data row0 col13" >0.090000</td>
#       <td id="T_5fb6e_row0_col14" class="data row0 col14" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5fb6e_level0_row1" class="row_heading level0 row1" >119</th>
#       <td id="T_5fb6e_row1_col0" class="data row1 col0" >loan</td>
#       <td id="T_5fb6e_row1_col1" class="data row1 col1" >ddpm_syn</td>
#       <td id="T_5fb6e_row1_col2" class="data row1 col2" >hpo</td>
#       <td id="T_5fb6e_row1_col3" class="data row1 col3" >1.000000</td>
#       <td id="T_5fb6e_row1_col4" class="data row1 col4" >0.940000</td>
#       <td id="T_5fb6e_row1_col5" class="data row1 col5" >0.450000</td>
#       <td id="T_5fb6e_row1_col6" class="data row1 col6" >1.000000</td>
#       <td id="T_5fb6e_row1_col7" class="data row1 col7" >0.950000</td>
#       <td id="T_5fb6e_row1_col8" class="data row1 col8" >0.970000</td>
#       <td id="T_5fb6e_row1_col9" class="data row1 col9" >0.980000</td>
#       <td id="T
row0_col14" class="data row0 col14" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_05053_level0_row1" class="row_heading level0 row1" >113</th>
#       <td id="T_05053_row1_col0" class="data row1 col0" >adult</td>
#       <td id="T_05053_row1_col1" class="data row1 col1" >arf_syn</td>
#       <td id="T_05053_row1_col2" class="data row1 col2" >hpo</td>
#       <td id="T_05053_row1_col3" class="data row1 col3" >0.980000</td>
#       <td id="T_05053_row1_col4" class="data row1 col4" >1.000000</td>
#       <td id="T_05053_row1_col5" class="data row1 col5" >0.810000</td>
#       <td id="T_05053_row1_col6" class="data row1 col6" >1.000000</td>
#       <td id="T_05053_row1_col7" class="data row1 col7" >0.900000</td>
#       <td id="T_05053_row1_col8" class="data row1 col8" >0.920000</td>
#       <td id="T_05053_row1_col9" class="data row1 col9" >0.990000</td>
#       <td id="T_05053_row1_col10" class="data row1 col10" >0.870000</td>
#       <td id="T_05053_row1_col11" class="data row1 col11" >0.900000</td>
#       <td id="T_05053_row1_col12" class="data row1 col12" >0.010000</td>
#       <td id="T_05053_row1_col13" class="data row1 col13" >0.160000</td>
#       <td id="T_05053_row1_col14" class="data row1 col14" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### rtvae | loan & adult

# %%
subset = all_df[(all_df["model"] == "rtvae_syn") & (all_df["dataset"] == "loan")]
df_style = subset.style.apply(lambda s: highlight_top3_min3(s, skip_cols=skip_cols, min_cols=min_cols))
df_style
# Out:
# <style type="text/css">
# #T_a19ee_row0_col3, #T_a19ee_row0_col7, #T_a19ee_row0_col8, #T_a19ee_row0_col11, #T_a19ee_row0_col13, #T_a19ee_row1_col5, #T_a19ee_row1_col9 {
#   background-color: #FFB347;
# }
# #T_a19ee_row0_col4, #T_a19ee_row0_col5, #T_a19ee_row0_col6, #T_a19ee_row0_col9, #T_a19ee_row0_col10, #T_a19ee_row0_col12, #T_a19ee_row0_col14, #T_a19ee_row1_col3, #T_a19ee_row1_col4, #T_a19ee_row1_col6, #T_a19ee_row1_col7, #T_a19ee_row1_col8, #T_a19ee_row1_col10, #T_a19ee_row1_col11, #T_a19ee_row1_col12, #T_a19ee_row1_col13, #T_a19ee_row1_col14 {
#   background-color: #77dd77;
# }
# </style>
# <table id="T_a19ee">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a19ee_level0_col0" class="col_heading level0 col0" >dataset</th>
#       <th id="T_a19ee_level0_col1" class="col_heading level0 col1" >model</th>
#       <th id="T_a19ee_level0_col2" class="col_heading level0 col2" >case</th>
#       <th id="T_a19ee_level0_col3" class="col_heading level0 col3" >domain_cov</th>
#       <th id="T_a19ee_level0_col4" class="col_heading level0 col4" >stats_cov</th>
#       <th id="T_a19ee_level0_col5" class="col_heading level0 col5" >outliers_cov</th>
#       <th id="T_a19ee_level0_col6" class="col_heading level0 col6" >missing_cov</th>
#       <th id="T_a19ee_level0_col7" class="col_heading level0 col7" >ks_sim</th>
#       <th id="T_a19ee_level0_col8" class="col_heading level0 col8" >tv_sim</th>
#       <th id="T_a19ee_level0_col9" class="col_heading level0 col9" >corr_sim</th>
#       <th id="T_a19ee_level0_col10" class="col_heading level0 col10" >contin_sim</th>
#       <th id="T_a19ee_level0_col11" class="col_heading level0 col11" >sdv_quality_report</th>
#       <th id="T_a19ee_level0_col12" class="col_heading level0 col12" >wass_dist</th>
#       <th id="T_a19ee_level0_col13" class="col_heading level0 col13" >js_dist</th>
#       <th id="T_a19ee_level0_col14" class="col_heading level0 col14" >new_row_synthesis</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a19ee_level0_row0" class="row_heading level0 row0" >95</th>
#       <td id="T_a19ee_row0_col0" class="data row0 col0" >loan</td>
#       <td id="T_a19ee_row0_col1" class="data row0 col1" >rtvae_syn</td>
#       <td id="T_a19ee_row0_col2" class="data row0 col2" >tabular</td>
#       <td id="T_a19ee_row0_col3" class="data row0 col3" >0.860000</td>
#       <td id="T_a19ee_row0_col4" class="data row0 col4" >0.970000</td>
#       <td id="T_a19ee_row0_col5" class="data row0 col5" >0.400000</td>
#       <td id="T_a19ee_row0_col6" class="data row0 col6" >1.000000</td>
#       <td id="T_a19ee_row0_col7" class="data row0 col7" >0.850000</td>
#       <td id="T_a19ee_row0_col8" class="data row0 col8" >0.960000</td>
#       <td id="T_a19ee_row0_col9" class="data row0 col9" >0.950000</td>
#       <td id="T_a19ee_row0_col10" class="data row0 col10" >0.810000</td>
#       <td id="T_a19ee_row0_col11" class="data row0 col11" >0.870000</td>
#       <td id="T_a19ee_row0_col12" class="data row0 col12" >0.040000</td>
#       <td id="T_a19ee_row0_col13" class="data row0 col13" >0.480000</td>
#       <td id="T_a19ee_row0_col14" class="data row0 col14" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a19ee_level0_row1" class="row_heading level0 row1" >120</th>
#       <td id="T_a19ee_row1_col0" class="data row1 col0" >loan</td>
#       <td id="T_a19ee_row1_col1" class="data row1 col1" >rtvae_syn</td>
#       <td id="T_a19ee_row1_col2" class="data row1 col2" >hpo</td>
#       <td id="T_a19ee_row1_col3" class="data row1 col3" >0.870000</td>
#       <td id="T_a19ee_row1_col4" class="data row1 col4" >0.970000</td>
#       <td id="T_a19ee_row1_col5" class="data row1 col5" >0.350000</td>
#       <td id="T_a19ee_row1_col6" class="data row1 col6" >1.000000</td>
#       <td id="T
row1_col14" class="data row1 col14" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### tvae | loan & adult

# %%
subset = all_df[(all_df["model"] == "tvae_syn") & (all_df["dataset"] == "loan")]
df_style = subset.style.apply(lambda s: highlight_top3_min3(s, skip_cols=skip_cols, min_cols=min_cols))
df_style
# Out:
# <style type="text/css">
# #T_6a083_row0_col3, #T_6a083_row0_col4, #T_6a083_row0_col7, #T_6a083_row0_col8, #T_6a083_row0_col10, #T_6a083_row0_col11, #T_6a083_row0_col12, #T_6a083_row0_col13, #T_6a083_row1_col5 {
#   background-color: #FFB347;
# }
# #T_6a083_row0_col5, #T_6a083_row0_col6, #T_6a083_row0_col9, #T_6a083_row0_col14, #T_6a083_row1_col3, #T_6a083_row1_col4, #T_6a083_row1_col6, #T_6a083_row1_col7, #T_6a083_row1_col8, #T_6a083_row1_col9, #T_6a083_row1_col10, #T_6a083_row1_col11, #T_6a083_row1_col12, #T_6a083_row1_col13, #T_6a083_row1_col14 {
#   background-color: #77dd77;
# }
# </style>
# <table id="T_6a083">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6a083_level0_col0" class="col_heading level0 col0" >dataset</th>
#       <th id="T_6a083_level0_col1" class="col_heading level0 col1" >model</th>
#       <th id="T_6a083_level0_col2" class="col_heading level0 col2" >case</th>
#       <th id="T_6a083_level0_col3" class="col_heading level0 col3" >domain_cov</th>
#       <th id="T_6a083_level0_col4" class="col_heading level0 col4" >stats_cov</th>
#       <th id="T_6a083_level0_col5" class="col_heading level0 col5" >outliers_cov</th>
#       <th id="T_6a083_level0_col6" class="col_heading level0 col6" >missing_cov</th>
#       <th id="T_6a083_level0_col7" class="col_heading level0 col7" >ks_sim</th>
#       <th id="T_6a083_level0_col8" class="col_heading level0 col8" >tv_sim</th>
#       <th id="T_6a083_level0_col9" class="col_heading level0 col9" >corr_sim</th>
#       <th id="T_6a083_level0_col10" class="col_heading level0 col10" >contin_sim</th>
#       <th id="T_6a083_level0_col11" class="col_heading level0 col11" >sdv_quality_report</th>
#       <th id="T_6a083_level0_col12" class="col_heading level0 col12" >wass_dist</th>
#       <th id="T_6a083_level0_col13" class="col_heading level0 col13" >js_dist</th>
#       <th id="T_6a083_level0_col14" class="col_heading level0 col14" >new_row_synthesis</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6a083_level0_row0" class="row_heading level0 row0" >90</th>
#       <td id="T_6a083_row0_col0" class="data row0 col0" >loan</td>
#       <td id="T_6a083_row0_col1" class="data row0 col1" >tvae_syn</td>
#       <td id="T_6a083_row0_col2" class="data row0 col2" >tabular</td>
#       <td id="T_6a083_row0_col3" class="data row0 col3" >0.930000</td>
#       <td id="T_6a083_row0_col4" class="data row0 col4" >0.970000</td>
#       <td id="T_6a083_row0_col5" class="data row0 col5" >0.360000</td>
#       <td id="T_6a083_row0_col6" class="data row0 col6" >1.000000</td>
#       <td id="T_6a083_row0_col7" class="data row0 col7" >0.880000</td>
#       <td id="T_6a083_row0_col8" class="data row0 col8" >0.970000</td>
#       <td id="T_6a083_row0_col9" class="data row0 col9" >0.960000</td>
#       <td id="T_6a083_row0_col10" class="data row0 col10" >0.890000</td>
#       <td id="T_6a083_row0_col11" class="data row0 col11" >0.920000</td>
#       <td id="T_6a083_row0_col12" class="data row0 col12" >0.040000</td>
#       <td id="T_6a083_row0_col13" class="data row0 col13" >0.270000</td>
#       <td id="T_6a083_row0_col14" class="data row0 col14" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6a083_level0_row1" class="row_heading level0 row1" >117</th>
#       <td id="T_6a083_row1_col0" class="data row1 col0" >loan</td>
#       <td id="T_6a083_row1_col1" class="data row1 col1" >tvae_syn</td>
#       <td id="T_6a083_row1_col2" class="data row1 col2" >hpo</td>
#       <td id="T_6a083_row1_col3" class="data row1 col3" >0.950000</td>
#       <td id="T_6a083_row1_col4" class="data row1 col4" >0.980000</td>
#       <td id="T_6a083_row1_col5" class="data row1 col5" >0.350000</td>
#       <td id="T_6a083_row1_col6" class="data row1 col6" >1.000000</td>
#       <td id="T_6a083_row1_col7" class="data row1 col7" >0.930000</td>
#       <td id="T_6a083_row1_col8" class="data row1 col8" >0.980000</td>
#       <td id="T_6a083_row1_col9" class="data row1 col9" >0.960000</td>
#       <td id="T_6a083_row1_col10" class="data row1 col10" >0.920000</td>
#       <td id="T_6a083_row1_col11" class="data row1 col11" >0.940000</td>
#       <td id="T_6a083_row1_col12" class="data row1 col12" >0.020000</td>
#       <td id="T_6a083_row1_col13" class="data row1 col13" >0.190000</td>
#       <td id="T_6a083_row1_col14" class="data row1 col14" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
subset = all_df[(all_df["model"] == "tvae_syn") & (all_df["dataset"] == "adult")]
df_style = subset.style.apply(lambda s: highlight_top3_min3(s, skip_cols=skip_cols, min_cols=min_cols))
df_style
# Out:
# <style type="text/css">
# #T_99dbc_row0_col3, #T_99dbc_row0_col7, #T_99dbc_row0_col11, #T_99dbc_row0_col13, #T_99dbc_row1_col5, #T_99dbc_row1_col8, #T_99dbc_row1_col10 {
#   background-color: #FFB347;
# }
# #T_99dbc_row0_col4, #T_99dbc_row0_col5, #T_99dbc_row0_col6, #T_99dbc_row0_col8, #T_99dbc_row0_col9, #T_99dbc_row0_col10, #T_99dbc_row0_col12, #T_99dbc_row0_col14, #T_99dbc_row1_col3, #T_99dbc_row1_col4, #T_99dbc_row1_col6, #T_99dbc_row1_col7, #T_99dbc_row1_col9, #T_99dbc_row1_col11, #T_99dbc_row1_col12, #T_99dbc_row1_col13, #T_99dbc_row1_col14 {
#   background-color: #77dd77;
# }
# </style>
# <table id="T_99dbc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_99dbc_level0_col0" class="col_heading level0 col0" >dataset</th>
#       <th id="T_99dbc_level0_col1" class="col_heading level0 col1" >model</th>
#       <th id="T_99dbc_level0_col2" class="col_heading level0 col2" >case</th>
#       <th id="T_99dbc_level0_col3" class="col_heading level0 col3" >domain_cov</th>
#       <th id="T_99dbc_level0_col4" class="col_heading level0 col4" >stats_cov</th>
#       <th id="T_99dbc_level0_col5" class="col_heading level0 col5" >outliers_cov</th>
#       <th id="T_99dbc_level0_col6" class="col_heading level0 col6" >missing_cov</th>
#       <th id="T_99dbc_level0_col7" class="col_heading level0 col7" >ks_sim</th>
#       <th id="T_99dbc_level0_col8" class="col_heading level0 col8" >tv_sim</th>
#       <th id="T_99dbc_level0_col9" class="col_heading level0 col9" >corr_sim</th>
#       <th id="T_99dbc_level0_col10" class="col_heading level0 col10" >contin_sim</th>
#       <th id="T_99dbc_level0_col11" class="col_heading level0 col11" >sdv_quality_report</th>
#       <th id="T_99dbc_level0_col12" class="col_heading level0 col12" >wass_dist</th>
#       <th id="T_99dbc_level0_col13" class="col_heading level0 col13" >js_dist</th>
#       <th id="T_99dbc_level0_col14" class="col_heading level0 col14" >new_row_synthesis</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_99dbc_level0_row0" class="row_heading level0 row0" >5</th>
#       <td id="T_99dbc_row0_col0" class="data row0 col0" >adult</td>
#       <td id="T_99dbc_row0_col1" class="data row0 col1" >tvae_syn</td>
#       <td id="T_99dbc_row0_col2" class="data row0 col2" >tabular</td>
#       <td id="T_99dbc_row0_col3" class="data row0 col3" >0.860000</td>
#       <td id="T_99dbc_row0_col4" class="data row0 col4" >0.990000</td>
#       <td id="T_99dbc_row0_col5" class="data row0 col5" >0.650000</td>
#       <td id="T_99dbc_row0_col6" class="data row0 col6" >1.000000</td>
#       <td id="T_99dbc_row0_col7" class="data row0 col7" >0.810000</td>
#       <td id="T_99dbc_row0_col8" class="data row0 col8" >0.890000</td>
#       <td id="T_99dbc_row0_col9" class="data row0 col9" >0.990000</td>
#       <td id="T_99dbc_row0_col10" class="data row0 col10" >0.810000</td>
#       <td id="T_99dbc_row0_col11" class="data row0 col11" >0.840000</td>
#       <td id="T_99dbc_row0_col12" class="data row0 col12" >0.010000</td>
#       <td id="T_99dbc_row0_col13" class="data row0 col13" >0.300000</td>
#       <td id="T_99dbc_row0_col14" class="data row0 col14" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_99dbc_level0_row1" class="row_heading level0 row1" >112</th>
#       <td id="T_99dbc_row1_col0" class="data row1 col0" >adult</td>
#       <td id="T_99dbc_row1_col1" class="data row1 col1" >tvae_syn</td>
#       <td id="T_99dbc_row1_col2" class="data row1 col2" >hpo</td>
#       <td id="T_99dbc_row1_col3" class="data row1 col3" >0.920000</td>
#       <td id="T_99dbc_row1_col4" class="data row1 col4" >0.990000</td>
#       <td id="T_99dbc_row1_col5" class="data row1 col5" >0.570000</td>
#       <td id="T_99dbc_row1_col6" class="data row1 col6" >1.000000</td>
#       <td id="T_99dbc_row1_col7" class="data row1 col7" >0.900000</td>
#       <td id="T_99dbc_row1_col8" class="data row1 col8" >0.850000</td>
#       <td id="T_99dbc_row1_col9" class="data row1 col9" >0.990000</td>
#       <td id="T_99dbc_row1_col10" class="data row1 col10" >0.800000</td>
#       <td id="T_99dbc_row1_col11" class="data row1 col11" >0.850000</td>
#       <td id="T_99dbc_row1_col12" class="data row1 col12" >0.010000</td>
#       <td id="T_99dbc_row1_col13" class="data row1 col13" >0.190000</td>
#       <td id="T_99dbc_row1_col14" class="data row1 col14" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Hyperimpute benchmarking

# %%
## TODO: Need to run on TAXI -- mostly numerical missing values

# %%
# subset = all_df[(all_df["model"] == "ctgan_sdv") & (all_df["dataset"] == "drugs")]

subset = all_df[(all_df["dataset"] == "drugs") & (all_df['case'].str.contains('only_'))]

df_style = subset.style.apply(lambda s: highlight_top3_min3(s, skip_cols=skip_cols, min_cols=min_cols))
df_style
# Out:
# <style type="text/css">
# #T_8773d_row0_col3 {
#   background-color: #fdfd96;
# }
# #T_8773d_row0_col4, #T_8773d_row0_col5, #T_8773d_row0_col6, #T_8773d_row0_col7, #T_8773d_row0_col9, #T_8773d_row0_col10, #T_8773d_row0_col12, #T_8773d_row0_col13, #T_8773d_row0_col14, #T_8773d_row1_col3, #T_8773d_row1_col4, #T_8773d_row1_col5, #T_8773d_row1_col6, #T_8773d_row1_col7, #T_8773d_row1_col8, #T_8773d_row1_col9, #T_8773d_row1_col10, #T_8773d_row1_col11, #T_8773d_row1_col12, #T_8773d_row1_col13, #T_8773d_row1_col14, #T_8773d_row2_col4, #T_8773d_row2_col5, #T_8773d_row2_col6, #T_8773d_row2_col7, #T_8773d_row2_col8, #T_8773d_row2_col9, #T_8773d_row2_col10, #T_8773d_row2_col11, #T_8773d_row2_col12, #T_8773d_row2_col13, #T_8773d_row2_col14, #T_8773d_row3_col4, #T_8773d_row3_col5, #T_8773d_row3_col6, #T_8773d_row3_col7, #T_8773d_row3_col8, #T_8773d_row3_col9, #T_8773d_row3_col10, #T_8773d_row3_col11, #T_8773d_row3_col12, #T_8773d_row3_col13, #T_8773d_row3_col14 {
row3_col5" class="data row3 col5" >1.000000</td>
#       <td id="T_3ba91_row3_col6" class="data row3 col6" >0.420000</td>
#       <td id="T_3ba91_row3_col7" class="data row3 col7" >0.850000</td>
#       <td id="T_3ba91_row3_col8" class="data row3 col8" >0.900000</td>
#       <td id="T_3ba91_row3_col9" class="data row3 col9" >0.960000</td>
#       <td id="T_3ba91_row3_col10" class="data row3 col10" >0.170000</td>
#       <td id="T_3ba91_row3_col11" class="data row3 col11" >0.530000</td>
#       <td id="T_3ba91_row3_col12" class="data row3 col12" >0.120000</td>
#       <td id="T_3ba91_row3_col13" class="data row3 col13" >0.270000</td>
#       <td id="T_3ba91_row3_col14" class="data row3 col14" >-99.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3ba91_level0_row4" class="row_heading level0 row4" >109</th>
#       <td id="T_3ba91_row4_col0" class="data row4 col0" >drugs</td>
#       <td id="T_3ba91_row4_col1" class="data row4 col1" >ctgan_sdv</td>
#       <td id="T_3ba91_row4_col2" class="data row4 col2" >simple</td>
#       <td id="T_3ba91_row4_col3" class="data row4 col3" >0.900000</td>
#       <td id="T_3ba91_row4_col4" class="data row4 col4" >0.980000</td>
#       <td id="T_3ba91_row4_col5" class="data row4 col5" >0.000000</td>
#       <td id="T_3ba91_row4_col6" class="data row4 col6" >0.420000</td>
#       <td id="T_3ba91_row4_col7" class="data row4 col7" >0.940000</td>
#       <td id="T_3ba91_row4_col8" class="data row4 col8" >0.890000</td>
#       <td id="T_3ba91_row4_col9" class="data row4 col9" >0.960000</td>
#       <td id="T_3ba91_

# %% [markdown]
# # Models Benchmarking

# %%
# ALL_TABULAR_DATASETS = ["adult", "census", "child", "covtype", "credit", "insurance", "health_insurance", 
#                        "intrusion", "drugs", "loan", "pums"]

# %%
subset = all_df[(all_df["dataset"] == "adult") & (all_df["case"] == "tabular")]
df_style = subset.style.apply(lambda s: highlight_top3_min3(s, skip_cols=skip_cols, min_cols=min_cols))
df_style
# Out:
# <style type="text/css">
# #T_2312d_row0_col4, #T_2312d_row0_col12, #T_2312d_row1_col4, #T_2312d_row1_col9, #T_2312d_row1_col12, #T_2312d_row2_col4, #T_2312d_row2_col10, #T_2312d_row2_col11, #T_2312d_row2_col12, #T_2312d_row4_col4, #T_2312d_row4_col9, #T_2312d_row4_col12, #T_2312d_row5_col4, #T_2312d_row7_col5, #T_2312d_row8_col9, #T_2312d_row9_col3, #T_2312d_row9_col12, #T_2312d_row10_col9, #T_2312d_row10_col12, #T_2312d_row11_col9, #T_2312d_row11_col14, #T_2312d_row12_col4, #T_2312d_row12_col7, #T_2312d_row12_col8, #T_2312d_row12_col9, #T_2312d_row12_col13, #T_2312d_row13_col3, #T_2312d_row13_col4, #T_2312d_row13_col9, #T_2312d_row13_col12 {
#   background-color: #FFB347;
# }
# #T_2312d_row0_col6, #T_2312d_row0_col14, #T_2312d_row1_col6, #T_2312d_row1_col14, #T_2312d_row2_col6, #T_2312d_row2_col14, #T_2312d_row3_col6, #T_2312d_row3_col9, #T_2312d_row3_col14, #T_2312d_row4_col6, #T_2312d_row4_col14, #T_2312d_row5_col6, #T_2312d_row5_col9, #T_2312d_row5_col12, #T_2312d_row5_col14, #T_2312d_row6_col6, #T_2312d_row6_col14, #T_2312d_row7_col3, #T_2312d_row7_col4, #T_2312d_row7_col6, #T_2312d_row7_col9, #T_2312d_row7_col12, #T_2312d_row7_col14, #T_2312d_row8_col3, #T_2312d_row8_col4, #T_2312d_row8_col6, #T_2312d_row8_col7, #T_2312d_row8_col8, #T_2312d_row8_col10
row1_col14" class="data row1 col14" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d5327_level0_row2" class="row_heading level0 row2" >87</th>
#       <td id="T_d5327_row2_col0" class="data row2 col0" >loan</td>
#       <td id="T_d5327_row2_col1" class="data row2 col1" >tvae_sdv</td>
#       <td id="T_d5327_row2_col2" class="data row2 col2" >tabular</td>
#       <td id="T_d5327_row2_col3" class="data row2 col3" >0.910000</td>
#       <td id="T_d5327_row2_col4" class="data row2 col4" >0.950000</td>
#       <td id="T_d5327_row2_col5" class="data row2 col5" >0.200000</td>
#       <td id="T_d5327_row2_col6" class="data row2 col6" >1.000000</td>
#       <td id="T_d5327_row2_col7" class="data row2 col7" >0.820000</td>
#       <td id="T_d5327_row2_col8" class="data row2 col8" >0.850000</td>
#       <td id="T_d5327_row2_col9" class="data row2 col9" >0.960000</td>
#       <td id="T_d5327_row2_col10" class="data row2 col10" >0.790000</td>
#       <td id="T_d5327_row2_col11" class="data row2 col11" >0.830000</td>
#       <td id="T_d5327_row2_col12" class="data row2 col12" >0.070000</td>
#       <td id="T_d5327_row2_col13" class="data row2 col13" >0.250000</td>
#       <td id="T_d5327_row2_col14" class="data row2 col14" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d5327_level0_row3" class="row_heading level0 row3" >88</th>
#       <td id="T_d5327_row3_col0" class="data row3 col0" >loan</td>
#       <td id="T_d5327_row3_col1" class="data row3 col1" >gaussian_copula_sdv</td>
#       <td id="T_d5327_row3_col2" class="data row3 col2" >tabular</td>
#       <td id="T_d5327_row3_col3" class="data row3 col3" >0.940000</td>
#       <td id="T_d5327_row3_col4" class="data row3 col4" >0.980000</td>
#       <td id="T_d5327_row3_col5" class="data row3 col5" >0.390000</td>
#       <td id="T_d5327_row3_col6" class="data row3 col6" >1.000000</td>
#       <td id="T_d5327_row3_col7" class="data row3 col7" >0.890000</td>
#       <td id="T_d5327_row3_col8" class="data row3 col8" >0.970000</td>
#       <td id="T_d5327_row3_col9" class="data row3 col9" >0.970000</td>
#       <td id="T_d5327_row3_col10" class="data row3 col10" >0.910000</td>
#       <td id="T_d5327_row3_col11" class="data row3 col11" >0.930000</td>
#       <td id="T_d5327_row3_col12" class="data row3 col12" >0.030000</td>
#       <td id="T_d5327_row3_col13" class="data row3 col13" >0.190000</td>
#       <td id="T_d5327_row3_col14" class

# %%
subset = all_df[(all_df["dataset"] == "health_insurance") & (all_df["case"] == "tabular")]
df_style = subset.style.apply(lambda s: highlight_top3_min3(s, skip_cols=skip_cols, min_cols=min_cols))
df_style
# Out:
# <style type="text/css">
# #T_34eeb_row0_col3, #T_34eeb_row0_col6, #T_34eeb_row0_col14, #T_34eeb_row1_col6, #T_34eeb_row1_col14, #T_34eeb_row2_col5, #T_34eeb_row2_col6, #T_34eeb_row2_col9, #T_34eeb_row2_col14, #T_34eeb_row3_col6, #T_34eeb_row3_col14, #T_34eeb_row4_col6, #T_34eeb_row4_col9, #T_34eeb_row4_col14, #T_34eeb_row5_col4, #T_34eeb_row5_col6, #T_34eeb_row5_col8, #T_34eeb_row5_col14, #T_34eeb_row6_col6, #T_34eeb_row6_col14, #T_34eeb_row7_col3, #T_34eeb_row7_col6, #T_34eeb_row7_col7, #T_34eeb_row7_col10, #T_34eeb_row7_col11, #T_34eeb_row7_col13, #T_34eeb_row8_col3, #T_34eeb_row8_col5, #T_34eeb_row8_col6, #T_34eeb_row8_col14, #T_34eeb_row9_col4, #T_34eeb_row9_col6, #T_34eeb_row9_col7, #T_34eeb_row9_col12, #T_34eeb_row9_col14, #T_34eeb_row10_col6, #T_34eeb_row10_col8, #T_34eeb_row10_col14, #T_34eeb_row11_col6, #T_34eeb_row11_col14, #T_34eeb_row12_col5, #T_34eeb_row12_col6, #T_34eeb_row12_col14 {
#   background-color: #77dd77;
row2_col2" class="data row2 col2" >tabular</td>
#       <td id="T_34eeb_row2_col3" class="data row2 col3" >0.910000</td>
#       <td id="T_34eeb_row2_col4" class="data row2 col4" >0.950000</td>
#       <td id="T_34eeb_row2_col5" class="data row2 col5" >0.670000</td>
#       <td id="T_34eeb_row2_col6" class="data row2 col6" >1.000000</td>
#       <td id="T_34eeb_row2_col7" class="data row2 col7" >0.810000</td>
#       <td id="T_34eeb_row2_col8" class="data row2 col8" >0.820000</td>
#       <td id="T_34eeb_row2_col9" class="data row2 col9" >0.980000</td>
#       <td id="T_34eeb_row2_col10" class="data row2 col10" >0.740000</td>
#       <td id="T_34eeb_row2_col11" class="data row2 col11" >0.800000</td>
#       <td id="T_34eeb_row2_col12" class="data row2 col12" >0.070000</td>
#       <td id="T_34eeb_row2_col13" class="data row2 col13" >0.200000</td>
#       <td id="T_34eeb_row2_col14" class="data row2 col14" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_34eeb_level0_row3" class="row_heading level0 row3" >57</th>
#       <td id="T_34eeb_row3_col0" class="data row3 col0" >health_insurance</td>
#       <td id="T_34eeb_row3_col1" class="data row3 col1" >gaussian_copula_sdv</td>
#       <td id="T_34eeb_row3_col2" class="data row3 col2" >tabular</td>
#       <td id="T_34eeb_row3_col3" class="data row3 col3" >0.930000</td>
#       <td id="T_34eeb_row3_col4" class="data row3 col4" >0.950000</td>
#       <td id="T_34eeb_row3_col5" class="data row3 col5" >0.110000</td>
#       <td id="T_34eeb_row3_col6" class="data row3 col6" >1.000000</td>
#       <td id="T_34eeb_row3_col7" class="data row3 col7" >0.850000</td>
#       <td id="T_34eeb_row3_col8" class="data row3 col8" >0.870000</td>
#       <td id="T_34eeb_row3_col9" class="data row3 col9" >0.940000</td>
#       <td id="T_34eeb_row3_col10" class="data row3 col10" >0.800000</td>
#       <td id="T_34eeb_row3_col11" class="data row3 col11" >0.840000</td>
#       <td id="T_34eeb_row3_col12" class="data row3 col12" >0.070000</td>
#       <td id="T_34eeb_row3_col13" class="data row3 col13" >0.180000</td>
#       <td id="T_34eeb_row3_col14" class="data row3 col14" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_34eeb_level0_row4" class="row_heading level0 row4" >58</th>
#       <td id="T_34eeb_row4_col0" class="data row4 col0" >health_insurance</td>
#       <td id="T_34eeb_row4_col1" class="data row4 col1" >ctgan_syn</td>
#       <td id="T_34eeb_row4_col2" class="data row4

# %%
subset = all_df[(all_df["dataset"] == "drugs") & (all_df["case"] == "tabular")]
df_style = subset.style.apply(lambda s: highlight_top3_min3(s, skip_cols=skip_cols, min_cols=min_cols))
df_style
# Out:
# <style type="text/css">
# #T_40bde_row0_col3, #T_40bde_row0_col6, #T_40bde_row0_col8, #T_40bde_row0_col14, #T_40bde_row1_col5, #T_40bde_row1_col6, #T_40bde_row1_col8, #T_40bde_row1_col10, #T_40bde_row1_col11, #T_40bde_row1_col14, #T_40bde_row2_col6, #T_40bde_row2_col9, #T_40bde_row2_col14, #T_40bde_row3_col4, #T_40bde_row3_col14, #T_40bde_row4_col12, #T_40bde_row4_col13, #T_40bde_row4_col14, #T_40bde_row5_col12, #T_40bde_row5_col13, #T_40bde_row5_col14, #T_40bde_row6_col12, #T_40bde_row6_col13, #T_40bde_row6_col14, #T_40bde_row7_col12, #T_40bde_row7_col13, #T_40bde_row7_col14, #T_40bde_row8_col7, #T_40bde_row8_col12, #T_40bde_row8_col13, #T_40bde_row8_col14, #T_40bde_row9_col12, #T_40bde_row9_col13, #T_40bde_row9_col14, #T_40bde_row10_col12, #T_40bde_row10_col13, #T_40bde_row10_col14 {
#   background-color: #77dd77;
# }
# #T_40bde_row0_col4, #T_40bde_row0_col5, #T_40bde_row0_col10, #T_40bde_row0_col11, #T_40bde_row1_col3, #T_40bde_row1_col4, #T_40bde_row2_col5, #T_40bde_row3_col5, #T_40bde_row3_col6, #T_40bde_row3_col7, #T_40bde_row3_col9, #T_40bde_row3_col12, #T_40bde_row3_col13, #T_40bde_row8_col8 {
#   background-color: #FFB347;
# }
# #T_40bde_row0_col12, #T_40bde_row1_col13, #T_40bde_row2_col4, #T_40bde_row2_col10, #T_40bde_row2_col11, #T_40bde_row3_col3, #T_40bde_row3_col8, #T_40bde_row3_col11, #T_40bde_row4_col5, #T_40bde_row4_col6, #T_40bde_row5_col5, #T_40bde_row5_col6, #T_40bde_row6_col5, #T_40bde_row6_col6, #T_40bde_row7_col5, #T_40bde_row7_col6, #T_40bde_row7_col7, #T_40bde_row8_col5, #T_40bde_row8_col6, #T_40bde_row9_col5, #T_40bde_row9_col6, #T_40bde_row9_col9, #T_40bde_row10_col5, #T_40bde_row10_col6 {
#   background-color: #fdfd96;
# }
# </style>
# <table id="T_40bde">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_40bde_level0_col0" class="col_heading level0 col0" >dataset</th>
#       <th id="T_40bde_level0_col1" class="col_heading level0 col1" >model</th>
#       <th id="T_40bde_level0_col2" class="col_heading level0 col2" >case</th>
#       <th id="T_40bde_level0_col3" class="col_heading level0 col3" >domain_cov</th>
#       <th id="T_40bde_level0_col4" class="col_heading level0 col4" >stats_cov</th>
#       <th id="T_40bde_level0_col5" class="col_heading level0 col5" >outliers_cov</th>
#       <th id="T_40bde_level0_col6" class="col_heading level0 col6" >missing_cov</th>
#       <th id="T_40bde_level0_col7" class="col_heading level0 col7" >ks_sim</th>
#       <th id="T_40bde_level0_col8" class="col_heading level0 col8" >tv_sim</th>
#       <th id="T_40bde_level0_col9" class="col_heading level0 col9" >corr_sim</th>
#       <th id="T_40bde_level0_col10" class="col_heading level0 col10" >contin_sim</th>
#       <th id="T_40bde_level0_col11" class="col_heading level0 col11" >sdv_quality_report</th>
#       <th id="T_40bde_level0_col12" class="col_heading level0 col12" >wass_dist</th>
#       <th id="T_40bde_level0_col13" class="col_heading level0 col13" >js_dist</th>
#       <th id="T_40bde_level0_col14" class="col_heading level0 col14" >new_row_synthesis</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_40bde_level0_row0" class="row_heading level0 row0" >74</th>
#       <td id="T_40bde_row0_col0" class="data row0 col0" >drugs</td>
#       <td id="T_40bde_row0_col1" class="data row0 col1" >actgan_gretel</td>
#       <td id="T_40bde_row0_col2" class="data row0 col2" >tabular</td>
#       <td id="T_40bde_row0_col3" class="data row0 col3" >0.900000</td>
#       <td id="T_40bde_row0_col4" class="data row0 col4" >0.960000</td>
#       <td id="T_40bde_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_40bde_row0_col6" class="data row0 col6" >0.950000</td>
#       <td id="T_40bde_row0_col7" class="data row0 col7" >0.870000</td>
#       <td id="T_40bde_row0_col8" class="data row0 col8" >0.920000</td>
#       <td id="T_40bde_row0_col9" class="data row0 col9" >0.940000</td>
#       <td id="T_40bde_row0_col10" class="data row0 col10" >0.820000</td>
#       <td id="T_40bde_row0_col11" class="data row0 col11" >0.870000</td>
#       <td id="T_40bde_row0_col12" class="data row0 col12" >0.050000</td>
#       <td id="T_40bde_row0_col13" class="data row0 col13" >0.180000</td>
#       <td id="T_40bde_row0_col14" class="data row0 col14" >-99.000000</td>
#     </tr>
#     <tr>
#       <th id="T_40bde_level0_row1" class="row_heading level0 row1" >75</th>
#       <td id="T_40bde_row1_col0" class="data row1 col0" >drugs</td>
#       <td id="T_40bde_row1_col1" class="data row1 col1" >ctgan_sdv</td>
#       <td id="T_40bde_row1_col2" class="data row1 col2" >tabular</td>
#       <td id="T_40bde_row1_col3" class="data row1 col3" >0.890000</td>
#       <td id="T_40bde_row1_col4" class="data row1 col4" >0.960000</td>
#       <td id="T_40bde_row1_col5" class="data row1 col5" >1.000000</td>
#       <td id="T_40bde_row1_col6" class="data row1 col6" >0.950000</td>
#       <td id="T_40bde_row1_col7" class="data row1 col7" >0.890000</td>
#       <td id="T_40bde_row1_col8" class="data row1 col8" >0.920000</td>
#       <td id="T_40bde_row1_col9" class="data row1 col9" >0.950000</td>
#       <td id="T_40bde_row1_col10" class="data row1 col10" >0.830000</td>
#       <td id="T_40bde_row1_col11" class="data row1 col11" >0.880000</td>
#       <td id="T_40bde_row1_col12" class="data row1 col12" >0.060000</td>
#       <td id="T_40bde_row1_col13" class="data row1 col13" >0.140000</td>
#       <td id="T_40bde_row1_col14" class="data row1 col14" >-99.000000</td>
#     </tr>
#     <tr>
#       <th id="T_40bde_level0_row2" class="row_heading level0 row2" >76</th>
#       <td id="T_40bde_row2_col0" class="data row2 col0" >drugs</td>
#       <td id="T_40bde_row2_col1" class="data row2 col1" >tvae_sdv</td>
#       <td id="T_40bde_row2_col2" class="data row2 col2" >tabular</td>
#       <td id="T_40bde_row2_col3" class="data row2 col3" >0.770000</td>
#       <td id="T_40bde_row2_col4" class="data row2 col4" >0.930000</td>
#       <td id="T_40bde_row2_col5" class="data row2 col5" >0.000000</td>
#       <td id="T_40bde_row2_col6" class="data row2 col6" >0.950000</td>
#       <td id="T_40bde_row2_col7" class="data row2 col7" >0.830000</td>
#       <td id="T_40bde_row2_col8" class="data row2 col8" >nan</td>
#       <td id="T_40bde_row2_col9" class="data row2 col9" >0.990000</td>
#       <td id="T_40bde_row2_col10" class="data row2 col10" >0.760000</td>
#       <td id="T_40bde_row2_col11" class="data row2 col11" >0.800000</td>
#       <td id="T_40bde_row2_col12" class="data row2 col12" >0.060000</td>
#       <td id="T_40bde_row2_col13" class="data row2 col13" >0.180000</td>
#       <td id="T_40bde_row2_col14" class="data row2 col14" >-99.000000</td>
#     </tr>
#     <tr>
#       <th id="T_40bde_level0_row3" class="row_heading level0 row3" >77</th>
#       <td id="T_40bde_row3_col0" class="data row3 col0" >drugs</td>
#       <td id="T_40bde_row3_col1" class="data row3 col1" >gaussian_copula_sdv</td>
#       <td id="T_40bde_row3_col2" class="data row3 col2" >tabular</td>
#       <td id="T_40bde_row3_col3" class="data row3 col3" >0.870000</td>
#       <td id="T_40bde_row3_col4" class="data row3 col4" >1.000000</td>
#       <td id="T_40bde_row3_col5" class="data row3 col5" >0.000000</td>
#       <td id="T_40bde_row3_col6" class="data row3 col6" >0.920000</td>
#       <td id="T_40bde_row3_col7" class="data row3 col7" >0.920000</td>
#       <td id="T_40bde_row3_col8" class="data row3 col8" >0.880000</td>
#       <td id="T_40bde_row3_col9" class="data row3 col9" >0.970000</td>
#       <td id="T_40bde_row3_col10" class="data row3 col10" >0.730000</td>
#       <td id="T_40bde_row3_col11" class="data row3 col11" >0.800000</td>
#       <td id="T_40bde_row3_col12" class="data row3 col12" >0.010000</td>
#       <td id="T_40bde_row3_col13" class="data row3 col13" >0.080000</td>
#       <td id="T_40bde_row3_col14" class="data row3 col14" >-99.000000</td>
#     </tr>
#     <tr>
#       <th id="T_40bde_level0_row4" class="row_heading level0 row4" >78</th>
#       <td id="T_40bde_row4_col0" class="data row4 col0" >drugs</td>
#       <td id="T_40bde_row4_col1" class="data row4 col1" >ctgan_syn</td>
#       <td id="T_40bde_row4_col2" class="data ro

# %%
subset = all_df[(all_df["dataset"] == "intrusion") & (all_df["case"] == "tabular")]
df_style = subset.style.apply(lambda s: highlight_top3_min3(s, skip_cols=skip_cols, min_cols=min_cols))
df_style
# Out:
# <style type="text/css">
# #T_c9c69_row0_col6, #T_c9c69_row1_col6, #T_c9c69_row2_col4, #T_c9c69_row2_col6, #T_c9c69_row2_col7, #T_c9c69_row2_col8, #T_c9c69_row2_col11, #T_c9c69_row2_col12, #T_c9c69_row3_col6, #T_c9c69_row3_col14, #T_c9c69_row4_col6, #T_c9c69_row4_col9, #T_c9c69_row4_col10, #T_c9c69_row4_col11, #T_c9c69_row4_col12, #T_c9c69_row4_col14, #T_c9c69_row5_col6, #T_c9c69_row5_col12, #T_c9c69_row6_col3, #T_c9c69_row6_col5, #T_c9c69_row6_col6, #T_c9c69_row6_col9, #T_c9c69_row6_col13 {
#   background-color: #77dd77;
# }
# #T_c9c69_row0_col7, #T_c9c69_row2_col13, #T_c9c69_row4_col3, #T_c9c69_row4_col5, #T_c9c69_row4_col8, #T_c9c69_row5_col4, #T_c9c69_row5_col9, #T_c9c69_row5_col11, #T_c9c69_row5_col14, #T_c9c69_row6_col10, #T_c9c69_row6_col11, #T_c9c69_row6_col12 {
#   background-color: #FFB347;
# }
# #T_c9c69_row0_col9, #T_c9c69_row0_col11, #T_c9c69_row0_col12, #T_c9c69_row0_col14, #T_c9c69_row1_col14, #T_c9c69_row2_col10, #T_c9c69_row3_col5, #T_c9c69_row4_col13, #T_c9c69_row5_col3, #T_c9c69_row5_col7, #T_c9c69_row5_col8, #T_c9c69_row5_col10, #T_c9c69_row6_col4 {
#   background-color: #fdfd96;
# }
# </style>
# <table id="T
row3_col6" class="data row3 col6" >1.000000</td>
#       <td id="T_c9c69_row3_col7" class="data row3 col7" >0.590000</td>
#       <td id="T_c9c69_row3_col8" class="data row3 col8" >0.630000</td>
#       <td id="T_c9c69_row3_col9" class="data row3 col9" >0.950000</td>
#       <td id="T_c9c69_row3_col10" class="data row3 col10" >0.480000</td>
#       <td id="T_c9c69_row3_col11" class="data row3 col11" >0.560000</td>
#       <td id="T_c9c69_row3_col12" class="data row3 col12" >0.280000</td>
#       <td id="T_c9c69_row3_col13" class="data row3 col13" >0.390000</td>
#       <td id="T_c9c69_row3_col14" class="data row3 col14" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c9c69_level0_row4" class="row_heading level0 row4" >71</th>
#       <td id="T_c9c69_row4_col0" class="data row4 col0" >intrusion</td>
#       <td id="T_c9c69_row4_col1" class="data row4 col1" >ctgan_syn</td>
#       <td id="T_c9c69_row4_col2" class="data row4 col2" >tabular</td>
#       <td id="T_c9c69_row4_col3" class="data row4 col3" >0.960000</td>
#       <td id="T_c9c69_row4_col4" class="data row4 col4" >0.900000</td>
#       <td id="T_c9c69_row4_col5" class="data row4 col5" >0.650000</td>
#       <td id="T_c9c69_row4_col6" class="data row4 col6" >1.000000</td>
#       <td id="T_c9c69_row4_col7" class="data row4 col7" >0.780000</td>
#       <td id="T_c9c69_row4_col8" class="data row4 col8" >0.960000</td>
#       <td id="T_c9c69_row4_col9" class="data row4 col9" >0.980000</td>
#       <td id="T_c9c69_

# %%
subset = all_df[(all_df["dataset"] == "covtype") & (all_df["case"] == "tabular")]
df_style = subset.style.apply(lambda s: highlight_top3_min3(s, skip_cols=skip_cols, min_cols=min_cols))
df_style
# Out:
# <style type="text/css">
# #T_dcd5c_row0_col3, #T_dcd5c_row0_col9, #T_dcd5c_row0_col10, #T_dcd5c_row0_col12, #T_dcd5c_row0_col13, #T_dcd5c_row1_col4, #T_dcd5c_row1_col8, #T_dcd5c_row1_col9, #T_dcd5c_row2_col4, #T_dcd5c_row2_col11, #T_dcd5c_row3_col7, #T_dcd5c_row4_col5, #T_dcd5c_row6_col9, #T_dcd5c_row6_col11, #T_dcd5c_row6_col12 {
#   background-color: #fdfd96;
# }
# #T_dcd5c_row0_col4, #T_dcd5c_row0_col5, #T_dcd5c_row0_col8, #T_dcd5c_row0_col11, #T_dcd5c_row2_col8, #T_dcd5c_row3_col4, #T_dcd5c_row3_col9, #T_dcd5c_row3_col12, #T_dcd5c_row3_col13, #T_dcd5c_row4_col7, #T_dcd5c_row4_col12, #T_dcd5c_row5_col3, #T_dcd5c_row5_col10, #T_dcd5c_row6_col4, #T_dcd5c_row6_col8 {
#   background-color: #FFB347;
# }
# #T_dcd5c_row0_col6, #T_dcd5c_row0_col14, #T_dcd5c_row1_col6, #T_dcd5c_row1_col14, #T_dcd5c_row2_col6, #T_dcd5c_row2_col14, #T_dcd5c_row3_col6, #T_dcd5c_row3_col14, #T_dcd5c_row4_col3, #T_dcd5c_row4_col4, #T_dcd5c_row4_col6, #T_dcd5c_row4_col8, #T_dcd5c_row4_col9, #T_dcd5c_row4_col10, #T_dcd5c_row4_col11, #T_dcd5c_row4_col13, #T_dcd5c_row4_col14, #T_dcd5c_row5_col4, #T_dcd5c_row5_col5, #T_dcd5c_row5_col6, #T_dcd5c_row5_col7, #T_dcd5c_row5_col8, #T_dcd5c_row5_col9, #T_dcd5c_row5_col11, #T_dcd5c_row5_col12, #T_dcd5c_row5_col13, #T_dcd5c_row5_col14, #T_dcd5c_row6_col6, #T_dcd5c_row6_col14 {
#   background-color: #77dd77;
# }
# </style>
# <table id="T
level0_row3" class="row_heading level0 row3" >32</th>
#       <td id="T_dcd5c_row3_col0" class="data row3 col0" >covtype</td>
#       <td id="T_dcd5c_row3_col1" class="data row3 col1" >gaussian_copula_sdv</td>
#       <td id="T_dcd5c_row3_col2" class="data row3 col2" >tabular</td>
#       <td id="T_dcd5c_row3_col3" class="data row3 col3" >0.750000</td>
#       <td id="T_dcd5c_row3_col4" class="data row3 col4" >0.990000</td>
#       <td id="T_dcd5c_row3_col5" class="data row3 col5" >0.560000</td>
#       <td id="T_dcd5c_row3_col6" class="data row3 col6" >1.000000</td>
#       <td id="T_dcd5c_row3_col7" class="data row3 col7" >0.950000</td>
#       <td id="T_dcd5c_row3_col8" class="data row3 col8" >0.170000</td>
#       <td id="T_dcd5c_row3_col9" class="data row3 col9" >0.980000</td>
#       <td id="T_dcd5c_row3_col10" class="data row3 col10" >0.170000</td>
#       <td id="T_dcd5c_row3_col11" class="data row3 col11" >0.260000</td>
#       <td id="T_dcd5c_row3_col12" class="data row3 col12" >0.010000</td>
#       <td id="T_dcd5c_row3_col13" class="data row3 col13" >0.100000</td>
#       <td id="T_dcd5c_row3_col14" class="data row3 col14" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_dcd5c_level0_row4" class="row_heading level0 row4" >33</th>
#       <td id="T_dcd5c_row4_col0" class="data row4 col0" >covtype</td>
#       <td id="T_dcd5c_row4_col1" class="data row4 col1" >arf_syn</td>
#       <td id="T_dcd5c_row4_col2" class="data row4 col2" >tabular</td>
#       <td id="T_dcd5c_row4_col3" class="data row4 col3" >1.000000</td>
#       <td id="T_dcd5c_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_dcd5c_row4_col5" class="data row4 col5" >0.790000</td>
#       <td id="T_dcd5c_row4_col6" class="data row4 col6" >1.000000</td>
#       <td id="T_dcd5c_row

# %%
subset = all_df[(all_df["dataset"] == "pums") & (all_df["case"] == "tabular")]
df_style = subset.style.apply(lambda s: highlight_top3_min3(s, skip_cols=skip_cols, min_cols=min_cols))
df_style
# Out:
# <style type="text/css">
# #T_55405_row0_col3, #T_55405_row0_col6, #T_55405_row0_col7, #T_55405_row0_col8, #T_55405_row0_col9, #T_55405_row0_col10, #T_55405_row0_col11, #T_55405_row0_col13, #T_55405_row0_col14, #T_55405_row2_col4, #T_55405_row2_col5, #T_55405_row2_col12, #T_55405_row3_col9 {
#   background-color: #FFB347;
# }
# #T_55405_row0_col4, #T_55405_row0_col12, #T_55405_row1_col3, #T_55405_row1_col4, #T_55405_row1_col5, #T_55405_row1_col6, #T_55405_row1_col7, #T_55405_row1_col8, #T_55405_row1_col9, #T_55405_row1_col10, #T_55405_row1_col11, #T_55405_row1_col12, #T_55405_row1_col13, #T_55405_row1_col14, #T_55405_row2_col6, #T_55405_row2_col14, #T_55405_row3_col6, #T_55405_row3_col14 {
#   background-color: #77dd77;
# }
# #T_55405_row0_col5, #T_55405_row2_col3, #T_55405_row2_col7, #T_55405_row2_col8, #T_55405_row2_col9, #T_55405_row2_col10, #T_55405_row2_col11, #T_55405_row2_col13, #T_55405_row3_col4, #T_55405_row3_col12 {
#   background-color: #fdfd96;
# }
# </style>
# <table id="T_55405">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_55405_level0_col0" class="col_heading level0 col0" >dataset</th>
#       <th id="T_55405_level0_col1" class="col_heading level0 col1" >model</th>
#       <th id="T_55405_level0_col2" class="col_heading level0 col2" >case</th>
#       <th id="T_55405_level0_col3" class="col_heading level0 col3" >domain_cov</th>
#       <th id="T_55405_level0_col4" class="col_heading level0 col4" >stats_cov</th>
#       <th id="T_55405_level0_col5" class="col_heading level0 col5" >outliers_cov</th>
#       <th id="T_55405_level0_col6" class="col_heading level0 col6" >missing_cov</th>
#       <th id="T_55405_level0_col7" class="col_heading level0 col7" >ks_sim</th>
#       <th id="T_55405_level0_col8" class="col_heading level0 col8" >tv_sim</th>
#       <th id="T_55405_level0_col9" class="col_heading level0 col9" >corr_sim</th>
#       <th id="T_55405_level0_col10" class="col_heading level0 col10" >contin_sim</th>
#       <th id="T_55405_level0_col11" class="col_heading level0 col11" >sdv_quality_report</th>
#       <th id="T_55405_level0_col12" class="col_heading level0 col12" >wass_dist</th>
#       <th id="T_55405_level0_col13" class="col_heading level0 col13" >js_dist</th>
#       <th id="T_55405_level0_col14" class="col_heading level0 col14" >new_row_synthesis</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_55405_level0_row0" class="row_heading level0 row0" >99</th>
#       <td id="T_55405_row0_col0" class="data row0 col0" >pums</td>
#       <td id="T_55405_row0_col1" class="data row0 col1" >actgan_gretel</td>
#       <td id="T_55405_row0_col2" class="data row0 col2" >tabular</td>
#       <td id="T_55405_row0_col3" class="data row0 col3" >0.810000</td>
#       <td id="T_55405_row0_col4" class="data row0 col4" >0.990000</td>
#       <td id="T_55405_row0_col5" class="data row0 col5" >0.600000</td>
#       <td id="T_55405_row0_col6" class="data row0 col6" >0.980000</td>
#       <td id="T_55405_row0_col7" class="data row0 col7" >0.850000</td>
#       <td id="T_55405_row0_col8" class="data row0 col8" >0.980000</td>
#       <td id="T_55405_row0_col9" class="data row0 col9" >0.970000</td>
#       <td id="T
]
df_style = subset.style.apply(lambda s: highlight_top3_min3(s, skip_cols=skip_cols, min_cols=min_cols))
df_style
# Out:
# <style type="text/css">
# #T_1f6f8_row0_col4, #T_1f6f8_row0_col6, #T_1f6f8_row1_col4, #T_1f6f8_row1_col5, #T_1f6f8_row1_col6, #T_1f6f8_row1_col7, #T_1f6f8_row1_col8, #T_1f6f8_row1_col11, #T_1f6f8_row1_col12, #T_1f6f8_row2_col6, #T_1f6f8_row2_col8, #T_1f6f8_row3_col4, #T_1f6f8_row3_col6, #T_1f6f8_row3_col9, #T_1f6f8_row3_col14, #T_1f6f8_row4_col4, #T_1f6f8_row4_col6, #T_1f6f8_row4_col8, #T_1f6f8_row4_col10, #T_1f6f8_row5_col4, #T_1f6f8_row5_col6, #T_1f6f8_row5_col8, #T_1f6f8_row5_col9, #T_1f6f8_row6_col3, #T_1f6f8_row6_col4, #T_1f6f8_row6_col6, #T_1f6f8_row6_col8, #T_1f6f8_row6_col9, #T_1f6f8_row6_col10, #T_1f6f8_row6_col11, #T_1f6f8_row6_col12, #T_1f6f8_row6_col13, #T_1f6f8_row7_col4, #T_1f6f8_row7_col6, #T_1f6f8_row7_col8, #T_1f6f8_row7_col14 {
#   background-color: #77dd77;
# }
# #T_1f6f8_row0_col5, #T_1f6f8_row0_col9, #T_1f6f8_row1_col10, #T_1f6f8_row2_col7, #T_1f6f8_row2_col9, #T_1f6f8_row2_col11, #T_1f6f8_row3_col8, #T_1f6f8_row4_col7, #T_1f6f8_row4_col13, #T_1f6f8_row5_col3, #T_1f6f8_row5_col7, #T_1f6f8_row5_col13, #T_1f6f8_row5_col14, #T_1f6f8_row7_col10, #T_1f6f8_row7_col11 {
#   background-color: #fdfd96;
# }
# #T_1f6f8_row0_col8, #T_1f6f8_row0_col12, #T_1f6f8_row1_col9, #T_1f6f8_row1_col13, #T_1f6f8_row2_col4, #T_1f6f8_row2_col12, #T_1f6f8_row3_col12, #T_1f6f8_row4_col3, #T_1f6f8_row4_col5, #T_1f6f8_row4_col9, #T_1f6f8_row4_col11, #T_1f6f8_row4_col12, #T_1f6f8_row4_col14, #T_1f6f8_row5_col10, #T_1f6f8_row5_col11, #T_1f6f8_row5_col12, #T_1f6f8_row6_col5, #T_1f6f8_row6_col7, #T_1f6f8_row7_col9, #T_1f6f8_row7_col12 {
#   background-color: #FFB347;
# }
# </style>
# <table id="T_1f6f8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1f6f8_level0_col0" class="col_heading level0 col0" >dataset</th>
#       <th id="T_1f6f8_level0_col1" class="col_heading level0 col1" >model</th>
#       <th id="T_1f6f8_level0_col2" class="col_heading level0 col2" >case</th>
#       <th id="T_1f6f8_level0_col3" class="col_heading level0 col3" >domain_cov</th>
#       <th id="T_1f6f8_level0_col4" class="col_heading level0 col4" >stats_cov</th>
#       <th id="T_1f6f8_level0_col5" class="col_heading level0 col5" >outliers_cov</th>
#       <th id="T_1f6f8_level0_col6" class="col_heading level0 col6" >missing_cov</th>
#       <th id="T_1f6f8_level0_col7" class="col_heading level0 col7" >ks_sim</th>
#       <th id="T_1f6f8_level0_col8" class="col_heading level0 col8" >tv_sim</th>
#       <th id="T_1f6f8_level0_col9" class="col_heading level0 col9" >corr_sim</th>
#       <th id="T_1f6f8_level0_col10" class="col_heading level0 col10" >contin_sim</th>
#       <th id="T_1f6f8_level0_col11" class="col_heading level0 col11" >sdv_quality_report</th>
#       <th id="T_1f6f8_level0_col12" class="col_heading level0 col12" >wass_dist</th>
#       <th id="T_1f6f8_level0_col13" class="col_heading level0 col13" >js_dist</th>
#       <th id="T_1f6f8_level0_col14" class="col_heading level0 col14" >new_row_synthesis</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1f6f8_level0_row0" class="row_heading level0 row0" >36</th>
#       <td id="T_1f6f8_row0_col0" class="data row0 col0" >credit</td>
#       <td id="T_1f6f8_row0_col1" class="data row0 col1" >actgan_gretel</td>
#       <td id="T_1f6f8_row0_col2" class="data row0 col2" >tabular</td>
#       <td id="T_1f6f8_row0_col3" class="data row0 col3" >0.220000</td>
#       <td id="T_1f6f8_row0_col4" class="data row0 col4" >1.000000</td>
#       <td id="T_1f6f8_row0_col5" class="data row0 col5" >0.770000</td>
#       <td id="T_1f6f8_row0_col6" class="data row0 col6" >1.000000</td>
#       <td id="T_1f6f8_row0_col7" class="data row0 col7" >0.900000</td>
#       <td id="T_1f6f8_row0_col8" class="data row0 col8" >0.420000</td>
#       <td id="T_1f6f8_row0_col9" class="data row0 col9" >0.960000</td>
#       <td id="T_1f6f8_row0_col10" class="data row0 col10" >0.280000</td>
#       <td id="T_1f6f8_row0_col11" class="data row0 col11" >0.900000</td>
#       <td id="T_1f6f8_row0_col12" class="data row0 col12" >0.010000</td>
#       <td id="T_1f6f8_row0_col13" class="data row0 col13" >0.120000</td>
#       <td id="T_1f6f8_row0_col14" class="data row0 col14" >0.960000</td>
#     </tr>
#     <tr>
#       <th id="T_1f6f8_level0_row1" class="row_heading level0 row1" >37</th>
#       <td id="T_1f6f8_row1_col0" class="data row1 col0" >credit</td>
#       <td id="T_1f6f8_row1_col1" class="data row1 col1" >ctgan_sdv</td>
#       <td id="T_1f6f8_row1_col2" class="data row1 col2" >tabular</td>
#       <td id="T_1f6f8_row1_col3" class="data row1 col3" >0.190000</td>
#       <td id="T_1f6f8_row1_col4" class="data row1 col4" >1.000000</td>
#       <td id="T_1f6f8_row1_col5" class="data row1 col5" >0.960000</td>
#       <td id="T_1f6f8_row1_col6" class="data row1 col6" >1.000000</td>
#       <td id="T_1f6f8_row1_col7" class="data row1 col7" >0.980000</td>
#       <td id="T_1f6f8_row1_col8" class="data row1 col8" >1.000000</td>
#       <td id="T_1f6f8_row1_col9" class="data row1 col9" >0.970000</td>
#       <td id="T_1f6f8_row1_col10" class="data row1 col10" >0.550000</td>
#       <td id="T_1f6f8_row1_col11" class="data row1 col11" >0.960000</td>
#       <td id="T_1f6f8_row1_col12" class="data row1 col12" >0.000000</td>
#       <td id="T_1f6f8_row1_col13" class="data row1 col13" >0.060000</td>
#       <td id="T_1f6f8_row1_col14" class="data row1 col14" >0.920000</td>
#     </tr>
#     <tr>
#       <th id="T_1f6f8_level0_row2" class="row_heading level0 row2" >38</th>
#       <td id="T_1f6f8_row2_col0" class="data row2 col0" >credit</td>
#       <td id="T_1f6f8_row2_col1" class="data row2 col1" >tvae_sdv</td>
#       <td id="T_1f6f8_row2_col2" class="data row2 col2" >tabular</td>
#       <td id="T_1f6f8_row2_col3" class="data row2 col3" >0.150000</td>
#       <td id="T_1f6f8_row2_col4" class="data row2 col4" >0.990000</td>
#       <td id="T_1f6f8_row2_col5" class="data row2 col5" >0.370000</td>
#       <td id="T_1f6f8_row2_col6" class="data row2 col6" >1.000000</td>
#       <td id="T_1f6f8_row2_col7" class="data row2 col7" >0.930000</td>
#       <td id="T_1f6f8_row2_col8" class="data row2 col8" >1.000000</td>
#       <td id="T_1f6f8_row2_col9" class="data row2 col9" >0.960000</td>
#       <td id="T_1f6f8_row2_col10" class="data row2 col10" >0.540000</td>
#       <td id="T_1f6f8_row2_col11" class="data row2 col11" >0.930000</td>
#       <td id="T_1f6f8_row2_col12" class="data row2 col12" >0.010000</td>
#       <td id="T_1f6f8_row2_col13" class="data row2 col13" >0.140000</td>
#       <td id="T_1f6f8_row2_col14" class="data row2 col14" >0.720000</td>
#     </tr>
#     <tr>
#       <th id="T_1f6f8_level0_row3" class="row_heading level0 row3" >39</th>
#       <td id="T_1f6f8_row3_col0" class="data row3 col0" >credit</td>
#       <td id="T_1f6f8_row3_col1" class="data row3 col1" >gaussian_copula_sdv</td>
#       <td id="T_1f6f8_row3_col2" class="data row3 col2" >tabular</td>
#       <td id="T_1f6f8_row3_col3" class="data row3 col3" >0.250000</td>
#       <td id="T_1f6f8_row3_col4" class="data row3 col4" >1.000000</td>
#       <td id="T_1f6f8_row3_col5" class="data row3 col5" >0.620000</td>
#       <td id="T_1f6f8_row3_col6" class="data row3 col6" >1.000000</td>
#       <td id="T_1f6f8_row3_col7" class="data row3 col7" >0.880000</td>
#       <td id="T_1f6f8_row3_col8" class="data row3 col8" >0.000000</td>
#       <td id="T_1f6f8_row3_col9" class="data row3 col9" >0.980000</td>
#       <td id="T_1f6f8_row3_col10" class="data row3 col10" >0.100000</td>
#       <td id="T_1f6f8_row3_col11" class="data row3 col11" >0.880000</td>
#       <td id="T_1f6f8_row3_col12" class="data row3 col12" >0.010000</td>
#       <td id="T_1f6f8_row3_col13" class="data row3 col13" >0.150000</td>
#       <td id="T_1f6f8_row3_col14" class="data row3 col14" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1f6f8_level0_row4" class="row_heading level0 row4" >40</th>
#       <td id="T_1f6f8_row4_col0" class="data row4 col0" >credit</td>
#       <td id="T_1f6f8_row4_col1" class="data row4 col1" >ctgan_syn</td>
#       <td id="T_1f6f8_row4_col2" class="data row4 col2" >tabular</td>
#       <td id="T_1f6f8_row4_col3" class="data row4 col3" >0.560000</td

# %%
# insurance, child
# subset = all_df[(all_df["dataset"] == "child") & (all_df["case"] == "tabular")]

# # subset = all_df[(all_df["dataset"] == "child") & (all_df["case"] == "tabular")]
# df_style = subset.style.apply(lambda s: highlight_top3_min3(s, skip_cols=skip_cols, min_cols=min_cols))
# df_style

# %% [markdown]
# ## Similar models across libraries

# %%
subset = all_df[all_df["model"].isin(["ctgan_syn", "ctgan_sdv", "actgan_gretel"])  & (all_df["case"] == "tabular") & (all_df["dataset"] == "adult")]
df_style = subset.style.apply(lambda s: highlight_top3_min3(s, skip_cols=skip_cols, min_cols=min_cols))
df_style

# adult, child, health_insurance, intrusion, drugs, loan, credit
# Out:
# <style type="text/css">
# #T_43a99_row0_col3, #T_43a99_row0_col5, #T_43a99_row0_col7, #T_43a99_row0_col9, #T_43a99_row0_col13, #T_43a99_row1_col8, #T_43a99_row1_col10, #T_43a99_row1_col11, #T_43a99_row2_col5 {
#   background-color: #FFB347;
# }
# #T_43a99_row0_col4, #T_43a99_row0_col6, #T_43a99_row0_col8, #T_43a99_row0_col10, #T_43a99_row0_col11, #T_43a99_row0_col12, #T_43a99_row0_col14, #T_43a99_row1_col4, #T_43a99_row1_col5, #T_43a99_row1_col6, #T_43a99_row1_col7, #T_43a99_row1_col9, #T_43a99_row1_col12, #T_43a99_row1_col13, #T_43a99_row1_col14, #T_43a99_row2_col3, #T_43a99_row2_col4, #T_43a99_row2_col6, #T_43a99_row2_col9, #T_43a99_row2_col12, #T_43a99_row2_col14 {
#   background-color: #77dd77;
# }
# #T_43a99_row1_col3, #T_43a99_row2_col7, #T_43a99_row2_col8, #T_43a99_row2_col10, #T_43a99_row2_col11, #T_43a99_row2_col13 {
#   background-color: #fdfd96;
# }
# </style>
# <table id="T_43a99">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_43a99_level0_col0" class="col_heading level0 col0" >dataset</th>
#       <th id="T_43a99_level0_col1" class="col_heading level0 col1" >model</th>
#       <th id="T_43a99_level0_col2" class="col_heading level0 col2" >case</th>
#       <th id="T_43a99_level0_col3" class="col_heading level0 col3" >domain_cov</th>
#       <th id="T_43a99_level0_col4" class="col_heading level0 col4" >stats_cov</th>
#       <th id="T_43a99_level0_col5" class="col_heading level0 col5" >outliers_cov</th>
#       <th id="T_43a99_level0_col6" class="col_heading level0 col6" >missing_cov</th>
#       <th id="T_43a99_level0_col7" class="col_heading level0 col7" >ks_sim</th>
#       <th id="T_43a99_level0_col8" class="col_heading level0 col8" >tv_sim</th>
#       <th id="T_43a99_level0_col9" class="col_heading level0 col9" >corr_sim</th>
#       <th id="T_43a99_level0_col10" class="col_heading level0 col10" >contin_sim</th>
#       <th id="T_43a99_level0_col11" class="col_heading level0 col11" >sdv_quality_report</th>
#       <th id="T_43a99_level0_col12" class="col_heading level0 col12" >wass_dist</th>
#       <th id="T_43a99_level0_col13" class="col_heading level0 col13" >js_dist</th>
#       <th id="T_43a99_level0_col14" class="col_heading level0 col14" >new_row_synthesis</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_43a99_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_43a99_row0_col0" class="data row0 col0" >adult</td>
#       <td id="T_43a99_row0_col1" class="data row0 col1" >actgan_gretel</td>
#       <td id="T_43a99_row0_col2" class="data row0 col2" >tabular</td>
#       <td id="T_43a99_row0_col3" class="data row0 col3" >0.890000</td>
#       <td id="T_43a99_row0_col4" class="data row0 col4" >0.990000</td>
#       <td id="T_43a99_row0_col5" class="data row0 col5" >0.490000</td>
#       <td id="T_43a99_row0_col6" class="data row0 col6" >1.000000</td>
#       <td id="T_43a99_row0_col7" class="data row0 col7" >0.790000</td>
#       <td id="T_43a99_row0_col8" class="data row0 col8" >0.920000</td>
#       <td id="T_43a99_row0_col9" class="data row0 col9" >0.970000</td>
#       <td id="T_43a99_row0_col10" class="data row0 col10" >0.870000</td>
#       <td id="T_43a99_row0_col11" class="data row0 col11" >0.880000</td>
#       <td id="T_43a99_row0_col12" class="data row0 col12" >0.020000</td>
#       <td id="T_43a99_row0_col13" class="data row0 col13" >0.240000</td>
#       <td id="T_43a99_row0_col14" class="data row0 col14" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_43a99_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_43a99_row1_col0" class="data row1 col0" >adult</td>
#       <td id="T_43a99_row1_col1" class="data row1 col1" >ctgan_sdv</td>
#       <td id="T_43a99_row1_col2" class="data row1 col2" >tabular</td>
#       <td id="T_43a99_row1_col3" class="data row1 col3" >0.870000</td>
#       <td id="T_43a99_row1_col4" class="data row1 col4" >0.990000</td>
#       <td id="T_43a99_row1_col5" class="data row1 col5" >0.790000</td>
#       <td id="T_43a99_row1_col6" class="data row1 col6" >1.000000</td>
#       <td id="T_43a99_row1_col7" class="data row1 col7" >0.870000</td>
#       <td id="T_43a99_row1_col8" class="data row1 col8" >0.910000</td>
#       <td id="T_43a99_row1_col9" class="data row1 col9" >0.980000</td>
#       <td id="T_43a99_row1_col10" class="data row1 col10" >0.820000</td>
#       <td id="T_43a99_row1_col11" class="data row1 col11" >0.870000</td>
#       <td id="T_43a99_row1_col12" class="data row1 col12" >0.020000</td>
#       <td id="T_43a99_row1_col13" class="data row1 col13" >0.220000</td>
#       <td id="T_43a99_row1_col14" class="data row1 col14" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_43a99_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_43a99_row2_col0" class="data row2 col0" >adult</td>
#       <td id="T_43a99_row2_col1" class="data row2 col1" >ctgan_syn</td>
#       <td id="T_43a99_row2_col2" class="data row2 col2" >tabular</td>
#       <td id="T_43a99_row2_col3" class="data row2 col3" >0.910000</td>
#       <td id="T_43a99_row2_col4" class="data row2 col4" >0.990000</td>
#       <td id="T_43a99_row2_col5" class="data row2 col5" >0.490000</td>
#       <td id="T_43a99_row2_col6" class="data row2 col6" >1.000000</td>
#       <td id="T_43a99_row2_col7" class="data row2 col7" >0.760000</td>
#       <td id="T_43a99_row2_col8" class="data row2 col8" >0.790000</td>
#       <td id="T_43a99_row2_col9" class="data row2 col9" >0.980000</td>
#       <td id="T_43a99_row2_col10" class="data row2 col10" >0.740000</td>
#       <td id="T_43a99_row2_col11" class="data row2 col11" >0.780000</td>
#       <td id="T_43a99_row2_col12" class="data row2 col12" >0.020000</td>
#       <td id="T_43a99_row2_col13" class="data row2 col13" >0.340000</td>
#       <td id="T_43a99_row2_col14" class="data row2 col14" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
subset = all_df[all_df["model"].isin(["ctgan_syn", "ctgan_sdv", "actgan_gretel"])  & (all_df["case"] == "tabular") & (all_df["dataset"] == "health_insurance")]
df_style = subset.style.apply(lambda s: highlight_top3_min3(s, skip_cols=skip_cols, min_cols=min_cols))
df_style
# Out:
# <style type="text/css">
# #T_afd3b_row0_col3, #T_afd3b_row0_col4, #T_afd3b_row0_col6, #T_afd3b_row0_col8, #T_afd3b_row0_col10, #T_afd3b_row0_col11, #T_afd3b_row0_col12, #T_afd3b_row0_col13, #T_afd3b_row0_col14, #T_afd3b_row1_col5, #T_afd3b_row1_col6, #T_afd3b_row1_col8, #T_afd3b_row1_col14, #T_afd3b_row2_col6, #T_afd3b_row2_col7, #T_afd3b_row2_col8, #T_afd3b_row2_col9, #T_afd3b_row2_col11, #T_afd3b_row2_col12, #T_afd3b_row2_col14 {
#   background-color: #77dd77;
# }
# #T_afd3b_row0_col5, #T_afd3b_row0_col7, #T_afd3b_row0_col9, #T_afd3b_row1_col3, #T_afd3b_row1_col10, #T_afd3b_row1_col11, #T_afd3b_row1_col12, #T_afd3b_row2_col4, #T_afd3b_row2_col13 {
#   background-color: #FFB347;
# }
# #T_afd3b_row1_col4, #T_afd3b_row1_col7, #T_afd3b_row1_col9, #T_afd3b_row1_col13, #T_afd3b_row2_col3, #T_afd3b_row2_col5, #T_afd3b_row2_col10 {
#   background-color: #fdfd96;
# }
# </style>
# <table id="T_afd3b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_afd3b_level0_col0" class="col_heading level0 col0" >dataset</th>
#       <th id="T_afd3b_level0_col1" class="col_heading level0 col1" >model</th>
#       <th id="T_afd3b_level0_col2" class="col_heading level0 col2" >case</th>
#       <th id="T_afd3b_level0_col3" class="col_heading level0 col3" >domain_cov</th>
#       <th id="T_afd3b_level0_col4" class="col_heading level0 col4" >stats_cov</th>
#       <th id="T_afd3b_level0_col5" class="col_heading level0 col5" >outliers_cov</th>
#       <th id="T_afd3b_level0_col6" class="col_heading level0 col6" >missing_cov</th>
#       <th id="T_afd3b_level0_col7" class="col_heading level0 col7" >ks_sim</th>
#       <th id="T_afd3b_level0_col8" class="col_heading level0 col8" >tv_sim</th>
#       <th id="T_afd3b_level0_col9" class="col_heading level0 col9" >corr_sim</th>
#       <th id="T_afd3b_level0_col10" class="col_heading level0 col10" >contin_sim</th>
#       <th id="T_afd3b_level0_col11" class="col_heading level0 col11" >sdv_quality_report</th>
#       <th id="T_afd3b_level0_col12" class="col_heading level0 col12" >wass_dist</th>
#       <th id="T_afd3b_level0_col13" class="col_heading level0 col13" >js_dist</th>
#       <th id="T_afd3b_level0_col14" class="col_heading level0 col14" >new_row_synthesis</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_afd3b_level0_row0" class="row_heading level0 row0" >54</th>
#       <td id="T_afd3b_row0_col0" class="data row0 col0" >health_insurance</td>
#       <td id="T_afd3b_row0_col1" class="data row0 col1" >actgan_gretel</td>
#       <td id="T_afd3b_row0_col2" class="data row0 col2" >tabular</td>
#       <td id="T_afd3b_row0_col3" class="data row0 col3" >1.000000</td>
#       <td id="T_afd3b_row0_col4" class="data row0 col4" >0.950000</td>
#       <td id="T_afd3b_row0_col5" class="data row0 col5" >0.330000</td>
#       <td id="T_afd3b_row0_col6" class="data row0 col6" >1.000000</td>
#       <td id="T_afd3b_row0_col7" class="data row0 col7" >0.850000</td>
#       <td id="T_afd3b_row0_col8" class="data row0 col8" >0.880000</td>
#       <td id="T_afd3b_row0_col9" class="data row0 col9" >0.910000</td>
#       <td id="T_afd3b_row0_col10" class="data row0 col10" >0.820000</td>
#       <td id="T_afd3b_row0_col11" class="data row0 col11" >0.850000</td>
#       <td id="T_afd3b_row0_col12" class="data row0 col12" >0.070000</td>
#       <td id="T_afd3b_row0_col13" class="data row0 col13" >0.190000</td>
#       <td id="T_afd3b_row0_col14" class="data row0 col14" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_afd3b_level0_row1" class="row_heading level0 row1" >55</th>
#       <td id="T_afd3b_row1_col0" class="data row1 col0" >health_insurance</td>
#       <td id="T_afd3b_row1_col1" class="data row1 col1" >ctgan_sdv</td>
#       <td id="T_afd3b_row1_col2" class="data row1 col2" >tabular</td>
#       <td id="T_afd3b_row1_col3" class="data row1 col3" >0.980000</td>
#       <td id="T_afd3b_row1_col4" class="data row1 col4" >0.890000</td>
#       <td id="T_afd3b_row1_col5" class="data row1 col5" >0.350000</td>
#       <td id="T_afd3b_row1_col6" class="data row1 col6" >1.000000</td>
#       <td id="T_afd3b_row1_col7" class="data row1 col7" >0.750000</td>
#       <td id="T_afd3b_row1_col8" class="data row1 col8" >0.880000</td>
#       <td id="T_afd3b_row1_col9" class="data row1 col9" >0.890000</td>
#       <td id="T_afd3b_row1_col10" class="data row1 col10" >0.810000</td>
#       <td id="T_afd3b_row1_col11" class="data row1 col11" >0.820000</td>
#       <td id="T_afd3b_row1_col12" class="data row1 col12" >0.130000</td>
#       <td id="T_afd3b_row1_col13" class="data row1 col13" >0.240000</td>
#       <td id="T_afd3b_row1_col14" class="data row1 col14" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_afd3b_level0_row2" class="row_heading level0 row2" >58</th>
#       <td id="T_afd3b_row2_col0" class="data row2 col0" >health_insurance</td>
#       <td id="T_afd3b_row2_col1" class="data row2 col1" >ctgan_syn</td>
#       <td id="T_afd3b_row2_col2" class="data row2 col2" >tabular</td>
#       <td id="T_afd3b_row2_col3" class="data row2 col3" >0.920000</td>
#       <td id="T_afd3b_row2_col4" class="data row2 col4" >0.940000</td>
#       <td id="T_afd3b_row2_col5" class="data row2 col5" >0.320000</td>
#       <td id="T_afd3b_row2_col6" class="data row2 col6" >1.000000</td>
#       <td id="T_afd3b_row2_col7" class="data row2 col7" >0.860000</td>
#       <td id="T_afd3b_row2_col8" class="data row2 col8" >0.880000</td>
#       <td id="T_afd3b_row2_col9" class="data row2 col9" >0.980000</td>
#       <td id="T_afd3b_row2_col10" class="data row2 col10" >0.800000</td>
#       <td id="T_afd3b_row2_col11" class="data row2 col11" >0.850000</td>
#       <td id="T_afd3b_row2_col12" class="data row2 col12" >0.070000</td>
#       <td id="T_afd3b_row2_col13" class="data row2 col13" >0.210000</td>
#       <td id="T_afd3b_row2_col14" class="data row2 col14" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
subset = all_df[all_df["model"].isin(["ctgan_syn", "ctgan_sdv", "actgan_gretel"])  & (all_df["case"] == "tabular") & (all_df["dataset"] == "intrusion")]
df_style = subset.style.apply(lambda s: highlight_top3_min3(s, skip_cols=skip_cols, min_cols=min_cols))
df_style
# Out:
# <style type="text/css">
# #T_f3f3f_row0_col3, #T_f3f3f_row0_col4, #T_f3f3f_row0_col5, #T_f3f3f_row0_col8, #T_f3f3f_row0_col9, #T_f3f3f_row0_col10, #T_f3f3f_row0_col11, #T_f3f3f_row0_col12, #T_f3f3f_row0_col13, #T_f3f3f_row0_col14, #T_f3f3f_row1_col5, #T_f3f3f_row1_col14, #T_f3f3f_row2_col7 {
#   background-color: #FFB347;
# }
# #T_f3f3f_row0_col6, #T_f3f3f_row0_col7, #T_f3f3f_row1_col6, #T_f3f3f_row2_col3, #T_f3f3f_row2_col4, #T_f3f3f_row2_col5, #T_f3f3f_row2_col6, #T_f3f3f_row2_col8, #T_f3f3f_row2_col9, #T_f3f3f_row2_col10, #T_f3f3f_row2_col11, #T_f3f3f_row2_col12, #T_f3f3f_row2_col13, #T_f3f3f_row2_col14 {
#   background-color: #77dd77;
# }
# #T_f3f3f_row1_col3, #T_f3f3f_row1_col4, #T_f3f3f_row1_col7, #T_f3f3f_row1_col8, #T_f3f3f_row1_col9, #T_f3f3f_row1_col10, #T_f3f3f_row1_col11, #T_f3f3f_row1_col12, #T_f3f3f_row1_col13 {
#   background-color: #fdfd96;
# }
# </style>
# <table id="T_f3f3f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f3f3f_level0_col0" class="col_heading level0 col0" >dataset</th>
#       <th id="T_f3f3f_level0_col1" class="col_heading level0 col1" >model</th>
#       <th id="T_f3f3f_level0_col2" class="col_heading level0 col2" >case</th>
#       <th id="T_f3f3f_level0_col3" class="col_heading level0 col3" >domain_cov</th>
#       <th id="T_f3f3f_level0_col4" class="col_heading level0 col4" >stats_cov</th>
#       <th id="T_f3f3f_level0_col5" class="col_heading level0 col5" >outliers_cov</th>
#       <th id="T_f3f3f_level0_col6" class="col_heading level0 col6" >missing_cov</th>
#       <th id="T_f3f3f_level0_col7" class="col_heading level0 col7" >ks_sim</th>
#       <th id="T_f3f3f_level0_col8" class="col_heading level0 col8" >tv_sim</th>
#       <th id="T_f3f3f_level0_col9" class="col_heading level0 col9" >corr_sim</th>
#       <th id="T_f3f3f_level0_col10" class="col_heading level0 col10" >contin_sim</th>
#       <th id="T_f3f3f_level0_col11" class="col_heading level0 col11" >sdv_quality_report</th>
#       <th id="T_f3f3f_level0_col12" class="col_heading level0 col12" >wass_dist</th>
#       <th id="T_f3f3f_level0_col13" class="col_heading level0 col13" >js_dist</th>
#       <th id="T_f3f3f_level0_col14" class="col_heading level0 col14" >new_row_synthesis</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f3f3f_level0_row0" class="row_heading level0 row0" >67</th>
#       <td id="T_f3f3f_row0_col0" class="data row0 col0" >intrusion</td>
#       <td id="T_f3f3f_row0_col1" class="data row0 col1" >actgan_gretel</td>
#       <td id="T_f3f3f_row0_col2" class="data row0 col2" >tabular</td>
#       <td id="T_f3f3f_row0_col3" class="data row0 col3" >0.740000</td>
#       <td id="T_f3f3f_row0_col4" class="data row0 col4" >0.890000</td>
#       <td id="T_f3f3f_row0_col5" class="data row0 col5" >0.360000</td>
#       <td id="T_f3f3f_row0_col6" class="data row0 col6" >1.000000</td>
#       <td id="T_f3f3f_row0_col7" class="data row0 col7" >0.830000</td>
#       <td id="T_f3f3f_row0_col8" class="data row0 col8" >0.910000</td>
#       <td id="T_f3f3f_row0_col9" class="data row0 col9" >0.960000</td>
#       <td id="T_f3f3f_row0_col10" class="data row0 col10" >0.780000</td>
#       <td id="T_f3f3f_row0_col11" class="data row0 col11" >0.840000</td>
#       <td id="T_f3f3f_row0_col12" class="data row0 col12" >0.070000</td>
#       <td id="T_f3f3f_row0_col13" class="data row0 col13" >0.180000</td>
#       <td id="T_f3f3f_row0_col14" class="data row0 col14" >0.980000</td>
#     </tr>
#     <tr>
#       <th id="T_f3f3f_level0_row1" class="row_heading level0 row1" >68</th>
#       <td id="T_f3f3f_row1_col0" class="data row1 col0" >intrusion</td>
#       <td id="T_f3f3f_row1_col1" class="data row1 col1" >ctgan_sdv</td>
#       <td id="T_f3f3f_row1_col2" class="data row1 col2" >tabular</td>
#       <td id="T_f3f3f_row1_col3" class="data row1 col3" >0.670000</td>
#       <td id="T_f3f3f_row1_col4" class="data row1 col4" >0.860000</td>
#       <td id="T_f3f3f_row1_col5" class="data row1 col5" >0.360000</td>
#       <td id="T_f3f3f_row1_col6" class="data row1 col6" >1.000000</td>
#       <td id="T_f3f3f_row1_col7" class="data row1 col7" >0.770000</td>
#       <td id="T_f3f3f_row1_col8" class="data row1 col8" >0.880000</td>
#       <td id="T_f3f3f_row1_col9" class="data row1 col9" >0.920000</td>
#       <td id="T_f3f3f_row1_col10" class="data row1 col10" >0.740000</td>
#       <td id="T_f3f3f_row1_col11" class="data row1 col11" >0.800000</td>
#       <td id="T_f3f3f_row1_col12" class="data row1 col12" >0.120000</td>
#       <td id="T_f3f3f_row1_col13" class="data row1 col13" >0.220000</td>
#       <td id="T_f3f3f_row1_col14" class="data row1 col14" >0.980000</td>
#     </tr>
#     <tr>
#       <th id="T_f3f3f_level0_row2" class="row_heading level0 row2" >71</th>
#       <td id="T_f3f3f_row2_col0" class="data row2 col0" >intrusion</td>
#       <td id="T_f3f3f_row2_col1" class="data row2 col1" >ctgan_syn</td>
#       <td id="T_f3f3f_row2_col2" class="data row2 col2" >tabular</td>
#       <td id="T_f3f3f_row2_col3" class="data row2 col3" >0.960000</td>
#       <td id="T_f3f3f_row2_col4" class="data row2 col4" >0.900000</td>
#       <td id="T_f3f3f_row2_col5" class="data row2 col5" >0.650000</td>
#       <td id="T_f3f3f_row2_col6" class="data row2 col6" >1.000000</td>
#       <td id="T_f3f3f_row2_col7" class="data row2 col7" >0.780000</td>
#       <td id="T_f3f3f_row2_col8" class="data row2 col8" >0.960000</td>
#       <td id="T_f3f3f_row2_col9" class="data row2 col9" >0.980000</td>
#       <td id="T_f3f3f_row2_col10" class="data row2 col10" >0.910000</td>
#       <td id="T_f3f3f_row2_col11" class="data row2 col11" >0.910000</td>
#       <td id="T_f3f3f_row2_col12" class="data row2 col12" >0.020000</td>
#       <td id="T_f3f3f_row2_col13" class="data row2 col13" >0.170000</td>
#       <td id="T_f3f3f_row2_col14" class="data row2 col14" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
subset = all_df[all_df["model"].isin(["ctgan_syn", "ctgan_sdv", "actgan_gretel"])  & (all_df["case"] == "tabular") & (all_df["dataset"] == "credit")]
df_style = subset.style.apply(lambda s: highlight_top3_min3(s, skip_cols=skip_cols, min_cols=min_cols))
df_style
# Out:
# <style type="text/css">
# #T_80fc2_row0_col3, #T_80fc2_row0_col8, #T_80fc2_row0_col9, #T_80fc2_row0_col12, #T_80fc2_row0_col14, #T_80fc2_row1_col10, #T_80fc2_row2_col5, #T_80fc2_row2_col7, #T_80fc2_row2_col11, #T_80fc2_row2_col12, #T_80fc2_row2_col13 {
#   background-color: #FFB347;
# }
# #T_80fc2_row0_col4, #T_80fc2_row0_col6, #T_80fc2_row1_col4, #T_80fc2_row1_col5, #T_80fc2_row1_col6, #T_80fc2_row1_col7, #T_80fc2_row1_col8, #T_80fc2_row1_col9, #T_80fc2_row1_col11, #T_80fc2_row1_col12, #T_80fc2_row1_col13, #T_80fc2_row2_col3, #T_80fc2_row2_col4, #T_80fc2_row2_col6, #T_80fc2_row2_col8, #T_80fc2_row2_col9, #T_80fc2_row2_col10, #T_80fc2_row2_col14 {
#   background-color: #77dd77;
# }
# #T_80fc2_row0_col5, #T_80fc2_row0_col7, #T_80fc2_row0_col10, #T_80fc2_row0_col11, #T_80fc2_row0_col13, #T_80fc2_row1_col3, #T_80fc2_row1_col14 {
#   background-color: #fdfd96;
# }
# </style>
# <table id="T
row2_col6" class="data row2 col6" >1.000000</td>
#       <td id="T_72f0f_row2_col7" class="data row2 col7" >0.870000</td>
#       <td id="T_72f0f_row2_col8" class="data row2 col8" >0.960000</td>
#       <td id="T_72f0f_row2_col9" class="data row2 col9" >0.980000</td>
#       <td id="T_72f0f_row2_col10" class="data row2 col10" >0.850000</td>
#       <td id="T_72f0f_row2_col11" class="data row2 col11" >0.900000</td>
#       <td id="T_72f0f_row2_col12" class="data row2 col12" >0.050000</td>
#       <td id="T_72f0f_row2_col13" class="data row2 col13" >0.210000</td>
#       <td id="T_72f0f_row2_col14" class="data row2 col14" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### TVAE

# %%
subset = all_df[all_df["model"].isin(["rtvae_syn", "tvae_sdv", "tvae_syn"])  & (all_df["case"] == "tabular") & (all_df["dataset"] == "adult")]
df_style = subset.style.apply(lambda s: highlight_top3_min3(s, skip_cols=skip_cols, min_cols=min_cols))
df_style

# adult, child, health_insurance, intrusion, drugs, loan, credit
# Out:
# <style type="text/css">
# #T_d225b_row0_col3, #T_d225b_row0_col12, #T_d225b_row1_col5, #T_d225b_row1_col7, #T_d225b_row1_col8, #T_d225b_row1_col10, #T_d225b_row1_col11, #T_d225b_row1_col13, #T_d225b_row2_col4, #T_d225b_row2_col9, #T_d225b_row2_col12 {
#   background-color: #FFB347;
# }
# #T_d225b_row0_col4, #T_d225b_row0_col5, #T_d225b_row0_col6, #T_d225b_row0_col7, #T_d225b_row0_col8, #T_d225b_row0_col10, #T_d225b_row0_col11, #T_d225b_row0_col13, #T_d225b_row0_col14, #T_d225b_row1_col3, #T_d225b_row1_col4, #T_d225b_row1_col6, #T_d225b_row1_col9, #T_d225b_row1_col12, #T_d225b_row1_col14, #T_d225b_row2_col6, #T_d225b_row2_col14 {
#   background-color: #77dd77;
# }
# #T_d225b_row0_col9, #T_d225b_row2_col3, #T_d225b_row2_col5, #T_d225b_row2_col7, #T_d225b_row2_col8, #T_d225b_row2_col10, #T_d225b_row2_col11, #T_d225b_row2_col13 {
#   background-color: #fdfd96;
# }
# </style>
# <table id="T_d225b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d225b_level0_col0" class="col_heading level0 col0" >dataset</th>
#       <th id="T_d225b_level0_col1" class="col_heading level0 col1" >model</th>
#       <th id="T_d225b_level0_col2" class="col_heading level0 col2" >case</th>
#       <th id="T_d225b_level0_col3" class="col_heading level0 col3" >domain_cov</th>
#       <th id="T_d225b_level0_col4" class="col_heading level0 col4" >stats_cov</th>
#       <th id="T_d225b_level0_col5" class="col_heading level0 col5" >outliers_cov</th>
#       <th id="T_d225b_level0_col6" class="col_heading level0 col6" >missing_cov</th>
#       <th id="T_d225b_level0_col7" class="col_heading level0 col7" >ks_sim</th>
#       <th id="T_d225b_level0_col8" class="col_heading level0 col8" >tv_sim</th>
#       <th id="T_d225b_level0_col9" class="col_heading level0 col9" >corr_sim</th>
#       <th id="T_d225b_level0_col10" class="col_heading level0 col10" >contin_sim</th>
#       <th id="T_d225b_level0_col11" class="col_heading level0 col11" >sdv_quality_report</th>
#       <th id="T_d225b_level0_col12" class="col_heading level0 col12" >wass_dist</th>
#       <th id="T_d225b_level0_col13" class="col_heading level0 col13" >js_dist</th>
#       <th id="T_d225b_level0_col14" class="col_heading level0 col14" >new_row_synthesis</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d225b_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_d225b_row0_col0" class="data row0 col0" >adult</td>
#       <td id="T_d225b_row0_col1" class="data row0 col1" >tvae_sdv</td>
#       <td id="T_d225b_row0_col2" class="data row0 col2" >tabular</td>
#       <td id="T_d225b_row0_col3" class="data row0 col3" >0.790000</td>
#       <td id="T_d225b_row0_col4" class="data row0 col4" >0.990000</td>
#       <td id="T_d225b_row0_col5" class="data row0 col5" >0.680000</td>
#       <td id="T_d225b_row0_col6" class="data row0 col6" >1.000000</td>
#       <td id="T_d225b_row0_col7" class="data row0 col7" >0.880000</td>
#       <td id="T_d225b_row0_col8" class="data row0 col8" >0.940000</td>
#       <td id="T_d225b_row0_col9" class="data row0 col9" >0.970000</td>
#       <td id="T_d225b_row0_col10" class="data row0 col10" >0.880000</td>
#       <td id="T_d225b_row0_col11" class="data row0 col11" >0.910000</td>
#       <td id="T_d225b_row0_col12" class="data row0 col12" >0.020000</td>
#       <td id="T_d225b_row0_col13" class="data row0 col13" >0.130000</td>
#       <td id="T_d225b_row0_col14" class="data row0 col14" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d225b_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_d225b_row1_col0" class="data row1 col0" >adult</td>
#       <td id="T_d225b_row1_col1" class="data row1 col1" >tvae_syn</td>
#       <td id="T_d225b_row1_col2" class="data row1 col2" >tabular</td>
#       <td id="T_d225b_row1_col3" class="data row1 col3" >0.860000</td>
#       <td id="T_d225b_row1_col4" class="data row1 col4" >0.990000</td>
#       <td id="T_d225b_row1_col5" class="data row1 col5" >0.650000</td>
#       <td id="T_d225b_row1_col6" class="data row1 col6" >1.000000</td>
#       <td id="T_d225b_row1_col7" class="data row1 col7" >0.810000</td>
#       <td id="T_d225b_row1_col8" class="data row1 col8" >0.890000</td>
#       <td id="T_d225b_row1_col9" class="data row1 col9" >0.990000</td>
#       <td id="T_d225b_row1_col10" class="data row1 col10" >0.810000</td>
#       <td id="T_d225b_row1_col11" class="data row1 col11" >0.840000</td>
#       <td id="T_d225b_row1_col12" class="data row1 col12" >0.010000</td>
#       <td id="T_d225b_row1_col13" class="data row1 col13" >0.300000</td>
#       <td id="T_d225b_row1_col14" class="data row1 col14" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d225b_level0_row2" class="row_heading level0 row2" >10</th>
#       <td id="T_d225b_row2_col0" class="data row2 col0" >adult</td>
#       <td id="T_d225b_row2_col1" class="data row2 col1" >rtvae_syn</td>
#       <td id="T_d225b_row2_col2" class="data row2 col2" >tabular</td>
#       <td id="T_d225b_row2_col3" class="data row2 col3" >0.730000</td>
#       <td id="T_d225b_row2_col4" class="data row2 col4" >0.980000</td>
#       <td id="T_d225b_row2_col5" class="data row2 col5" >0.390000</td>
#       <td id="T_d225b_row2_col6" class="data row2 col6" >1.000000</td>
#       <td id="T_d225b_row2_col7" class="data row2 col7" >0.770000</td>
#       <td id="T_d225b_row2_col8" class="data row2 col8" >0.740000</td>
#       <td id="T_d225b_row2_col9" class="data row2 col9" >0.980000</td>
#       <td id="T_d225b_row2_col10" class="data row2 col10" >0.650000</td>
#       <td id="T_d225b_row2_col11" class="data row2 col11" >0.730000</td>
#       <td id="T_d225b_row2_col12" class="data row2 col12" >0.020000</td>
#       <td id="T_d225b_row2_col13" class="data row2 col13" >0.480000</td>
#       <td id="T_d225b_row2_col14" class="data row2 col14" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
subset = all_df[all_df["model"].isin(["rtvae_syn", "tvae_sdv", "tvae_syn"])  & (all_df["case"] == "tabular") & (all_df["dataset"] == "health_insurance")]
df_style = subset.style.apply(lambda s: highlight_top3_min3(s, skip_cols=skip_cols, min_cols=min_cols))
df_style
# Out:
# <style type="text/css">
# #T_ef84a_row0_col3, #T_ef84a_row0_col7, #T_ef84a_row0_col8, #T_ef84a_row0_col10, #T_ef84a_row0_col12, #T_ef84a_row1_col5, #T_ef84a_row1_col9, #T_ef84a_row1_col13, #T_ef84a_row2_col4, #T_ef84a_row2_col11, #T_ef84a_row2_col12 {
#   background-color: #FFB347;
# }
# #T_ef84a_row0_col4, #T_ef84a_row0_col11, #T_ef84a_row2_col3, #T_ef84a_row2_col5, #T_ef84a_row2_col7, #T_ef84a_row2_col9, #T_ef84a_row2_col10, #T_ef84a_row2_col13 {
#   background-color: #fdfd96;
# }
# #T_ef84a_row0_col5, #T_ef84a_row0_col6, #T_ef84a_row0_col9, #T_ef84a_row0_col13, #T_ef84a_row0_col14, #T_ef84a_row1_col3, #T_ef84a_row1_col4, #T_ef84a_row1_col6, #T_ef84a_row1_col7, #T_ef84a_row1_col8, #T_ef84a_row1_col10, #T_ef84a_row1_col11, #T_ef84a_row1_col12, #T_ef84a_row1_col14, #T_ef84a_row2_col6, #T_ef84a_row2_col8, #T_ef84a_row2_col14 {
#   background-color: #77dd77;
# }
# </style>
# <table id="T_ef84a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ef84a_level0_col0" class="col_heading level0 col0" >dataset</th>
#       <th id="T_ef84a_level0_col1" class="col_heading level0 col1" >model</th>
#       <th id="T_ef84a_level0_col2" class="col_heading level0 col2" >case</th>
#       <th id="T_ef84a_level0_col3" class="col_heading level0 col3" >domain_cov</th>
#       <th id="T_ef84a_level0_col4" class="col_heading level0 col4" >stats_cov</th>
#       <th id="T_ef84a_level0_col5" class="col_heading level0 col5" >outliers_cov</th>
#       <th id="T_ef84a_level0_col6" class="col_heading level0 col6" >missing_cov</th>
#       <th id="T_ef84a_level0_col7" class="col_heading level0 col7" >ks_sim</th>
#       <th id="T_ef84a_level0_col8" class="col_heading level0 col8" >tv_sim</th>
#       <th id="T_ef84a_level0_col9" class="col_heading level0 col9" >corr_sim</th>
#       <th id="T_ef84a_level0_col10" class="col_heading level0 col10" >contin_sim</th>
#       <th id="T_ef84a_level0_col11" class="col_heading level0 col11" >sdv_quality_report</th>
#       <th id="T_ef84a_level0_col12" class="col_heading level0 col12" >wass_dist</th>
#       <th id="T_ef84a_level0_col13" class="col_heading level0 col13" >js_dist</th>
#       <th id="T_ef84a_level0_col14" class="col_heading level0 col14" >new_row_synthesis</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ef84a_level0_row0" class="row_heading level0 row0" >56</th>
#       <td id="T_ef84a_row0_col0" class="data row0 col0" >health_insurance</td>
#       <td id="T_ef84a_row0_col1" class="data row0 col1" >tvae_sdv</td>
#       <td id="T_ef84a_row0_col2" class="data row0 col2" >tabular</td>
#       <td id="T_ef84a_row0_col3" class="data row0 col3" >0.910000</td>
#       <td id="T_ef84a_row0_col4" class="data row0 col4" >0.950000</td>
#       <td id="T_ef84a_row0_col5" class="data row0 col5" >0.670000</td>
#       <td id="T_ef84a_row0_col6" class="data row0 col6" >1.000000</td>
#       <td id="T_ef84a_row0_col7" class="data row0 col7" >0.810000</td>
#       <td id="T_ef84a_row0_col8" class="data row0 col8" >0.820000</td>
#       <td id="T_ef84a_row0_col9" class="data row0 col9" >0.980000</td>
#       <td id="T_ef84a_row0_col10" class="data row0 col10" >0.740000</td>
#       <td id="T_ef84a_row0_col11" class="data row0 col11" >0.800000</td>
#       <td id="T_ef84a_row0_col12" class="data row0 col12" >0.070000</td>
#       <td id="T_ef84a_row0_col13" class="data row0 col13" >0.200000</td>
#       <td id="T_ef84a_row0_col14" class="data row0 col14" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ef84a_level0_row1" class="row_heading level0 row1" >59</th>
#       <td id="T_ef84a_row1_col0" class="data row1 col0" >health_insurance</td>
#       <td id="T_ef84a_row1_col1" class="data row1 col1" >tvae_syn</td>
#       <td id="T_ef84a_row1_col2" class="data row1 col2" >tabular</td>
#       <td id="T_ef84a_row1_col3" class="data row1 col3" >0.930000</td>
#       <td id="T_ef84a_row1_col4" class="data row1 col4" >0.980000</td>
#       <td id="T_ef84a_row1_col5" class="data row1 col5" >0.330000</td>
#       <td id="T_ef84a_row1_col6" class="data row1 col6" >1.000000</td>
#       <td id="T_ef84a_row1_col7" class="data row1 col7" >0.890000</td>
#       <td id="T_ef84a_row1_col8" class="data row1 col8" >0.960000</td>
#       <td id="T_ef84a_row1_col9" class="data row1 col9" >0.960000</td>
#       <td id="T_ef84a_row1_col10" class="data row1 col10" >0.860000</td>
#       <td id="T_ef84a_row1_col11" class="data row1 col11" >0.900000</td>
#       <td id="T_ef84a_row1_col12" class="data row1 col12" >0.030000</td>
#       <td id="T_ef84a_row1_col13" class="data row1 col13" >0.260000</td>
#       <td id="T_ef84a_row1_col14" class="data row1 col14" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ef84a_level0_row2" class="row_heading level0 row2" >64</th>
#       <td id="T_ef84a_row2_col0" class="data row2 col0" >health_insurance</td>
#       <td id="T_ef84a_row2_col1" class="data row2 col1" >rtvae_syn</td>
#       <td id="T_ef84a_row2_col2" class="data row2 col2" >tabular</td>
#       <td id="T_ef84a_row2_col3" class="data row2 col3" >0.830000</td>
#       <td id="T_ef84a_row2_col4" class="data row2 col4" >0.960000</td>
#       <td id="T_ef84a_row2_col5" class="data row2 col5" >0.000000</td>
#       <td id="T_ef84a_row2_col6" class="data row2 col6" >1.000000</td>
#       <td id="T_ef84a_row2_col7" class="data row2 col7" >0.780000</td>
#       <td id="T_ef84a_row2_col8" class="data row2 col8" >0.960000</td>
#       <td id="T_ef84a_row2_col9" class="data row2 col9" >0.900000</td>
#       <td id="T_ef84a_row2_col10" class="data row2 col10" >0.730000</td>
#       <td id="T_ef84a_row2_col11" class="data row2 col11" >0.820000</td>
#       <td id="T_ef84a_row2_col12" class="data row2 col12" >0.070000</td>
#       <td id="T_ef84a_row2_col13" class="data row2 col13" >0.530000</td>
#       <td id="T_ef84a_row2_col14" class="data row2 col14" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# subset = all_df[all_df["model"].isin(["rtvae_syn", "tvae_sdv", "tvae_syn"])  & (all_df["case"] == "tabular") & (all_df["dataset"] == "drugs")]
# df_style = subset.style.apply(lambda s: highlight_top3_min3(s, skip_cols=skip_cols, min_cols=min_cols))
# df_style

# %%
subset = all_df[all_df["model"].isin(["rtvae_syn", "tvae_sdv", "tvae_syn"])  & (all_df["case"] == "tabular") & (all_df["dataset"] == "loan")]
df_style = subset.style.apply(lambda s: highlight_top3_min3(s, skip_cols=skip_cols, min_cols=min_cols))
df_style
# Out:
# <style type="text/css">
# #T_fd99b_row0_col3, #T_fd99b_row0_col4, #T_fd99b_row0_col12, #T_fd99b_row1_col5, #T_fd99b_row1_col13, #T_fd99b_row2_col7, #T_fd99b_row2_col8, #T_fd99b_row2_col9, #T_fd99b_row2_col10, #T_fd99b_row2_col11 {
#   background-color: #FFB347;
# }
# #T_fd99b_row0_col5, #T_fd99b_row0_col7, #T_fd99b_row0_col8, #T_fd99b_row0_col10, #T_fd99b_row0_col11, #T_fd99b_row2_col3, #T_fd99b_row2_col13 {
#   background-color: #fdfd96;
# }
# #T_fd99b_row0_col6, #T_fd99b_row0_col9, #T_fd99b_row0_col13, #T_fd99b_row0_col14, #T_fd99b_row1_col3, #T_fd99b_row1_col4, #T_fd99b_row1_col6, #T_fd99b_row1_col7, #T_fd99b_row1_col8, #T_fd99b_row1_col9, #T_fd99b_row1_col10, #T_fd99b_row1_col11, #T_fd99b_row1_col12, #T_fd99b_row1_col14, #T_fd99b_row2_col4, #T_fd99b_row2_col5, #T_fd99b_row2_col6, #T_fd99b_row2_col12, #T_fd99b_row2_col14 {
#   background-color: #77dd77;
# }
# </style>
# <table id="T_fd99b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fd99b_level0_col0" class="col_heading level0 col0" >dataset</th>
#       <th id="T_fd99b_level0_col1" class="col_heading level0 col1" >model</th>
#       <th id="T_fd99b_level0_col2" class="col_heading level0 col2" >case</th>
#       <th id="T_fd99b_level0_col3" class="col_heading level0 col3" >domain_cov</th>
#       <th id="T_fd99b_level0_col4" class="col_heading level0 col4" >stats_cov</th>
#       <th id="T_fd99b_level0_col5" class="col_heading level0 col5" >outliers_cov</th>
#       <th id="T_fd99b_level0_col6" class="col_heading level0 col6" >missing_cov</th>
#       <th id="T_fd99b_level0_col7" class="col_heading level0 col7" >ks_sim</th>
#       <th id="T_fd99b_level0_col8" class="col_heading level0 col8" >tv_sim</th>
#       <th id="T_fd99b_level0_col9" class="col_heading level0 col9" >corr_sim</th>
#       <th id="T_fd99b_level0_col10" class="col_heading level0 col10" >contin_sim</th>
#       <th id="T_fd99b_level0_col11" class="col_heading level0 col11" >sdv_quality_report</th>
#       <th id="T_fd99b_level0_col12" class="col_heading level0 col12" >wass_dist</th>
#       <th id="T_fd99b_level0_col13" class="col_heading level0 col13" >js_dist</th>
#       <th id="T_fd99b_level0_col14" class="col_heading level0 col14" >new_row_synthesis</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fd99b_level0_row0" class="row_heading level0 row0" >87</th>
#       <td id="T_fd99b_row0_col0" class="data row0 col0" >loan</td>
#       <td id="T_fd99b_row0_col1" class="data row0 col1" >tvae_sdv</td>
#       <td id="T_fd99b_row0_col2" class="data row0 col2" >tabular</td>
#       <td id="T_fd99b_row0_col3" class="data row0 col3" >0.910000</td>
#       <td id="T_fd99b_row0_col4" class="data row0 col4" >0.950000</td>
#       <td id="T_fd99b_row0_col5" class="data row0 col5" >0.200000</td>
#       <td id="T_fd99b_row0_col6" class="data row0 col6" >1.000000</td>
#       <td id="T_fd99b_row0_col7" class="data row0 col7" >0.820000</td>
#       <td id="T_fd99b_row0_col8" class="data row0 col8" >0.850000</td>
#       <td id="T_fd99b_row0_col9" class="data row0 col9" >0.960000</td>
#       <td id="T_fd99b_row0_col10" class="data row0 col10" >0.790000</td>
#       <td id="T_fd99b_row0_col11" class="data row0 col11" >0.830000</td>
#       <td id="T_fd99b_row0_col12" class="data row0 col12" >0.070000</td>
#       <td id="T_fd99b_row0_col13" class="data row0 col13" >0.250000</td>
#       <td id="T_fd99b_row0_col14" class="data row0 col14" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fd99b_level0_row1" class="row_heading level0 row1" >90</th>
#       <td id="T_fd99b_row1_col0" class="data row1 col0" >loan</td>
#       <td id="T_fd99b_row1_col1" class="data row1 col1" >tvae_syn</td>
#       <td id="T_fd99b_row1_col2" class="data row1 col2" >tabular</td>
#       <td id="T_fd99b_row1_col3" class="data row1 col3" >0.930000</td>
#       <td id="T_fd99b_row1_col4" class="data row1 col4" >0.970000</td>
#       <td id="T_fd99b_row1_col5" class="data row1 col5" >0.360000</td>
#       <td id="T_fd99b_row1_col6" class="data row1 col6" >1.000000</td>
#       <td id="T_fd99b_row1_col7" class="data row1 col7" >0.880000</td>
#       <td id="T_fd99b_row1_col8" class="data row1 col8" >0.970000</td>
#       <td id="T_fd99b_row1_col9" class="data row1 col9" >0.960000</td>
#       <td id="T_fd99b_row1_col10" class="data row1 col10" >0.890000</td>
#       <td id="T_fd99b_row1_col11" class="data row1 col11" >0.920000</td>
#       <td id="T_fd99b_row1_col12" class="data row1 col12" >0.040000</td>
#       <td id="T_fd99b_row1_col13" class="data row1 col13" >0.270000</td>
#       <td id="T_fd99b_row1_col14" class="data row1 col14" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fd99b_level0_row2" class="row_heading level0 row2" >95</th>
#       <td id="T_fd99b_row2_col0" class="data row2 col0" >loan</td>
#       <td id="T_fd99b_row2_col1" class="data row2 col1" >rtvae_syn</td>
#       <td id="T_fd99b_row2_col2" class="data row2 col2" >tabular</td>
#       <td id="T_fd99b_row2_col3" class="data row2 col3" >0.860000</td>
#       <td id="T_fd99b_row2_col4" class="data row2 col4" >0.970000</td>
#       <td id="T_fd99b_row2_col5" class="data row2 col5" >0.400000</td>
#       <td id="T_fd99b_row2_col6" class="data row2 col6" >1.000000</td>
#       <td id="T_fd99b_row2_col7" class="data row2 col7" >0.850000</td>
#       <td id="T_fd99b_row2_col8" class="data row2 col8" >0.960000</td>
#       <td id="T_fd99b_row2_col9" class="data row2 col9" >0.950000</td>
#       <td id="T_fd99b_row2_col10" class="data row2 col10" >0.810000</td>
#       <td id="T_fd99b_row2_col11" class="data row2 col11" >0.870000</td>
#       <td id="T_fd99b_row2_col12" class="data row2 col12" >0.040000</td>
#       <td id="T_fd99b_row2_col13" class="data row2 col13" >0.480000</td>
#       <td id="T_fd99b_row2_col14" class="data row2 col14" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
subset = all_df[all_df["model"].isin(["rtvae_syn", "tvae_sdv", "tvae_syn"])  & (all_df["case"] == "tabular") & (all_df["dataset"] == "intrusion")]
df_style = subset.style.apply(lambda s: highlight_top3_min3(s, skip_cols=skip_cols, min_cols=min_cols))
df_style
# Out:
# <style type="text/css">
# #T_754fc_row0_col3, #T_754fc_row0_col5, #T_754fc_row0_col9, #T_754fc_row0_col14, #T_754fc_row1_col4, #T_754fc_row1_col7, #T_754fc_row1_col8, #T_754fc_row1_col11, #T_754fc_row1_col13 {
#   background-color: #FFB347;
# }
# #T_754fc_row0_col4, #T_754fc_row0_col6, #T_754fc_row0_col7, #T_754fc_row0_col8, #T_754fc_row0_col10, #T_754fc_row0_col11, #T_754fc_row0_col12, #T_754fc_row0_col13, #T_754fc_row1_col3, #T_754fc_row1_col5, #T_754fc_row1_col6, #T_754fc_row1_col9, #T_754fc_row1_col10, #T_754fc_row1_col12, #T_754fc_row1_col14 {
#   background-color: #77dd77;
# }
# </style>
# <table id="T_754fc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_754fc_level0_col0" class="col_heading level0 col0" >dataset</th>
#       <th id="T_754fc_level0_col1" class="col_heading level0 col1" >model</th>
#       <th id="T_754fc_level0_col2" class="col_heading level0 col2" >case</th>
#       <th id="T_754fc_level0_col3" class="col_heading level0 col3" >domain_cov</th>
#       <th id="T_754fc_level0_col4" class="col_heading level0 col4" >stats_cov</th>
#       <th id="T_754fc_level0_col5" class="col_heading level0 col5" >outliers_cov</th>
#       <th id="T_754fc_level0_col6" class="col_heading level0 col6" >missing_cov</th>
#       <th id="T_754fc_level0_col7" class="col_heading level0 col7" >ks_sim</th>
#       <th id="T_754fc_level0_col8" class="col_heading level0 col8" >tv_sim</th>
#       <th id="T_754fc_level0_col9" class="col_heading level0 col9" >corr_sim</th>
#       <th id="T_754fc_level0_col10" class="col_heading level0 col10" >contin_sim</th>
#       <th id="T_754fc_level0_col11" class="col_heading level0 col11" >sdv_quality_report</th>
#       <th id="T_754fc_level0_col12" class="col_heading level0 col12" >wass_dist</th>
#       <th id="T_754fc_level0_col13" class="col_heading level0 col13" >js_dist</th>
#       <th id="T_754fc_level0_col14" class="col_heading level0 col14" >new_row_synthesis</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_754fc_level0_row0" class="row_heading level0 row0" >69</th>
#       <td id="T_754fc_row0_col0" class="data row0 col0" >intrusion</td>
#       <td id="T_754fc_row0_col1" class="data row0 col1" >tvae_sdv</td>
#       <td id="T_754fc_row0_col2" class="data row0 col2" >tabular</td>
#       <td id="T_754fc_row0_col3" class="data row0 col3" >0.630000</td>
#       <td id="T_754fc_row0_col4" class="data row0 col4" >0.990000</td>
#       <td id="T_754fc_row0_col5" class="data row0 col5" >0.150000</td>
#       <td id="T_754fc_row0_col6" class="data row0 col6" >1.000000</td>
#       <td id="T_754fc_row0_col7" class="data row0 col7" >0.910000</td>
#       <td id="T_754fc_row0_col8" class="data row0 col8" >0.970000</td>
#       <td id="T_754fc_row0_col9" class="data row0 col9" >0.930000</td>
#       <td id="T_754fc_row0_col10" class="data row0 col10" >0.870000</td>
#       <td id="T_754fc_row0_col11" class="data row0 col11" >0.910000</td>
#       <td id="T_754fc_row0_col12" class="data row0 col12" >0.020000</td>
#       <td id="T_754fc_row0_col13" class="data row0 col13" >0.150000</td>
#       <td id="T_754fc_row0_col14" class="data row0 col14" >0.960000</td>
#     </tr>
#     <tr>
#       <th id="T_754fc_level0_row1" class="row_heading level0 row1" >72</th>
#       <td id="T_754fc_row1_col0" class="data row1 col0" >intrusion</td>
#       <td id="T_754fc_row1_col1" class="data row1 col1" >tvae_syn</td>
#       <td id="T_754fc_row1_col2" class="data row1 col2" >tabular</td>
#       <td id="T_754fc_row1_col3" class="data row1 col3" >0.760000</td>
#       <td id="T_754fc_row1_col4" class="data row1 col4" >0.950000</td>
#       <td id="T_754fc_row1_col5" class="data row1 col5" >0.350000</td>
#       <td id="T_754fc_row1_col6" class="data row1 col6" >1.000000</td>
#       <td id="T_754fc_row1_col7" class="data row1 col7" >0.810000</td>
#       <td id="T_754fc_row1_col8" class="data row1 col8" >0.950000</td>
#       <td id="T_754fc_row1_col9" class="data row1 col9" >0.970000</td>
#       <td id="T_754fc_row1_col10" class="data row1 col10" >0.870000</td>
#       <td id="T_754fc_row1_col11" class="data row1 col11" >0.890000</td>
#       <td id="T_754fc_row1_col12" class="data row1 col12" >0.020000</td>
#       <td id="T_754fc_row1_col13" class="data row1 col13" >0.180000</td>
#       <td id="T_754fc_row1_col14" class="data row1 col14" >0.990000</td>
#     </tr>
#   </tbody>
# </table>

# %%
subset = all_df[all_df["model"].isin(["rtvae_syn", "tvae_sdv", "tvae_syn"])  & (all_df["case"] == "tabular") & (all_df["dataset"] == "credit")]
df_style = subset.style.apply(lambda s: highlight_top3_min3(s, skip_cols=skip_cols, min_cols=min_cols))
df_style
# Out:
# <style type="text/css">
# #T_d0dde_row0_col3, #T_d0dde_row0_col5, #T_d0dde_row0_col9, #T_d0dde_row0_col10, #T_d0dde_row0_col13, #T_d0dde_row0_col14 {
#   background-color: #fdfd96;
# }
# #T_d0dde_row0_col4, #T_d0dde_row0_col11, #T_d0dde_row1_col14, #T_d0dde_row2_col3, #T_d0dde_row2_col5, #T_d0dde_row2_col7, #T_d0dde_row2_col9, #T_d0dde_row2_col10, #T_d0dde_row2_col11, #T_d0dde_row2_col13 {
row2_col6" class="data row2 col6" >1.000000</td>
#       <td id="T_d0dde_row2_col7" class="data row2 col7" >0.920000</td>
#       <td id="T_d0dde_row2_col8" class="data row2 col8" >1.000000</td>
#       <td id="T_d0dde_row2_col9" class="data row2 col9" >0.970000</td>
#       <td id="T_d0dde_row2_col10" class="data row2 col10" >0.550000</td>
#       <td id="T_d0dde_row2_col11" class="data row2 col11" >0.930000</td>
#       <td id="T_d0dde_row2_col12" class="data row2 col12" >0.010000</td>
#       <td id="T_d0dde_row2_col13" class="data row2 col13" >0.110000</td>
#       <td id="T_d0dde_row2_col14" class="data row2 col14" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Execution Benchmarking

# %%
execution_scores_df.columns
# Out:
# Index(['dataset', 'lib', 'model', 'num_rows', 'num_cols', 'num_sampled_rows',
#        'device', 'num_epochs', 'train_time_sec', 'sample_time_sec',
#        'peak_memory_mb', 'synthesizer_size', 'synthetic_dataset_size_mb_deep',
#        'train_dataset_size_mb_deep', 'synthetic_dataset_size_mb',
#        'train_dataset_size_mb'],
#       dtype='object')

# %%
execution_scores_df.to_csv("execution_scores.csv")

# %%
std_tabular_df[std_tabular_df["model"] == "ctgan_sdv"].style.highlight_max(color='#ffb6c1')
# Out:
# <style type="text/css">
# #T_1f8a5_row0_col1, #T_1f8a5_row0_col2, #T_1f8a5_row0_col6, #T_1f8a5_row0_col14, #T_1f8a5_row1_col1, #T_1f8a5_row1_col2, #T_1f8a5_row2_col1, #T_1f8a5_row2_col2, #T_1f8a5_row2_col6, #T_1f8a5_row2_col14, #T_1f8a5_row3_col1, #T_1f8a5_row3_col2, #T_1f8a5_row3_col4, #T_1f8a5_row3_col6, #T_1f8a5_row3_col7, #T_1f8a5_row3_col8, #T_1f8a5_row3_col11, #T_1f8a5_row4_col1, #T_1f8a5_row4_col2, #T_1f8a5_row4_col3, #T_1f8a5_row4_col6, #T_1f8a5_row4_col12, #T_1f8a5_row4_col13, #T_1f8a5_row4_col14, #T_1f8a5_row5_col1, #T_1f8a5_row5_col2, #T_1f8a5_row5_col6, #T_1f8a5_row6_col1, #T_1f8a5_row6_col2, #T_1f8a5_row6_col5, #T_1f8a5_row7_col1, #T_1f8a5_row7_col2, #T_1f8a5_row7_col6, #T_1f8a5_row7_col14, #T_1f8a5_row8_col0, #T_1f8a5_row8_col1, #T_1f8a5_row8_col2, #T_1f8a5_row8_col6, #T_1f8a5_row8_col9, #T_1f8a5_row8_col10, #T_1f8a5_row8_col14 {
#   background-color: #ffb6c1;
# }
# </style>
# <table id="T_1f8a5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1f8a5_level0_col0" class="col_heading level0 col0" >dataset</th>
#       <th id="T_1f8a5_level0_col1" class="col_heading level0 col1" >model</th>
#       <th id="T_1f8a5_level0_col2" class="col_heading level0 col2" >case</th>
#       <th id="T_1f8a5_level0_col3" class="col_heading level0 col3" >domain_cov</th>
#       <th id="T_1f8a5_level0_col4" class="col_heading level0 col4" >stats_cov</th>
#       <th id="T_1f8a5_level0_col5" class="col_heading level0 col5" >outliers_cov</th>
#       <th id="T_1f8a5_level0_col6" class="col_heading level0 col6" >missing_cov</th>
#       <th id="T_1f8a5_level0_col7" class="col_heading level0 col7" >ks_sim</th>
#       <th id="T_1f8a5_level0_col8" class="col_heading level0 col8" >tv_sim</th>
#       <th id="T_1f8a5_level0_col9" class="col_heading level0 col9" >corr_sim</th>
#       <th id="T_1f8a5_level0_col10" class="col_heading level0 col10" >contin_sim</th>
#       <th id="T_1f8a5_level0_col11" class="col_heading level0 col11" >sdv_quality_report</th>
#       <th id="T_1f8a5_level0_col12" class="col_heading level0 col12" >wass_dist</th>
#       <th id="T_1f8a5_level0_col13" class="col_heading level0 col13" >js_dist</th>
#       <th id="T_1f8a5_level0_col14" class="col_heading level0 col14" >new_row_synthesis</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1f8a5_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_1f8a5_row0_col0" class="data row0 col0" >adult</td>
#       <td id="T_1f8a5_row0_col1" class="data row0 col1" >ctgan_sdv</td>
#       <td id="T_1f8a5_row0_col2" class="data row0 col2" >tabular</td>
#       <td id="T_1f8a5_row0_col3" class="data row0 col3" >0.870000</td>
#       <td id="T_1f8a5_row0_col4" class="data row0 col4" >0.990000</td>
#       <td id="T_1f8a5_row0_col5" class="data row0 col5" >0.790000</td>
#       <td id="T_1f8a5_row0_col6" class="data row0 col6" >1.000000</td>
#       <td id="T
>0.920000</td>
#     </tr>
#     <tr>
#       <th id="T_1f8a5_level0_row4" class="row_heading level0 row4" >55</th>
#       <td id="T_1f8a5_row4_col0" class="data row4 col0" >health_insurance</td>
#       <td id="T_1f8a5_row4_col1" class="data row4 col1" >ctgan_sdv</td>
#       <td id="T_1f8a5_row4_col2" class="data row4 col2" >tabular</td>
#       <td id="T_1f8a5_row4_col3" class="data row4 col3" >0.980000</td>
#       <td id="T_1f8a5_row4_col4" class="data row4 col4" >0.890000</td>
#       <td id="T_1f8a5_row4_col5" class="data row4 col5" >0.350000</td>
#       <td id="T_1f8a5_row4_col6" class="data row4 col6" >1.000000</td>
#       <td id="T_1f8a5_row4_col7" class="data row4 col7" >0.750000</td>
#       <td id="T_1f8a5_row4_col8" class="data row4 col8" >0.880000</td>
#       <td id="T_1f8a5_row4_col9" class="data row4 col9" >0.890000</td>
#       <td id="T_1f8a5_row4_col10" class="data row4 col10" >0.810000</td>
#       <td id="T_1f8a5_row4_col11" class="data row4 col11" >0.820000</td>
#       <td id="T_1f8a5_row4_col12" class="data row4 col12" >0.130000</td>
#       <td id="T_1f8a5_row4_col13" c

# %%
# df.style.apply(highlight_top3)
std_tabular_df[std_tabular_df["dataset"] == "adult"].style.apply(highlight_top3)
# Out:
# <style type="text/css">
# #T_df09a_row0_col4, #T_df09a_row0_col10, #T_df09a_row1_col4, #T_df09a_row1_col5, #T_df09a_row2_col4, #T_df09a_row2_col8, #T_df09a_row4_col4, #T_df09a_row4_col13, #T_df09a_row5_col4, #T_df09a_row7_col10, #T_df09a_row7_col11, #T_df09a_row9_col3, #T_df09a_row11_col12, #T_df09a_row12_col4, #T_df09a_row13_col3, #T_df09a_row13_col4, #T_df09a_row13_col7, #T_df09a_row13_col8 {
#   background-color: grey;
# }
# #T_df09a_row0_col6, #T_df09a_row0_col14, #T_df09a_row1_col6, #T_df09a_row1_col14, #T_df09a_row2_col6, #T_df09a_row2_col14, #T_df09a_row3_col6, #T_df09a_row3_col9, #T_df09a_row3_col12, #T_df09a_row3_col14, #T_df09a_row4_col6, #T_df09a_row4_col14, #T_df09a_row5_col6, #T_df09a_row5_col9, #T_df09a_row5_col14, #T_df09a_row6_col6, #T_df09a_row6_col13, #T_df09a_row6_col14, #T_df09a_row7_col3, #T_df09a_row7_col4, #T_df09a_row7_col6, #T_df09a_row7_col9, #T_df09a_row7_col14, #T_df09a_row8_col3, #T_df09a_row8_col4, #T_df09a_row8_col6, #T_df09a_row8_col7, #T_df09a_row8_col8, #T_df09a_row8_col10, #T_df09a_row8_col11, #T_df09a_row8_col14, #T_df09a_row9_col6, #T_df09a_row9_col14, #T_df09a_row10_col6, #T_df09a_row10_col14, #T_df09a_row11_col6, #T_df09a_row12_col5, #T_df09a_row12_col6, #T_df09a_row12_col14, #T_df09a_row13_col6, #T_df09a_row13_col14 {
#   background-color: gold;
# }
# #T_df09a_row2_col10, #T_df09a_row2_col11, #T_df09a_row6_col12, #T_df09a_row7_col5, #T_df09a_row10_col13, #T_df09a_row12_col7, #T_df09a_row12_col8 {
#   background-color: pink;
# }
# </style>
# <table id="T_df09a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_df09a_level0_col0" class="col_heading level0 col0" >dataset</th>
#       <th id="T_df09a_level0_col1" class="col_heading level0 col1" >model</th>
#       <th id="T_df09a_level0_col2" class="col_heading level0 col2" >case</th>
#       <th id="T_df09a_level0_col3" class="col_heading level0 col3" >domain_cov</th>
#       <th id="T_df09a_level0_col4" class="col_heading level0 col4" >stats_cov</th>
#       <th id="T_df09a_level0_col5" class="col_heading level0 col5" >outliers_cov</th>
#       <th id="T_df09a_level0_col6" class="col_heading level0 col6" >missing_cov</th>
#       <th id="T_df09a_level0_col7" class="col_heading level0 col7" >ks_sim</th>
#       <th id="T_df09a_level0_col8" class="col_heading level0 col8" >tv_sim</th>
#       <th id="T_df09a_level0_col9" class="col_heading level0 col9" >corr_sim</th>
#       <th id="T_df09a_level0_col10" class="col_heading level0 col10" >contin_sim</th>
#       <th id="T_df09a_level0_col11" class="col_heading level0 col11" >sdv_quality_report</th>
#       <th id="T_df09a_level0_col12" class="col_heading level0 col12" >wass_dist</th>
#       <th id="T_df09a_level0_col13" class="col_heading level0 col13" >js_dist</th>
#       <th id="T_df09a_level0_col14" class="col_heading level0 col14" >new_row_synthesis</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_df09a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_df09a_row0_col0" class="data row0 col0" >adult</td>
#       <td id="T_df09a_row0_col1" class="data row0 col1" >actgan_gretel</td>
#       <td id="T_df09a_row0_col2" class="data row0 col2" >tabular</td>
#       <td id="T_df09a_row0_col3" class="data row0 col3" >0.890000</td>
#       <td id="T_df09a_row0_col4" class="data row0 col4" >0.990000</td>
#       <td id="T_df09a_row0_col5" class="data row0 col5" >0.490000</td>
#       <td id="T_df09a_row0_col6" class="data row0 col6" >1.000000</td>
#       <td id="T_df09a_row0_col7" class="data row0 col7" >0.790000</td>
#       <td id="T_df09a_row0_col8" class="data row0 col8" >0.920000</td>
#       <td id="T_df09a_row0_col9" class="data row0 col9" >0.970000</td>
#       <td id="T_df09a_row0_col10" class="data row0 col10" >0.870000</td>
#       <td id="T_df09a_row0_col11" class="data row0 col11" >0.880000</td>
#       <td id="T_df09a_row0_col12" class="data row0 col12" >0.020000</td>
#       <td id="T_df09a_row0_col13" class="data row0 col13" >0.240000</td>
#       <td id="T_df09a_row0_col14" class="data row0 col14" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_df09a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_df09a_row1_col0" class="data row1 col0" >adult</td>
#       <td id="T_df09a_row1_col1" class="data row1 col1" >ctgan_sdv</td>
#       <td id="T_df09a_row1_col2" class="data row1 col2" >tabular</td>
#       <td id="T_df09a_row1_col3" class="data row1 col3" >0.870000</td>
#       <td id="T_df09a_row1_col4" class="data row1 col4" >0.990000</td>
#       <td id="T_df09a_row1_col5" class="data row1 col5" >0.790000</td>
#       <td id="T_df09a_row1_col6" class="data row1 col6" >1.000000</td>
#       <td id="T_df09a_row1_col7" class="data row1 col7" >0.870000</td>
#       <td id="T_df09a_row1_col8" class="data row1 col8" >0.910000</td>
#       <td id="T_df09a_row1_col9" class="data row1 col9" >0.980000</td>
#       <td id="T_df09a_row1_col10" class="data row1 col10" >0.820000</td>
#       <td id="T_df09a_row1_col11" class="data row1 col11" >0.870000</td>
#       <td id="T_df09a_row1_col12" class="data row1 col12" >0.020000</td>
#       <td id="T_df09a_row1_col13" class="data row1 col13" >0.220000</td>
#       <td id="T_df09a_row1_col14" class="data row1 col14" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_df09a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_df09a_row2_col0" class="data row2 col0" >adult</td>
#       <td id="T_df09a_row2_col1" class="data row2 col1" >tvae_sdv</td>
#       <td id="T_df09a_row2_col2" class="data row2 col2" >tabular</td>
#       <td id="T_df09a_row2_col3" class="data row2 col3" >0.790000</td>
#       <td id="T_df09a_row2_col4" class="data row2 col4" >0.990000</td>
#       <td id="T_df09a_row2_col5" class="data row2 col5" >0.680000</td>
#       <td id="T_df09a_row2_col6" class="data row2 col6" >1.000000</td>
#       <td id="T_df09a_row2_col7" class="data row2 col7" >0.880000</td>
#       <td id="T_df09a_row2_col8" class="data row2 col8" >0.940000</td>
#       <td id="T_df09a_row2_col9" class="data row2 col9" >0.970000</td>
#       <td id="T_df09a_row2_col10" class="data row2 col10" >0.880000</td>
#       <td id="T_df09a_row2_col11" class="data row2 col11" >0.910000</td>
#       <td id="T_df09a_row2_col12" class="data row2 col12" >0.020000</td>
#       <td id="T_df09a_row2_col13" class="data row2 col13" >0.130000</td>
#       <td id="T_df09a_row2_col14" class="data row2 col14" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_df09a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_df09a_row3_col0" class="data row3 col0" >adult</td>
#       <td id="T_df09a_row3_col1" class="data row3 col1" >gaussian_copula_sdv</td>
#       <td id="T_df09a_row3_col2" class="data row3 col2" >tabular</td>
#       <td id="T_df09a_row3_col3" class="data row3 col3" >0.920000</td>
#       <td id="T_df09a_row3_col4" class="data row3 col4" >0.950000</td>
#       <td id="T_df09a_row3_col5" class="data row3 col5" >0.410000</td>
#       <td id="T_df09a_row3_col6" class="data row3 col6" >1.000000</td>
#       <td id="T_df09a_row3_col7" class="data row3 col7" >0.700000</td>
#       <td id="T_df09a_row3_col8" class="data row3 col8" >0.800000</td>
#       <td id="T_df09a_row3_col9" class="data row3 col9" >0.990000</td>
#       <td id="T_df09a_row3_col10" class="data row3 col10" >0.730000</td>
#       <td id="T_df09a_row3_col11" class="data row3 col11" >0.760000</td>
#       <td id="T_df09a_row3_col12" class="data row3 col12" >0.070000</td>
#       <td id="T_df09a_row3_col13" class="data row3 col13" >0.290000</td>
#       <td id="T_df09a_row3_col14" class="data row3 col14" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_df09a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_df09a_row4_col0" class="data row4 col0" >adult</td>
#       <td id="T_df09a_row4_col1" class="data row4 col1" >ctgan_syn</td>
#       <td id="T_df09a_row4_col2" class="data row4 col2" >tabular</td>
#       <td id="T_df09a_row4_col3" class="data row4 col3" >0.910000</td>
#       <td id="T_df09a_row4_col4" class="data row4 col4" >0.990000</td>
#       <td id="T_df09a_row4_col

# %%
# def highlight_top3(s):
#     '''
#     Highlight the top 3 numerical values in each column with different colors.
#     Skip non-numerical columns.
#     '''
#     if s.name not in ["dataset", "lib", "model", "device", "num_sampled_rows", "synthetic_dataset_size_mb_deep", 
#                      "train_dataset_size_mb_deep", "synthetic_dataset_size_mb", "train_dataset_size_mb"]:
#     # in ['domain_cov', 'stats_cov', 'outliers_cov', 'missing_cov', 'ks_sim', 'tv_sim', 'corr_sim', 'contin_sim', 'sdv_quality_report', 'wass_dist', 'js_dist', 'new_row_synthesis']:
#         print(s.name)
#         top1 = s.nlargest(1)
#         top2 = s.nlargest(2).drop(top1.index)
#         top3 = s.nlargest(3).drop(top1.index).drop(top2.index)

#         return ['background-color: gold' if v in top1.values else
#                 'background-color: pink' if v in top2.values else
#                 'background-color: grey' if v in top3.values else ''
#                 for v in s]
#     else:
#         return ['' for _ in s]  # Return empty styling for non-numerical columns

#

# %% [markdown]
# # TODOs

# %%
# Sequential Sequences Analysis

# %%
# HPO time analysis

# %%
# Hyperimpute time analysis

# %%
# Visualisation
