# %%
import json
import pandas as pd
import statistics as stats
import re
import pprint

# %%
ALL_TABULAR_DATASETS = ["adult", "census", "child", "covtype", "credit", "insurance", "health_insurance", 
                       "intrusion", "drugs", "loan", "pums"]
ALL_TABULAR_MODELS = {
    "gretel": ["actgan"], 
    "sdv": ["ctgan", "tvae", "gaussian_copula"], 
    "syn": ["ctgan", "tvae", "goggle", "arf", "ddpm", "nflow", "rtvae"], 
    "llm": ["great"], 
    "betterdata": ["gan", "gan_dp"]
}

# %%
def get_cmds_configs(command_string):

    # Sample command string
    # command_string = "python3 run_model.py --m sequential --l sdv --s par --data nasdaq --o outputs --run_model_training --use_gpu"

    # Regular expression pattern to extract arguments for "--l", "--s", and "--data"
    pattern = r"--l (\S+).*?--s (\S+).*?--data (\S+)"

    # Use regex to find the match
    match = re.search(pattern, command_string)

    # Extract values from the match
    library = match.group(1) if match else None
    synthesizer = match.group(2) if match else None
    data = match.group(3) if match else None

    return (library, synthesizer, data)

# %%
sdg_jobs_df = pd.read_csv("../final_outs/sdg_jobs.csv")

if 'Unnamed: 0' in sdg_jobs_df.columns:
    sdg_jobs_df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
# Iterate over rows and print 'Command Parameters' for specific 'Status' values
TABULAR_INCOMPLETE_JOBS = {
    "gretel": {}, 
    "sdv": {}, 
    "syn": {}
}
for index, row in sdg_jobs_df.iterrows():
    if row['Status'] in ['Failed', 'Canceled', 'Running']:
        (library, synthesizer, data) = get_cmds_configs(row['Command Parameters'])
        if library and synthesizer and data:
            # print(library, synthesizer, data)
            
            if library == "synthcity":
                library = "syn"
            
            if synthesizer in TABULAR_INCOMPLETE_JOBS[library]:
                TABULAR_INCOMPLETE_JOBS[library][synthesizer][data] = row['Status']
            else:
                TABULAR_INCOMPLETE_JOBS[library][synthesizer] = {}
                TABULAR_INCOMPLETE_JOBS[library][synthesizer][data] = row['Status']
                
                
pprint.pprint(TABULAR_INCOMPLETE_JOBS)
# Out:
# {'gretel': {'dgan': {'pums': 'Failed'}},
#  'sdv': {'ctgan': {'insurance': 'Failed'}, 'par': {'pums': 'Failed'}},
#  'syn': {'arf': {'pums': 'Failed'},
#          'ctgan': {'covtype': 'Running',
#                    'credit': 'Canceled',
#                    'pums': 'Failed'},
#          'ddpm': {'pums': 'Canceled'},
#          'goggle': {'adult': 'Failed',
#                     'covtype': 'Failed',
#                     'intrusion': 'Failed',
#                     'loan': 'Failed',
#                     'pums': 'Running'},
#          'nflow': {'adult': 'Failed',
#                    'covtype': 'Failed',
#                    'loan': 'Failed',
#                    'pums': 'Failed'},
#          'rtvae': {'credit': 'Canceled', 'pums': 'Failed'},
#          'tvae': {'pums': 'Failed'}}}

# %%
ERROR_VAL  = -99
def get_scores_df(exp_dataset, config="tabular"):
    
    final_report = {
        "dataset": [], 
        "model": [],
        "domain_cov": [], 
        "stats_cov": [], 
        "outliers_cov": [],
        "ks_sim": [], 
        "tv_sim": [],
        "corr_sim": [], 
        "contin_sim": [], 
        "sdv_quality_report": [],
        "wass_dist": [], 
        "js_dist": [], 
        "new_row_synthesis": []
    }

    for lib, models in ALL_TABULAR_MODELS.items():
        
        if config == "hpo" and lib!= "syn":
            continue
        for model in models: 
                
            corr_file = f"../metrics_out/{config}/{model}_{lib}/{exp_dataset}/{exp_dataset}_{model}_correlation.csv"
            metrics_file = f"../metrics_out/{config}/{model}_{lib}/{exp_dataset}/{exp_dataset}_{model}_metrics.json"
            
            final_report["model"].append(f"{model}_{lib}")
            final_report["dataset"].append(exp_dataset)
            
            try:
                with open(metrics_file, 'r') as file:
                    metrics_scores = json.load(file)
                corr_df = pd.read_csv(corr_file)
            except Exception as e:
                # print(model, lib)
                status = None
                if lib in TABULAR_INCOMPLETE_JOBS and model in TABULAR_INCOMPLETE_JOBS[lib]:
                    if exp_dataset in TABULAR_INCOMPLETE_JOBS[lib][model]:
                        # print("Status: ",  TABULAR_INCOMPLETE_JOBS[lib][model][exp_dataset])
                        # print("-")
                        status = TABULAR_INCOMPLETE_JOBS[lib][model][exp_dataset]
                    else:
                        status = "Skipped"
                else:
                    status = "Skipped"
                    # print(e)
                    # print("Skipped")
                for k in final_report.keys():
                    if k not in ["model", "dataset"]: 
                        final_report[k].append(status)
                    # print(final_report)
                continue
                
            
            # print(final_report) 
            
            if metrics_scores["coverage"]["domain_coverage"].values():
                domain_coverage_mean = round(stats.mean(metrics_scores["coverage"]["domain_coverage"].values()), 2)
                final_report["domain_cov"].append(domain_coverage_mean)
            else:
                # Handle the case for empty list, e.g., append a default value or skip
                final_report["domain_cov"].append(ERROR_VAL)  # or any other default value
            
            
            if metrics_scores["coverage"]["outlier_coverage"].values():
                outlier_coverage_mean = round(stats.mean(metrics_scores["coverage"]["outlier_coverage"].values()), 2)
                final_report["outliers_cov"].append(outlier_coverage_mean)
            else:
                # Handle the case for empty list, e.g., append a default value or skip
                final_report["outliers_cov"].append(ERROR_VAL)  # or any other default value

            # final_report["outliers_cov"].append(round(stats.mean(metrics_scores["coverage"]["outlier_coverage"].values()), 2))

            # Initialize total and count variables
            total_average = 0
            count = 0
            # Calculate the average of mean, median, and std for each column
            for c, s in metrics_scores["similarity"]["statistic"].items():
                column_average = (s["mean"] + s["median"] + s["std"]) / 3
                total_average += column_average
                count += 1
            # Calculate the overall average
            overall_average = total_average / count if count > 0 else ERROR_VAL
            final_report["stats_cov"].append(round(overall_average, 2))


            ks_scores = []
            tv_scores = []
            for key, value in metrics_scores["sdv_quality_report"]["distribution"].items():
                if value["metric"] == "KSComplement":
                    ks_scores.append(value["score"])
                elif value["metric"] == "TVComplement":
                    tv_scores.append(value["score"])

            # Calculating averages
            ks_average = stats.mean(ks_scores) if ks_scores else ERROR_VAL
            tv_average = stats.mean(tv_scores) if tv_scores else ERROR_VAL
            final_report["ks_sim"].append(round(ks_average, 2))
            final_report["tv_sim"].append(round(tv_average, 2))


            # contingency_average, correlation_average
            contingency_average = corr_df[corr_df['Metric'] == 'ContingencySimilarity']["Score"].mean()
            correlation_average = corr_df[corr_df['Metric'] == 'CorrelationSimilarity']["Score"].mean()

            final_report["contin_sim"].append(round(contingency_average, 2))
            final_report["corr_sim"].append(round(correlation_average, 2))

            final_report["sdv_quality_report"].append(round(metrics_scores["sdv_quality_report"]["score"], 2))
            
            if metrics_scores["similarity"]["js_distance"].values():
                js_dist_mean = round(stats.mean(metrics_scores["similarity"]["js_distance"].values()), 2)
                final_report["js_dist"].append(js_dist_mean)
            else:
                # Handle the case for empty list, e.g., append a default value or skip
                final_report["js_dist"].append(ERROR_VAL)  # or any other default value
                
            if metrics_scores["similarity"]["wass_distance"].values():
                wass_dist_mean = round(stats.mean(metrics_scores["similarity"]["wass_distance"].values()), 2)
                final_report["wass_dist"].append(wass_dist_mean)
            else:
                # Handle the case for empty list, e.g., append a default value or skip
                final_report["wass_dist"].append(ERROR_VAL)  # or any other default value

            # # final_report["js_dist"].append(round(stats.mean(metrics_scores["similarity"]["js_distance"].values()), 2))
            # final_report["wass_dist"].append(round(stats.mean(metrics_scores["similarity"]["wass_distance"].values()), 2))
            
            if "score" in metrics_scores["privacy"]["new_row_synthesis"]:
                final_report["new_row_synthesis"].append(round(metrics_scores["privacy"]["new_row_synthesis"]["score"], 2))
            else:
                final_report["new_row_synthesis"].append(ERROR_VAL)
            
    return final_report

# %%
# # exp_dataset = "adult"
# ALL_TABULAR_DATASETS = ["adult", "loan"]

# for exp_dataset in ALL_TABULAR_DATASETS:
    
#     final_report =
    
#     try:
#         pd.DataFrame(final_report)
#     except Exception as e:
#         print(e)
#         print("~"*10, exp_dataset)
#         for k, v in final_report.items():
#             print(k, len(v))
            
pd.DataFrame( get_scores_df("adult", "hpo"))
# Out:
#   dataset       model domain_cov stats_cov outliers_cov  ks_sim  tv_sim  \
# 0   adult   ctgan_syn       0.94      0.99         0.59     0.8    0.83
# 1   adult    tvae_syn       0.92      0.99         0.57     0.9    0.85
# 2   adult  goggle_syn     Failed    Failed       Failed  Failed  Failed
# 3   adult     arf_syn       0.98       1.0         0.81     0.9    0.92
# 4   adult    ddpm_syn       0.99       1.0         0.72    0.98    0.97
# 5   adult   nflow_syn     Failed    Failed       Failed  Failed  Failed
# 6   adult   rtvae_syn       0.96      0.98         0.95    0.84     0.8
#
#   corr_sim contin_sim sdv_quality_report wass_dist js_dist new_row_synthesis
# 0     0.98       0.76               0.81      0.01    0.27               1.0
# 1     0.99        0.8               0.85      0.01    0.19               1.0
# 2   Failed     Failed             Failed    Failed  Failed            Failed
# 3     0.99       0.87                0.9      0.01    0.16               1.0
# 4     0.99       0.94               0.96      0.01    0.07               1.0
# 5   Failed     Failed             Failed    Failed  Failed            Failed
# 6     0.96       0.74               0.79      0.03    0.23               1.0

# %%
pd.DataFrame( get_scores_df("loan", "hpo"))
# Out:
#   dataset       model domain_cov stats_cov outliers_cov  ks_sim  tv_sim  \
# 0    loan   ctgan_syn       0.97      0.99          0.4    0.91    0.98
# 1    loan    tvae_syn       0.95      0.98         0.35    0.93    0.98
# 2    loan  goggle_syn     Failed    Failed       Failed  Failed  Failed
# 3    loan     arf_syn        1.0      0.99         0.46     0.9    0.99
# 4    loan    ddpm_syn        1.0      0.94         0.45    0.95    0.97
# 5    loan   nflow_syn     Failed    Failed       Failed  Failed  Failed
# 6    loan   rtvae_syn       0.87      0.97         0.35    0.87    0.98
#
#   corr_sim contin_sim sdv_quality_report wass_dist js_dist new_row_synthesis
# 0     0.96       0.93               0.94      0.03    0.17               1.0
# 1     0.96       0.92               0.94      0.02    0.19               1.0
# 2   Failed     Failed             Failed    Failed  Failed            Failed
# 3     0.98       0.93               0.94      0.02    0.14               1.0
# 4     0.98       0.88               0.93      0.03     0.1               1.0
# 5   Failed     Failed             Failed    Failed  Failed            Failed
# 6     0.94       0.81               0.88      0.04    0.47               1.0

# %%
# exp_dataset = "adult"
ALL_TABULAR_DATASETS = ["adult", "census", "child", "covtype", "credit", "insurance", "health_insurance", 
                       "intrusion", "drugs", "loan", "pums"]

for exp_dataset in ALL_TABULAR_DATASETS:
    
    final_report = get_scores_df(exp_dataset)
    
    try:
        pd.DataFrame(final_report)
    except Exception as e:
        print(e)
        print("~"*10, exp_dataset)
        for k, v in final_report.items():
            print(k, len(v))

# %%
pd.DataFrame(get_scores_df("adult"))
# Out:
#                   model  domain_cov  stats_cov  outliers_cov  ks_sim  tv_sim  \
# 0         actgan_gretel        0.89       0.99          0.49    0.79    0.92
# 1             ctgan_sdv        0.87       0.99          0.79    0.87    0.91
# 2              tvae_sdv        0.79       0.99          0.68    0.88    0.94
# 3   gaussian_copula_sdv        0.92       0.95          0.41    0.70    0.80
# 4             ctgan_syn        0.91       0.99          0.49    0.76    0.79
# 5              tvae_syn        0.86       0.99          0.65    0.81    0.89
# 6            goggle_syn        0.33       0.95          0.27    0.62    0.67
# 7               arf_syn        0.99       1.00          0.81    0.88    0.91
# 8              ddpm_syn        0.99       1.00          0.68    0.98    0.97
# 9             nflow_syn        0.97       0.98          0.70    0.89    0.77
# 10            rtvae_syn        0.73       0.98          0.39    0.77    0.74
# 11            great_llm        0.90       0.97          0.63    0.91    0.84
# 12       gan_betterdata        0.95       0.99          0.84    0.96    0.95
# 13    gan_dp_betterdata        0.97       0.99          0.76    0.93    0.94
#
#     corr_sim  contin_sim  sdv_quality_report  wass_dist  js_dist  \
# 0       0.97        0.87                0.88       0.02     0.24
# 1       0.98        0.82                0.87       0.02     0.22
# 2       0.97        0.88                0.91       0.02     0.13
# 3       0.99        0.73                0.76       0.07     0.29
# 4       0.98        0.74                0.78       0.02     0.34
# 5       0.99        0.81                0.84       0.01     0.30
# 6       0.97        0.49                0.59       0.06     0.54
# 7       0.99        0.87                0.90       0.01     0.16
# 8       0.98        0.95                0.97       0.01     0.06
# 9       0.97        0.69                0.77       0.02     0.23
# 10      0.98        0.65                0.73       0.02     0.48
# 11      0.98        0.78                0.84       0.03     0.13
# 12      0.98        0.36                0.70       0.01     0.11
# 13      0.98        0.34                0.68       0.02     0.14
#
#     new_row_synthesis
# 0                1.00
# 1                1.00
# 2                1.00
# 3                1.00
# 4                1.00
# 5                1.00
# 6                1.00
# 7                1.00
# 8                1.00
# 9                1.00
# 10               1.00
# 11               0.99
# 12               1.00
# 13               1.00

# %%
pd.DataFrame(get_scores_df("census"))
# Out:
#                   model domain_cov stats_cov outliers_cov   ks_sim   tv_sim  \
# 0         actgan_gretel       0.92      0.97         0.41     0.87     0.91
# 1             ctgan_sdv       None      None         None     None     None
# 2              tvae_sdv       0.91      0.98         0.38     0.93     0.95
# 3   gaussian_copula_sdv       0.93      0.89         0.29      0.5     0.77
# 4             ctgan_syn       None      None         None     None     None
# 5              tvae_syn       None      None         None     None     None
# 6            goggle_syn       None      None         None     None     None
# 7               arf_syn       None      None         None     None     None
# 8              ddpm_syn       None      None         None     None     None
# 9             nflow_syn       None      None         None     None     None
# 10            rtvae_syn       None      None         None     None     None
# 11            great_llm    Skipped   Skipped      Skipped  Skipped  Skipped
# 12       gan_betterdata       0.93      0.97         0.45     0.96     0.92
#
#    corr_sim contin_sim sdv_quality_report wass_dist  js_dist new_row_synthesis
# 0      0.98       0.88               0.89      0.02      0.2              0.98
# 1      None       None               None      None     None              None
# 2      0.98       0.92               0.93      0.02      0.1               0.9
# 3      0.98       0.64               0.68      0.11     0.42               1.0
# 4      None       None               None      None     None              None
# 5      None       None               None      None     None              None
# 6      None       None               None      None     None              None
# 7      None       None               None      None     None              None
# 8      None       None               None      None     None              None
# 9      None       None               None      None     None              None
# 10     None       None               None      None     None              None
# 11  Skipped    Skipped            Skipped   Skipped  Skipped           Skipped
# 12     0.97       0.53               0.73      0.02     0.07               1.0

# %%
pd.DataFrame(get_scores_df("child"))
# Out:
#                   model domain_cov stats_cov outliers_cov   ks_sim   tv_sim  \
# 0         actgan_gretel        1.0       -99          -99      -99     0.93
# 1             ctgan_sdv       0.97       -99          -99      -99      0.9
# 2              tvae_sdv       0.97       -99          -99      -99     0.95
# 3   gaussian_copula_sdv       0.94       -99          -99      -99     0.85
# 4             ctgan_syn        1.0       -99          -99      -99     0.94
# 5              tvae_syn        1.0       -99          -99      -99     0.97
# 6            goggle_syn        1.0       -99          -99      -99     0.75
# 7               arf_syn        1.0       -99          -99      -99     0.96
# 8              ddpm_syn        1.0       -99          -99      -99     0.96
# 9             nflow_syn        1.0       -99          -99      -99     0.91
# 10            rtvae_syn        1.0       -99          -99      -99     0.96
# 11            great_llm    Skipped   Skipped      Skipped  Skipped  Skipped
# 12       gan_betterdata    Skipped   Skipped      Skipped  Skipped  Skipped
#
#    corr_sim contin_sim sdv_quality_report wass_dist  js_dist new_row_synthesis
# 0       NaN       0.89               0.91       -99      -99              0.79
# 1       NaN       0.84               0.87       -99      -99              0.89
# 2       NaN       0.91               0.93       -99      -99              0.86
# 3       NaN       0.71               0.78       -99      -99               1.0
# 4       NaN        0.9               0.92       -99      -99              0.86
# 5       NaN       0.94               0.95       -99      -99              0.91
# 6       NaN       0.59               0.67       -99      -99              0.85
# 7       NaN       0.93               0.95       -99      -99              0.84
# 8       NaN       0.94               0.95       -99      -99              0.85
# 9       NaN       0.86               0.89       -99      -99              0.92
# 10      NaN       0.93               0.95       -99      -99              0.93
# 11  Skipped    Skipped            Skipped   Skipped  Skipped           Skipped
# 12  Skipped    Skipped            Skipped   Skipped  Skipped           Skipped

# %%
pd.DataFrame(get_scores_df("covtype"))
# Out:
#                   model domain_cov stats_cov outliers_cov   ks_sim   tv_sim  \
# 0         actgan_gretel       0.98      0.99          0.8     0.94     0.98
# 1             ctgan_sdv       0.84      0.97         0.68     0.88     0.96
# 2              tvae_sdv       0.76      0.97         0.42     0.84     0.98
# 3   gaussian_copula_sdv       0.75      0.99         0.56     0.95     0.17
# 4             ctgan_syn    Running   Running      Running  Running  Running
# 5              tvae_syn       None      None         None     None     None
# 6            goggle_syn     Failed    Failed       Failed   Failed   Failed
# 7               arf_syn        1.0       1.0         0.79     0.97      1.0
# 8              ddpm_syn       0.99       1.0         0.88     0.99      1.0
# 9             nflow_syn     Failed    Failed       Failed   Failed   Failed
# 10            rtvae_syn       0.86      0.99         0.29     0.88     0.98
# 11            great_llm    Skipped   Skipped      Skipped  Skipped  Skipped
# 12       gan_betterdata    Skipped   Skipped      Skipped  Skipped  Skipped
#
#    corr_sim contin_sim sdv_quality_report wass_dist  js_dist new_row_synthesis
# 0      0.97       0.95               0.96      0.02     0.11               1.0
# 1      0.97       0.91               0.93      0.04     0.15               1.0
# 2      0.96       0.93               0.94      0.04     0.22               1.0
# 3      0.98       0.17               0.26      0.01      0.1               1.0
# 4   Running    Running            Running   Running  Running           Running
# 5      None       None               None      None     None              None
# 6    Failed     Failed             Failed    Failed   Failed            Failed
# 7      0.99       0.99               0.99      0.01     0.06               1.0
# 8      0.99       0.98               0.99       0.0     0.06               1.0
# 9    Failed     Failed             Failed    Failed   Failed            Failed
# 10     0.97       0.91               0.94      0.02      0.7               1.0
# 11  Skipped    Skipped            Skipped   Skipped  Skipped           Skipped
# 12  Skipped    Skipped            Skipped   Skipped  Skipped           Skipped

# %%
pd.DataFrame(get_scores_df("credit"))
# Out:
#                   model domain_cov stats_cov outliers_cov   ks_sim   tv_sim  \
# 0         actgan_gretel       0.22       1.0         0.77      0.9     0.42
# 1             ctgan_sdv       0.19       1.0         0.96     0.98      1.0
# 2              tvae_sdv       0.15      0.99         0.37     0.93      1.0
# 3   gaussian_copula_sdv       0.25       1.0         0.62     0.88      0.0
# 4             ctgan_syn       0.56       1.0          0.8     0.93      1.0
# 5              tvae_syn       0.47       1.0         0.63     0.93      1.0
# 6            goggle_syn       None      None         None     None     None
# 7               arf_syn       0.75       1.0          0.8     0.96      1.0
# 8              ddpm_syn       None      None         None     None     None
# 9             nflow_syn       None      None         None     None     None
# 10            rtvae_syn       0.37       1.0         0.61     0.92      1.0
# 11            great_llm    Skipped   Skipped      Skipped  Skipped  Skipped
# 12       gan_betterdata    Skipped   Skipped      Skipped  Skipped  Skipped
#
#    corr_sim contin_sim sdv_quality_report wass_dist  js_dist new_row_synthesis
# 0      0.96       0.28                0.9      0.01     0.12              0.96
# 1      0.97       0.55               0.96       0.0     0.06              0.92
# 2      0.96       0.54               0.93      0.01     0.14              0.72
# 3      0.98        0.1               0.88      0.01     0.15               1.0
# 4      0.97       0.64               0.94      0.01     0.08              0.99
# 5      0.98       0.62               0.94      0.01     0.08              0.98
# 6      None       None               None      None     None              None
# 7      0.98       0.64               0.96       0.0     0.04              0.91
# 8      None       None               None      None     None              None
# 9      None       None               None      None     None              None
# 10     0.97       0.55               0.93      0.01     0.11               1.0
# 11  Skipped    Skipped            Skipped   Skipped  Skipped           Skipped
# 12  Skipped    Skipped            Skipped   Skipped  Skipped           Skipped

# %%
pd.DataFrame(get_scores_df("intrusion"))
# Out:
#                   model domain_cov stats_cov outliers_cov   ks_sim   tv_sim  \
# 0         actgan_gretel       0.74      0.89         0.36     0.83     0.91
# 1             ctgan_sdv       0.67      0.86         0.36     0.77     0.88
# 2              tvae_sdv       0.63      0.99         0.15     0.91     0.97
# 3   gaussian_copula_sdv       0.72      0.85         0.54     0.59     0.63
# 4             ctgan_syn       0.96       0.9         0.65     0.78     0.96
# 5              tvae_syn       0.76      0.95         0.35     0.81     0.95
# 6            goggle_syn     Failed    Failed       Failed   Failed   Failed
# 7               arf_syn       0.98      0.91         0.69      0.8     0.93
# 8              ddpm_syn       None      None         None     None     None
# 9             nflow_syn       None      None         None     None     None
# 10            rtvae_syn       None      None         None     None     None
# 11            great_llm    Skipped   Skipped      Skipped  Skipped  Skipped
# 12       gan_betterdata    Skipped   Skipped      Skipped  Skipped  Skipped
#
#    corr_sim contin_sim sdv_quality_report wass_dist  js_dist new_row_synthesis
# 0      0.96       0.78               0.84      0.07     0.18              0.98
# 1      0.92       0.74                0.8      0.12     0.22              0.98
# 2      0.93       0.87               0.91      0.02     0.15              0.96
# 3      0.95       0.48               0.56      0.28     0.39               1.0
# 4      0.98       0.91               0.91      0.02     0.17               1.0
# 5      0.97       0.87               0.89      0.02     0.18              0.99
# 6    Failed     Failed             Failed    Failed   Failed            Failed
# 7      0.98       0.88               0.89      0.06     0.14              0.97
# 8      None       None               None      None     None              None
# 9      None       None               None      None     None              None
# 10     None       None               None      None     None              None
# 11  Skipped    Skipped            Skipped   Skipped  Skipped           Skipped
# 12  Skipped    Skipped            Skipped   Skipped  Skipped           Skipped

# %%
pd.DataFrame(get_scores_df("insurance"))
# Out:
#                   model domain_cov stats_cov outliers_cov   ks_sim   tv_sim  \
# 0         actgan_gretel        1.0       -99          -99      -99     0.93
# 1             ctgan_sdv     Failed    Failed       Failed   Failed   Failed
# 2              tvae_sdv       0.93       -99          -99      -99     0.76
# 3   gaussian_copula_sdv       0.98       -99          -99      -99     0.85
# 4             ctgan_syn        1.0       -99          -99      -99     0.96
# 5              tvae_syn       0.96       -99          -99      -99     0.96
# 6            goggle_syn       0.62       -99          -99      -99     0.77
# 7               arf_syn       0.99       -99          -99      -99     0.98
# 8              ddpm_syn        1.0       -99          -99      -99     0.98
# 9             nflow_syn        1.0       -99          -99      -99     0.92
# 10            rtvae_syn       0.97       -99          -99      -99     0.97
# 11            great_llm    Skipped   Skipped      Skipped  Skipped  Skipped
# 12       gan_betterdata    Skipped   Skipped      Skipped  Skipped  Skipped
#
#    corr_sim contin_sim sdv_quality_report wass_dist  js_dist new_row_synthesis
# 0       NaN       0.89               0.91       -99      -99              0.94
# 1    Failed     Failed             Failed    Failed   Failed            Failed
# 2       NaN       0.59               0.67       -99      -99               1.0
# 3       NaN       0.73               0.79       -99      -99               1.0
# 4       NaN       0.93               0.94       -99      -99              0.91
# 5       NaN       0.94               0.95       -99      -99              0.95
# 6       NaN       0.62                0.7       -99      -99              0.93
# 7       NaN       0.96               0.97       -99      -99              0.87
# 8       NaN       0.96               0.97       -99      -99              0.85
# 9       NaN       0.87                0.9       -99      -99              0.96
# 10      NaN       0.94               0.95       -99      -99              0.94
# 11  Skipped    Skipped            Skipped   Skipped  Skipped           Skipped
# 12  Skipped    Skipped            Skipped   Skipped  Skipped           Skipped

# %%
pd.DataFrame(get_scores_df("health_insurance"))
# Out:
#                   model  domain_cov  stats_cov  outliers_cov  ks_sim  tv_sim  \
# 0         actgan_gretel        1.00       0.95          0.33    0.85    0.88
# 1             ctgan_sdv        0.98       0.89          0.35    0.75    0.88
# 2              tvae_sdv        0.91       0.95          0.67    0.81    0.82
# 3   gaussian_copula_sdv        0.93       0.95          0.11    0.85    0.87
# 4             ctgan_syn        0.92       0.94          0.32    0.86    0.88
# 5              tvae_syn        0.93       0.98          0.33    0.89    0.96
# 6            goggle_syn        0.56       0.90          0.00    0.63    0.73
# 7               arf_syn        1.00       0.97          0.57    0.90    0.94
# 8              ddpm_syn        1.00       0.95          0.67    0.89    0.91
# 9             nflow_syn        0.95       0.98          0.27    0.90    0.87
# 10            rtvae_syn        0.83       0.96          0.00    0.78    0.96
# 11            great_llm        0.99       0.96          0.63    0.88    0.95
# 12       gan_betterdata        0.97       0.96          0.67    0.88    0.94
#
#     corr_sim  contin_sim  sdv_quality_report  wass_dist  js_dist  \
# 0       0.91        0.82                0.85       0.07     0.19
# 1       0.89        0.81                0.82       0.13     0.24
# 2       0.98        0.74                0.80       0.07     0.20
# 3       0.94        0.80                0.84       0.07     0.18
# 4       0.98        0.80                0.85       0.07     0.21
# 5       0.96        0.86                0.90       0.03     0.26
# 6       0.92        0.51                0.63       0.10     0.55
# 7       0.95        0.88                0.91       0.04     0.12
# 8       0.92        0.83                0.87       0.07     0.21
# 9       0.96        0.82                0.86       0.02     0.15
# 10      0.90        0.73                0.82       0.07     0.53
# 11      0.93        0.72                0.83       0.05     0.15
# 12      0.97        0.71                0.83       0.05     0.18
#
#     new_row_synthesis
# 0                1.00
# 1                1.00
# 2                1.00
# 3                1.00
# 4                1.00
# 5                1.00
# 6                1.00
# 7                0.96
# 8                1.00
# 9                1.00
# 10               1.00
# 11               1.00
# 12               1.00

# %%
pd.DataFrame(get_scores_df("drugs"))
# Out:
#                   model domain_cov stats_cov outliers_cov   ks_sim   tv_sim  \
# 0         actgan_gretel        0.9      0.96          0.0     0.87     0.92
# 1             ctgan_sdv       0.89      0.96            1     0.89     0.92
# 2              tvae_sdv       0.77      0.93          0.0     0.83      NaN
# 3   gaussian_copula_sdv       0.87       1.0          0.0     0.92     0.88
# 4             ctgan_syn        -99       -99          -99     0.89     0.85
# 5              tvae_syn        -99       -99          -99     0.89     0.86
# 6            goggle_syn        -99       -99          -99     0.85     0.74
# 7               arf_syn        -99       -99          -99     0.91     0.86
# 8              ddpm_syn        -99       -99          -99     0.93      0.9
# 9             nflow_syn        -99       -99          -99      0.9     0.85
# 10            rtvae_syn        -99       -99          -99     0.74     0.82
# 11            great_llm    Skipped   Skipped      Skipped  Skipped  Skipped
# 12       gan_betterdata    Skipped   Skipped      Skipped  Skipped  Skipped
#
#    corr_sim contin_sim sdv_quality_report wass_dist  js_dist new_row_synthesis
# 0      0.94       0.82               0.87      0.05     0.18               -99
# 1      0.95       0.83               0.88      0.06     0.14               -99
# 2      0.99       0.76                0.8      0.06     0.18               -99
# 3      0.97       0.73                0.8      0.01     0.08               -99
# 4      0.93       0.14                0.5       -99      -99               -99
# 5      0.94       0.15                0.5       -99      -99               -99
# 6      0.95       0.08               0.41       -99      -99               -99
# 7      0.94       0.15               0.51       -99      -99               -99
# 8      0.93       0.18               0.54       -99      -99               -99
# 9      0.96       0.15                0.5       -99      -99               -99
# 10     0.92       0.11               0.47       -99      -99               -99
# 11  Skipped    Skipped            Skipped   Skipped  Skipped           Skipped
# 12  Skipped    Skipped            Skipped   Skipped  Skipped           Skipped

# %%
pd.DataFrame(get_scores_df("loan"))
# Out:
#                   model  domain_cov  stats_cov  outliers_cov  ks_sim  tv_sim  \
# 0         actgan_gretel        0.99       0.96          0.40    0.83    0.89
# 1             ctgan_sdv        0.97       0.97          0.37    0.85    0.93
# 2              tvae_sdv        0.91       0.95          0.20    0.82    0.85
# 3   gaussian_copula_sdv        0.94       0.98          0.39    0.89    0.97
# 4             ctgan_syn        0.96       0.96          0.49    0.87    0.96
# 5              tvae_syn        0.93       0.97          0.36    0.88    0.97
# 6            goggle_syn        0.75       0.89          0.19    0.58    0.77
# 7               arf_syn        1.00       0.99          0.33    0.89    0.98
# 8              ddpm_syn        1.00       0.94          0.44    0.96    0.97
# 9             nflow_syn        0.99       0.97          0.38    0.88    0.95
# 10            rtvae_syn        0.86       0.97          0.40    0.85    0.96
# 11            great_llm        0.98       0.96          0.37    0.88    0.96
# 12       gan_betterdata        1.00       0.99          0.38    0.93    0.96
#
#     corr_sim  contin_sim  sdv_quality_report  wass_dist  js_dist  \
# 0       0.92        0.85                0.87       0.05     0.16
# 1       0.91        0.88                0.89       0.04     0.15
# 2       0.96        0.79                0.83       0.07     0.25
# 3       0.97        0.91                0.93       0.03     0.19
# 4       0.98        0.85                0.90       0.05     0.21
# 5       0.96        0.89                0.92       0.04     0.27
# 6       0.91        0.58                0.66       0.13     0.55
# 7       0.97        0.91                0.93       0.02     0.15
# 8       0.96        0.89                0.93       0.03     0.09
# 9       0.94        0.89                0.91       0.04     0.17
# 10      0.95        0.81                0.87       0.04     0.48
# 11      0.97        0.59                0.80       0.05     0.16
# 12      0.98        0.75                0.87       0.02     0.11
#
#     new_row_synthesis
# 0                 1.0
# 1                 1.0
# 2                 1.0
# 3                 1.0
# 4                 1.0
# 5                 1.0
# 6                 1.0
# 7                 1.0
# 8                 1.0
# 9                 1.0
# 10                1.0
# 11                1.0
# 12                1.0

# %%
pd.DataFrame(get_scores_df("pums"))
# Out:
#                   model domain_cov stats_cov outliers_cov    ks_sim    tv_sim  \
# 0         actgan_gretel       0.81      0.99          0.6      0.85      0.98
# 1             ctgan_sdv       0.82      0.99         0.67      0.88      0.99
# 2              tvae_sdv        0.8      0.97         0.63      0.81      0.92
# 3   gaussian_copula_sdv       0.77      0.96         0.52      0.73      0.73
# 4             ctgan_syn     Failed    Failed       Failed    Failed    Failed
# 5              tvae_syn     Failed    Failed       Failed    Failed    Failed
# 6            goggle_syn    Running   Running      Running   Running   Running
# 7               arf_syn     Failed    Failed       Failed    Failed    Failed
# 8              ddpm_syn   Canceled  Canceled     Canceled  Canceled  Canceled
# 9             nflow_syn     Failed    Failed       Failed    Failed    Failed
# 10            rtvae_syn     Failed    Failed       Failed    Failed    Failed
# 11            great_llm    Skipped   Skipped      Skipped   Skipped   Skipped
# 12       gan_betterdata    Skipped   Skipped      Skipped   Skipped   Skipped
#
#     corr_sim contin_sim sdv_quality_report wass_dist   js_dist  \
# 0       0.97       0.91               0.92      0.01       0.2
# 1       0.99       0.94               0.95      0.01      0.19
# 2       0.95       0.82               0.86      0.04      0.29
# 3       0.97       0.62               0.69      0.05      0.35
# 4     Failed     Failed             Failed    Failed    Failed
# 5     Failed     Failed             Failed    Failed    Failed
# 6    Running    Running            Running   Running   Running
# 7     Failed     Failed             Failed    Failed    Failed
# 8   Canceled   Canceled           Canceled  Canceled  Canceled
# 9     Failed     Failed             Failed    Failed    Failed
# 10    Failed     Failed             Failed    Failed    Failed
# 11   Skipped    Skipped            Skipped   Skipped   Skipped
# 12   Skipped    Skipped            Skipped   Skipped   Skipped
#
#    new_row_synthesis
# 0               0.99
# 1                1.0
# 2                1.0
# 3                1.0
# 4             Failed
# 5             Failed
# 6            Running
# 7             Failed
# 8           Canceled
# 9             Failed
# 10            Failed
# 11           Skipped
# 12           Skipped

# %%
def get_ml_metrics(ml_efficacy_stats):
    # ml_efficacy_stats = data_dict["ml_efficacy"]
    ml_metrics = {}
    for classifier, scores in ml_efficacy_stats.items():
        if classifier == "timing":
            continue            
        ml_metrics[classifier] = round(abs(scores["synthetic_f1"] - scores["real_f1"]), 2)
    return ml_metrics

ML_CLASSIFICATION_TASK_DATASETS = [
    "adult", "census", "credit", "covtype", "loan", "intrusion"]
ML_REGRESSION_TASK_DATASETS = ["health_insurance"]
# ML_CLASSIFICATION_MODELS = ["adaboost", "decision_tree", "logistic", "mlp"]
# ML_REGRESSION_MODELS = ["linear", "mlp"]

# %%
ERROR_VAL  = -99
def get_ml_scores_df(exp_dataset, final_report, metric):
    for lib, models in ALL_TABULAR_MODELS.items():
        for model in models: 
            # corr_file = f"../metrics_out/tabular/{model}_{lib}/{exp_dataset}/{exp_dataset}_{model}_correlation.csv"
            metrics_file = f"../metrics_out/tabular/{model}_{lib}/{exp_dataset}/{exp_dataset}_{model}_metrics.json"
            
            final_report["dataset"].append(exp_dataset)
            final_report["model"].append(f"{model}_{lib}")
            
            try:
                with open(metrics_file, 'r') as file:
                    metrics_scores = json.load(file)
            except Exception as e:
                # print(model, lib)
                status = None
                if lib in TABULAR_INCOMPLETE_JOBS and model in TABULAR_INCOMPLETE_JOBS[lib]:
                    if exp_dataset in TABULAR_INCOMPLETE_JOBS[lib][model]:
                        # print("Status: ",  TABULAR_INCOMPLETE_JOBS[lib][model][exp_dataset])
                        # print("-")
                        status = TABULAR_INCOMPLETE_JOBS[lib][model][exp_dataset]
                else:
                    status = "Skipped"
                    # print(e)
                    # print("Skipped")
                for k in final_report.keys():
                    if k == "model": continue
                    final_report[k].append(status)
                    # print(final_report)
                continue
                
            for classifier, scores in metrics_scores["ml_efficacy"].items():
                if classifier == "timing":
                    continue            
                final_report[classifier].append(round(abs(scores[f"synthetic_{metric}"] - scores[f"real_{metric}"]), 2))
                # final_report_ml_cls["model"]["adaboost_classifier"].append()
                
    return final_report

# %%
final_report_ml_cls = {
    "dataset": [],  
    "model": [],
    "adaboost_classification": [], 
    "decision_tree_classification": [], 
    "logistic_classification": [],
    "mlp_classification": [], 
    # "linear_regressor": [],
    # "mlp_regressor": []
}

ml_cls_metric = "f1"

final_report_ml_regress = {
    "dataset": [],  
    "model": [],
    "linear_regression": [], 
    "mlp_regression": []
}

ml_regress_metric = "r2"

# %%
final_report = get_ml_scores_df("adult", final_report_ml_cls, ml_cls_metric)
pd.DataFrame(final_report)
# Out:
#    dataset                model  adaboost_classification  \
# 0    adult        actgan_gretel                     0.03
# 1    adult            ctgan_sdv                     0.01
# 2    adult             tvae_sdv                     0.01
# 3    adult  gaussian_copula_sdv                     0.02
# 4    adult            ctgan_syn                     0.04
# 5    adult             tvae_syn                     0.02
# 6    adult           goggle_syn                     0.06
# 7    adult              arf_syn                     0.01
# 8    adult             ddpm_syn                     0.01
# 9    adult            nflow_syn                     0.03
# 10   adult            rtvae_syn                     0.00
# 11   adult            great_llm                     0.02
# 12   adult       gan_betterdata                     0.03
#
#     decision_tree_classification  logistic_classification  mlp_classification
# 0                           0.01                     0.05                0.02
# 1                           0.03                     0.05                0.01
# 2                           0.02                     0.05                0.03
# 3                           0.11                     0.06                0.03
# 4                           0.08                     0.06                0.02
# 5                           0.07                     0.08                0.01
# 6                           0.31                     0.23                0.10
# 7                           0.02                     0.03                0.02
# 8                           0.02                     0.03                0.02
# 9                           0.05                     0.09                0.03
# 10                          0.16                     0.11                0.15
# 11                          0.04                     0.05                0.00
# 12                          0.03                     0.03                0.03

# %%
final_report = get_ml_scores_df("loan", final_report_ml_cls, ml_cls_metric)
pd.DataFrame(final_report)
#"adult", "census", "credit", "covtype", "loan", "intrusion"
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [292], in <cell line: 2>()
#       1 final_report = get_ml_scores_df("loan", final_report_ml_cls, ml_cls_metric)
# ----> 2 pd.DataFrame(final_report)
#
# File ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/core/frame.py:664, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     658     mgr = self._init_mgr(
#     659         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     660     )
#     662 elif isinstance(data, dict):
#     663     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 664     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     665 elif isinstance(data, ma.MaskedArray):
#     666     import numpy.ma.mrecords as mrecords
#
# File ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/core/internals/construction.py:493, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     489     else:
#     490         # dtype check to exclude e.g. range objects, scalars
#     491         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 493 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/core/internals/construction.py:118, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     115 if verify_integrity:
#     116     # figure out the index, if necessary
#     117     if index is None:
# --> 118         index = _extract_index(arrays)
#     119     else:
#     120         index = ensure_index(index)
#
# File ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/core/internals/construction.py:666, in _extract_index(data)
#     664 lengths = list(set(raw_lengths))
#     665 if len(lengths) > 1:
# --> 666     raise ValueError("All arrays must be of the same length")
#     668 if have_dicts:
#     669     raise ValueError(
#     670         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     671     )
#
# ValueError: All arrays must be of the same length

# %%
final_report = get_ml_scores_df("health_insurance", final_report_ml_regress, ml_regress_metric)
pd.DataFrame(final_report)
# Out:
#              dataset                model  linear_regression  mlp_regression
# 0   health_insurance        actgan_gretel               0.55            0.01
# 1   health_insurance            ctgan_sdv               0.90            0.01
# 2   health_insurance             tvae_sdv               0.12            0.01
# 3   health_insurance  gaussian_copula_sdv               0.31            0.01
# 4   health_insurance            ctgan_syn               0.00            0.01
# 5   health_insurance             tvae_syn               0.05            0.01
# 6   health_insurance           goggle_syn               0.44            0.02
# 7   health_insurance              arf_syn               0.00            0.01
# 8   health_insurance             ddpm_syn               0.27            0.01
# 9   health_insurance            nflow_syn               0.10            0.01
# 10  health_insurance            rtvae_syn               0.20            0.01
# 11  health_insurance            great_llm               0.38            0.01
# 12  health_insurance       gan_betterdata               0.07            0.01
